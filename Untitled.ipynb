# %%
import pandas as pd
from pprint import pprint

df_business = pd.read_json('dataset/business.json', lines=True)

# %%
category = {}
for i in df_business:
    print(type(i))
    if 'Restaurants' in i['categories'] and 'Adult' in i['categories']:
        print(i)        
#         for c in i:
#             if c in category:
#                 category[c] += 1
#             else:
#                 category[c] = 1

# %%
import matplotlib.pyplot as pyplot
pyplot.pie([v for v in category.values()], labels=[k for k in category.keys()], autopct=None)
pyplot.show()

# %%
pprint(category)
# Out:
# {'Acai Bowls': 31,
#  'Accessories': 3,
#  'Accountants': 1,
#  'Active Life': 199,
#  'Acupuncture': 2,
#  'Adult': 1,
#  'Adult Education': 4,
#  'Adult Entertainment': 22,
#  'Advertising': 2,
#  'Afghan': 88,
#  'African': 128,
#  'Air Duct Cleaning': 2,
#  'Aircraft Repairs': 1,
#  'Airport Lounges': 3,
#  'Airport Shuttles': 3,
#  'Airports': 8,
#  'Airsoft': 1,
#  'Alsatian': 1,
#  'Amateur Sports Teams': 8,
#  'American (New)': 3802,
#  'American (Traditional)': 5737,
#  'Amusement Parks': 10,
#  'Animal Shelters': 3,
#  'Antiques': 6,
#  'Apartments': 2,
#  'Appliances': 11,
#  'Appliances & Repair': 6,
#  'Aquarium Services': 1,
#  'Aquariums': 3,
#  'Arabian': 55,
#  'Arcades': 64,
#  'Argentine': 38,
#  'Armenian': 7,
#  'Art Classes': 4,
#  'Art Galleries': 32,
#  'Art Schools': 4,
#  'Arts & Crafts': 23,
#  'Arts & Entertainment': 703,
#  'Asian Fusion': 1554,
#  'Australian': 9,
#  'Austrian': 12,
#  'Auto Customization': 2,
#  'Auto Detailing': 1,
# ...

# %%
import json
import statistics
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import fcluster
from scipy.spatial.distance import pdist, squareform
import sklearn.cluster as cluster
import time
import scipy
import seaborn as sns
import random
sns.set_context('poster')
sns.set_color_codes()
plot_kwds = {'alpha': 0.25, 's':80, 'linewidths':0}

# %% [markdown]
# # set up type of service

# %%
# user input
user_input = 'Restaurants'
# u_id = 'McLqvYLBQoCFQikU9dC4cQ'

# %% [markdown]
# # read in business file, compose business categories, business rating on category and business postal code dictionary

# %%
# initialize business data
bcmap = {}
with open('./business.json','r') as bf:
    for line in bf:
        l = json.loads(line)
        
        key = l['business_id']
        state = l['city']
        #Business Category Dictionary
        category = l['categories']
        if state not in bcmap:
            bcmap[state] = {}
        bcmap[state][key] = category

# generate top categories
category = {}
for state in bcmap:
    category[state] = {}
    for i in bcmap[state]:
        if user_input in bcmap[state][i]:
            for j in bcmap[state][i]:
                if j not in category[state]:
                    category[state][j] = 1
                else:
                    category[state][j] += 1

tc = {}
for state in category:
    top_cate = sorted(category[state].items(), key=lambda x:(-x[1]))[1:21]
    tc[state] = []
    for i in top_cate:
        tc[state].append(i[0])
    
# initialize business data   
location = {}
bcrmap = {}
business_name = {}
with open('./business.json','r') as bf:
    for line in bf:
        l = json.loads(line)
        key = l['business_id']
        category = l['categories']
        
        # Business City Dictionary
        city = l['city']
        location[key] = city
        
        # Business -> Category -> Star Dictionary
        stars = l['stars']
        valid = False
        number_of_tc = 0
        if city not in bcrmap:
            bcrmap[city] = {}
        if key not in bcrmap[city]:
            bcrmap[city][key] = {}
        for i in category:
            if i in tc[city]:
                number_of_tc += 1
                valid = True
                bcrmap[city][key].setdefault(i,[]).append(stars)
        if not valid or number_of_tc <3:
            del bcrmap[city][key]
            
            
        # Business name -> Address Dictionary
        name = l['name'] +','  + l['address'] +','  + l['city'] +',' + l['state']
        business_name[key] = name

# %% [markdown]
# # read in review file and generate user to category to rating map

# %%
# initialize user review data
# User -> Categories -> Stars
ucrmap = {}
test_urcmap = {}
user_rating = {}
with open('./review.json', 'r') as rv:
    for line in rv:
        n1 = json.loads(line)
        
        okey = n1['user_id']
        year = n1['date']
        bid = n1['business_id']
        value = n1['stars']
        
        city = location[bid]
        
        ikeys = bcmap[city][bid]
        
        if city not in user_rating:
            user_rating[city] = {}
        user_rating[city].setdefault(okey, []).append(value)
        if city not in ucrmap:
            ucrmap[city]  = {}
        if city not in test_urcmap:
            test_urcmap[city]  = {}
        if int(n1['date'].split('-')[0]) < 2016:
            if okey not in ucrmap[city]:
                ucrmap[city][okey] = {}
            for ikey in ikeys:
                if ikey in tc[city]:
                    ucrmap[city][okey].setdefault(ikey, []).append(value)
        else:
            if okey not in test_urcmap:
                test_urcmap[city][okey] = {}
            test_urcmap[city][okey][bid] = value

# %%
listCity = {}
for i in ucrmap:
    if i in bcrmap:
        listCity[i] = {}
        listCity[i]['user'] = len(ucrmap[i])
        listCity[i]['business'] = len(bcrmap[i])

# %%
len(listCity)
# Out:
# 1010

# %%
sorted_by_business = sorted(listCity.items(), key=lambda x: -x[1]['business'])
sorted_by_business
# Out:
# [('Las Vegas', {'business': 1427, 'user': 290813}),
#  ('Toronto', {'business': 1325, 'user': 53905}),
#  ('Phoenix', {'business': 1033, 'user': 114505}),
#  ('Charlotte', {'business': 784, 'user': 39523}),
#  ('Edinburgh', {'business': 676, 'user': 6869}),
#  ('Pittsburgh', {'business': 671, 'user': 31715}),
#  ('Montréal', {'business': 614, 'user': 21535}),
#  ('Scottsdale', {'business': 542, 'user': 71454}),
#  ('Cleveland', {'business': 409, 'user': 20653}),
#  ('Madison', {'business': 368, 'user': 17121}),
#  ('Stuttgart', {'business': 326, 'user': 7877}),
#  ('Mesa', {'business': 285, 'user': 32842}),
#  ('Tempe', {'business': 272, 'user': 44293}),
#  ('Henderson', {'business': 227, 'user': 37913}),
#  ('Mississauga', {'business': 210, 'user': 8450}),
#  ('Chandler', {'business': 208, 'user': 30060}),
#  ('Gilbert', {'business': 180, 'user': 23918}),
#  ('Glendale', {'business': 166, 'user': 21017}),
#  ('Markham', {'business': 138, 'user': 6136}),
#  ('Peoria', {'business': 98, 'user': 12282}),
#  ('Champaign', {'business': 96, 'user': 6173}),
#  ('Brampton', {'business': 95, 'user': 2128}),
#  ('Concord', {'business': 83, 'user': 3941}),
#  ('Richmond Hill', {'business': 79, 'user': 4051}),
#  ('Lakewood', {'business': 75, 'user': 4170}),
#  ('North York', {'business': 74, 'user': 5138}),
#  ('Oakville', {'business': 71, 'user': 1927}),
#  ('Vaughan', {'business': 71, 'user': 2997}),
#  ('North Las Vegas', {'business': 68, 'user': 10471}),
#  ('Surprise', {'business': 66, 'user': 6230}),
#  ('Mentor', {'business': 58, 'user': 1511}),
#  ('Scarborough', {'business': 57, 'user': 4148}),
#  ('Etobicoke', {'business': 56, 'user': 3332}),
#  ('Fort Mill', {'business': 54, 'user': 2313}),
#  ('Cuyahoga Falls', {'business': 48, 'user': 1607}),
#  ('Strongsville', {'business': 47, 'user': 1738}),
#  ('Westlake', {'business': 47, 'user': 2282}),
#  ('Matthews', {'business': 46, 'user': 3170}),
#  ('Gastonia', {'business': 44, 'user': 1436}),
#  ('Goodyear', {'business': 42, 'user': 5891}),
#  ('Willoughby', {'business': 41, 'user': 1085}),
#  ('North Olmsted', {'business': 39, 'user': 1958}),
#  ('Whitby', {'business': 39, 'user': 802}),
#  ('Laval', {'business': 39, 'user': 659}),
#  ('Huntersville', {'business': 38, 'user': 3076}),
#  ('Aurora', {'business': 38, 'user': 969}),
#  ('Avondale', {'business': 37, 'user': 5230}),
#  ('Ludwigsburg', {'business': 36, 'user': 1113}),
#  ('Cornelius', {'business': 36, 'user': 2071}),
#  ('Newmarket', {'business': 35, 'user': 797}),
#  ('Urbana', {'business': 34, 'user': 2855}),
#  ('Parma', {'business': 33, 'user': 1552}),
#  ('Rocky River', {'business': 32, 'user': 1909}),
#  ('Solon', {'business': 32, 'user': 1093}),
#  ('Medina', {'business': 32, 'user': 1137}),
#  ('Middleton', {'business': 31, 'user': 2342}),
#  ('Monroeville', {'business': 31, 'user': 1751}),
#  ('Inverness', {'business': 30, 'user': 447}),
#  ('Kent', {'business': 30, 'user': 1277}),
#  ('Esslingen', {'business': 29, 'user': 563}),
#  ('Thornhill', {'business': 28, 'user': 2280}),
#  ('Cleveland Heights', {'business': 28, 'user': 2587}),
#  ('Stow', {'business': 28, 'user': 981}),
#  ('Avon', {'business': 28, 'user': 992}),
#  ('Fellbach', {'business': 27, 'user': 437}),
#  ('Sindelfingen', {'business': 27, 'user': 573}),
#  ('Sun Prairie', {'business': 27, 'user': 993}),
#  ('Ajax', {'business': 27, 'user': 672}),
#  ('Wexford', {'business': 26, 'user': 1120}),
#  ('Coraopolis', {'business': 26, 'user': 1139}),
#  ('Verona', {'business': 26, 'user': 872}),
#  ('Hudson', {'business': 25, 'user': 1156}),
#  ('Pickering', {'business': 25, 'user': 782}),
#  ('Cave Creek', {'business': 25, 'user': 3742}),
#  ('Elyria', {'business': 24, 'user': 502}),
#  ('Mayfield Heights', {'business': 23, 'user': 861}),
#  ('Montreal', {'business': 23, 'user': 2334}),
#  ('Woodbridge', {'business': 23, 'user': 840}),
#  ('Pineville', {'business': 23, 'user': 1983}),
#  ('Fountain Hills', {'business': 22, 'user': 1847}),
#  ('North Royalton', {'business': 22, 'user': 506}),
#  ('Irwin', {'business': 21, 'user': 328}),
#  ('Avon Lake', {'business': 21, 'user': 609}),
#  ('Brunswick', {'business': 21, 'user': 539}),
#  ('Bridgeville', {'business': 21, 'user': 844}),
#  ('Broadview Heights', {'business': 20, 'user': 591}),
#  ('Böblingen', {'business': 20, 'user': 641}),
#  ('Carnegie', {'business': 20, 'user': 644}),
#  ('Belmont', {'business': 19, 'user': 701}),
#  ('Middleburg Heights', {'business': 19, 'user': 625}),
#  ('Beachwood', {'business': 19, 'user': 1843}),
#  ('Pointe-Claire', {'business': 19, 'user': 321}),
#  ('Fitchburg', {'business': 18, 'user': 1350}),
#  ('Painesville', {'business': 18, 'user': 439}),
#  ('Ostfildern', {'business': 18, 'user': 176}),
#  ('Twinsburg', {'business': 18, 'user': 693}),
#  ('Monona', {'business': 18, 'user': 769}),
#  ('Fairlawn', {'business': 18, 'user': 862}),
#  ('Independence', {'business': 17, 'user': 1443}),
#  ('Boulder City', {'business': 16, 'user': 3567}),
#  ('Harrisburg', {'business': 16, 'user': 469}),
#  ('Bethel Park', {'business': 16, 'user': 648}),
#  ('Homestead', {'business': 16, 'user': 1140}),
#  ('Indian Trail', {'business': 16, 'user': 972}),
#  ('Streetsboro', {'business': 15, 'user': 548}),
#  ('Canonsburg', {'business': 15, 'user': 667}),
#  ('Litchfield Park', {'business': 15, 'user': 2201}),
#  ('Chagrin Falls', {'business': 14, 'user': 955}),
#  ('Kannapolis', {'business': 14, 'user': 451}),
#  ('Carefree', {'business': 14, 'user': 857}),
#  ('Davidson', {'business': 14, 'user': 945}),
#  ('Brossard', {'business': 13, 'user': 378}),
#  ('Leonberg', {'business': 13, 'user': 197}),
#  ('West Mifflin', {'business': 13, 'user': 517}),
#  ('Leinfelden-Echterdingen', {'business': 13, 'user': 405}),
#  ('Gerlingen', {'business': 13, 'user': 107}),
#  ('Euclid', {'business': 13, 'user': 337}),
#  ('Paradise Valley', {'business': 13, 'user': 2303}),
#  ('Berea', {'business': 13, 'user': 753}),
#  ('Amherst', {'business': 13, 'user': 373}),
#  ('Sewickley', {'business': 13, 'user': 515}),
#  ('McMurray', {'business': 13, 'user': 473}),
#  ('Stoughton', {'business': 13, 'user': 320}),
#  ('McKees Rocks', {'business': 13, 'user': 211}),
#  ('Fairview Park', {'business': 12, 'user': 729}),
#  ('North Versailles', {'business': 12, 'user': 142}),
#  ('Westmount', {'business': 12, 'user': 343}),
#  ('Laveen', {'business': 12, 'user': 873}),
#  ('Macedonia', {'business': 12, 'user': 462}),
#  ('Waxhaw', {'business': 12, 'user': 618}),
#  ('Lyndhurst', {'business': 11, 'user': 984}),
#  ('Gibsonia', {'business': 11, 'user': 390}),
#  ('Murrysville', {'business': 11, 'user': 412}),
#  ('Lorain', {'business': 11, 'user': 284}),
#  ('Waunakee', {'business': 11, 'user': 246}),
#  ('Brooklyn', {'business': 11, 'user': 494}),
#  ('New Kensington', {'business': 11, 'user': 279}),
#  ('Eastlake', {'business': 11, 'user': 277}),
#  ('Allison Park', {'business': 11, 'user': 389}),
#  ('Saint-Sauveur', {'business': 11, 'user': 97}),
#  ('Oregon', {'business': 10, 'user': 228}),
#  ('Dunfermline', {'business': 10, 'user': 88}),
#  ('Northfield', {'business': 10, 'user': 451}),
#  ('McKeesport', {'business': 10, 'user': 157}),
#  ('Waiblingen', {'business': 10, 'user': 213}),
#  ('Unionville', {'business': 10, 'user': 554}),
#  ('Brook Park', {'business': 10, 'user': 251}),
#  ('Sun City', {'business': 10, 'user': 1152}),
#  ('Georgetown', {'business': 10, 'user': 110}),
#  ('South Euclid', {'business': 10, 'user': 413}),
#  ('Dollard-Des-Ormeaux', {'business': 10, 'user': 258}),
#  ('Willoughby Hills', {'business': 10, 'user': 273}),
#  ('Olmsted Falls', {'business': 9, 'user': 310}),
#  ('Dorval', {'business': 9, 'user': 527}),
#  ('Chardon', {'business': 9, 'user': 233}),
#  ('Oakmont', {'business': 9, 'user': 314}),
#  ('Bedford', {'business': 9, 'user': 399}),
#  ('Saint-Laurent', {'business': 9, 'user': 435}),
#  ('Stouffville', {'business': 9, 'user': 142}),
#  ('Filderstadt', {'business': 9, 'user': 305}),
#  ('Mint Hill', {'business': 9, 'user': 323}),
#  ('Kornwestheim', {'business': 9, 'user': 126}),
#  ('Shaker Heights', {'business': 9, 'user': 362}),
#  ('Verdun', {'business': 9, 'user': 439}),
#  ('Pleasant Hills', {'business': 9, 'user': 205}),
#  ('York', {'business': 8, 'user': 540}),
#  ('Parma Heights', {'business': 8, 'user': 303}),
#  ('Mahomet', {'business': 8, 'user': 159}),
#  ('Valley View', {'business': 8, 'user': 515}),
#  ('Brecksville', {'business': 8, 'user': 495}),
#  ('White Oak', {'business': 8, 'user': 111}),
#  ('Ambridge', {'business': 8, 'user': 136}),
#  ('Woodmere', {'business': 8, 'user': 1170}),
#  ('Olivos', {'business': 8, 'user': 70}),
#  ('North Ridgeville', {'business': 8, 'user': 353}),
#  ('Chesterland', {'business': 8, 'user': 364}),
#  ('Boisbriand', {'business': 7, 'user': 25}),
#  ('De Forest', {'business': 7, 'user': 133}),
#  ('Saint-Jean-sur-Richelieu', {'business': 7, 'user': 43}),
#  ('East York', {'business': 7, 'user': 807}),
#  ('University Heights', {'business': 7, 'user': 458}),
#  ('Tolleson', {'business': 7, 'user': 910}),
#  ('Richfield', {'business': 7, 'user': 298}),
#  ('MESA', {'business': 7, 'user': 1192}),
#  ('North Huntingdon', {'business': 7, 'user': 223}),
#  ('Middlefield', {'business': 7, 'user': 130}),
#  ('Mount Holly', {'business': 7, 'user': 140}),
#  ('Maple', {'business': 7, 'user': 201}),
#  ('Willowick', {'business': 7, 'user': 228}),
#  ('Oakdale', {'business': 7, 'user': 134}),
#  ('Monticello', {'business': 7, 'user': 107}),
#  ('Robinson Township', {'business': 7, 'user': 259}),
#  ('Glenshaw', {'business': 7, 'user': 176}),
#  ('Bay Village', {'business': 6, 'user': 221}),
#  ('Lake Wylie', {'business': 6, 'user': 301}),
#  ('Seven Hills', {'business': 6, 'user': 264}),
#  ('Fairview', {'business': 6, 'user': 124}),
#  ('Warrensville Heights', {'business': 6, 'user': 300}),
#  ('Tallmadge', {'business': 6, 'user': 276}),
#  ('East Gwillimbury', {'business': 6, 'user': 71}),
#  ('Frazer', {'business': 6, 'user': 442}),
#  ('Mount Horeb', {'business': 6, 'user': 325}),
#  ('Bolton', {'business': 6, 'user': 84}),
#  ('Moon Township', {'business': 6, 'user': 360}),
#  ('Savoy', {'business': 6, 'user': 441}),
#  ('Belleville', {'business': 6, 'user': 93}),
#  ('Wickliffe', {'business': 6, 'user': 177}),
#  ('Cross Plains', {'business': 6, 'user': 134}),
#  ('Kirtland', {'business': 6, 'user': 117}),
#  ('Braddock', {'business': 6, 'user': 76}),
#  ('Garfield Heights', {'business': 6, 'user': 146}),
#  ('Highland Heights', {'business': 6, 'user': 462}),
#  ('El Mirage', {'business': 6, 'user': 541}),
#  ('Boucherville', {'business': 6, 'user': 69}),
#  ('Elizabeth', {'business': 6, 'user': 64}),
#  ('Bradford', {'business': 6, 'user': 66}),
#  ('Anthem', {'business': 6, 'user': 670}),
#  ('Livingston', {'business': 6, 'user': 103}),
#  ('Outremont', {'business': 6, 'user': 288}),
#  ('Tega Cay', {'business': 6, 'user': 257}),
#  ('Kirkland', {'business': 5, 'user': 80}),
#  ('Newbury', {'business': 5, 'user': 78}),
#  ('Dallas', {'business': 5, 'user': 74}),
#  ('Cottage Grove', {'business': 5, 'user': 146}),
#  ('West Homestead', {'business': 5, 'user': 377}),
#  ('Rantoul', {'business': 5, 'user': 117}),
#  ('Lachine', {'business': 5, 'user': 94}),
#  ('Saint Joseph', {'business': 5, 'user': 30}),
#  ('DeForest', {'business': 5, 'user': 134}),
#  ('Youngtown', {'business': 5, 'user': 282}),
#  ('Maple Heights', {'business': 5, 'user': 79}),
#  ('Lasalle', {'business': 5, 'user': 168}),
#  ('Sun City West', {'business': 5, 'user': 353}),
#  ('Copley', {'business': 5, 'user': 173}),
#  ('Tuscola', {'business': 5, 'user': 115}),
#  ('Monongahela', {'business': 5, 'user': 57}),
#  ('Ditzingen', {'business': 5, 'user': 99}),
#  ('Indian Land', {'business': 5, 'user': 233}),
#  ('Mc Farland', {'business': 5, 'user': 153}),
#  ('Neuhausen', {'business': 5, 'user': 52}),
#  ('Cramerton', {'business': 5, 'user': 162}),
#  ('Mc Kees Rocks', {'business': 5, 'user': 177}),
#  ('Esslingen am Neckar', {'business': 5, 'user': 116}),
#  ('Ahwatukee', {'business': 5, 'user': 509}),
#  ('Sheffield Village', {'business': 5, 'user': 133}),
#  ('Valley City', {'business': 5, 'user': 90}),
#  ('Whitchurch-Stouffville', {'business': 5, 'user': 202}),
#  ('King City', {'business': 5, 'user': 68}),
#  ('Richmond Heights', {'business': 5, 'user': 169}),
#  ('McFarland', {'business': 5, 'user': 112}),
#  ('Bedford Heights', {'business': 5, 'user': 84}),
#  ('WICKLIFFE', {'business': 5, 'user': 119}),
#  ('Mentor-on-the-Lake', {'business': 5, 'user': 86}),
#  ('Sainte-Therese', {'business': 4, 'user': 10}),
#  ('Lowell', {'business': 4, 'user': 90}),
#  ('Trafford', {'business': 4, 'user': 43}),
#  ('Anjou', {'business': 4, 'user': 47}),
#  ('Hemmingen', {'business': 4, 'user': 66}),
#  ('San Tan Valley', {'business': 4, 'user': 444}),
#  ('Mont-Royal', {'business': 4, 'user': 87}),
#  ('Sainte-Anne-de-Bellevue', {'business': 4, 'user': 27}),
#  ('Moon', {'business': 4, 'user': 35}),
#  ('Steinenbronn', {'business': 4, 'user': 23}),
#  ('Schomberg', {'business': 4, 'user': 15}),
#  ('Stallings', {'business': 4, 'user': 247}),
#  ('Fairport Harbor', {'business': 4, 'user': 55}),
#  ('Saint-Hubert', {'business': 4, 'user': 50}),
#  ('Higley', {'business': 4, 'user': 166}),
#  ('Roosevelt', {'business': 4, 'user': 33}),
#  ('Greenfield Park', {'business': 4, 'user': 45}),
#  ('Millvale', {'business': 4, 'user': 48}),
#  ('Peninsula', {'business': 4, 'user': 306}),
#  ('Caledon', {'business': 4, 'user': 75}),
#  ('New Town', {'business': 4, 'user': 43}),
#  ('Munhall', {'business': 4, 'user': 118}),
#  ('Wesley Chapel', {'business': 4, 'user': 149}),
#  ('Burton', {'business': 4, 'user': 119}),
#  ('Bellevue', {'business': 4, 'user': 212}),
#  ('Pierrefonds', {'business': 4, 'user': 124}),
#  ('Turtle Creek', {'business': 4, 'user': 70}),
#  ('Penn Hills', {'business': 4, 'user': 75}),
#  ('Columbia Station', {'business': 3, 'user': 55}),
#  ('Plum', {'business': 3, 'user': 91}),
#  ('Rouses Point', {'business': 3, 'user': 30}),
#  ('Houston', {'business': 3, 'user': 50}),
#  ('Etna', {'business': 3, 'user': 70}),
#  ('South Las Vegas', {'business': 3, 'user': 519}),
#  ('Rexdale', {'business': 3, 'user': 96}),
#  ('Glenrothes', {'business': 3, 'user': 26}),
#  ('Freyburg', {'business': 3, 'user': 36}),
#  ('Saint-Leonard', {'business': 3, 'user': 102}),
#  ('Ross Township', {'business': 3, 'user': 121}),
#  ('Laveen Village', {'business': 3, 'user': 15}),
#  ('Mount Lebanon', {'business': 3, 'user': 232}),
#  ('Missisauga', {'business': 3, 'user': 218}),
#  ('Wilmerding', {'business': 3, 'user': 37}),
#  ('Grafton', {'business': 3, 'user': 29}),
#  ('Brentwood', {'business': 3, 'user': 41}),
#  ('Imperial', {'business': 3, 'user': 69}),
#  ('Saint-Eustache', {'business': 3, 'user': 25}),
#  ('Emsworth', {'business': 3, 'user': 42}),
#  ('Bainbridge', {'business': 3, 'user': 62}),
#  ('Chateauguay', {'business': 3, 'user': 26}),
#  ('Old Town', {'business': 3, 'user': 17}),
#  ('Upper Saint Clair', {'business': 3, 'user': 6}),
#  ('Midland', {'business': 3, 'user': 43}),
#  ('Hampton Township', {'business': 3, 'user': 55}),
#  ('Penicuik', {'business': 3, 'user': 34}),
#  ('King', {'business': 3, 'user': 18}),
#  ('Saint-Lambert', {'business': 3, 'user': 45}),
#  ('Munroe Falls', {'business': 3, 'user': 58}),
#  ('South Queensferry', {'business': 3, 'user': 58}),
#  ('Sainte-Julie', {'business': 3, 'user': 14}),
#  ('Chambly', {'business': 3, 'user': 38}),
#  ('Clairton', {'business': 2, 'user': 72}),
#  ('Springdale', {'business': 2, 'user': 108}),
#  ('Hochdorf', {'business': 2, 'user': 11}),
#  ('Sheffield Lake', {'business': 2, 'user': 37}),
#  ('Blawnox', {'business': 2, 'user': 13}),
#  ('Musselburgh', {'business': 2, 'user': 78}),
#  ('Kernen im Remstal', {'business': 2, 'user': 18}),
#  ('Bratenahl', {'business': 2, 'user': 32}),
#  ('Korntal-Münchingen', {'business': 2, 'user': 41}),
#  ("L'Île-Perrot", {'business': 2, 'user': 77}),
#  ('Medina Township', {'business': 2, 'user': 26}),
#  ('Moreland Hills', {'business': 2, 'user': 148}),
#  ('City of Edinburgh', {'business': 2, 'user': 8}),
#  ('Caledon East', {'business': 2, 'user': 22}),
#  ('Kahnawake', {'business': 2, 'user': 9}),
#  ('Bradford West Gwillimbury', {'business': 2, 'user': 39}),
#  ('Kleinburg', {'business': 2, 'user': 37}),
#  ('Sheffield', {'business': 2, 'user': 53}),
#  ('Mayfield Village', {'business': 2, 'user': 132}),
#  ('Longueuil', {'business': 2, 'user': 147}),
#  ('Terrebonne', {'business': 2, 'user': 18}),
#  ('North Randall', {'business': 2, 'user': 54}),
#  ('Scottdale', {'business': 2, 'user': 233}),
#  ('Mount Albert', {'business': 2, 'user': 21}),
#  ('Dollard-des-Ormeaux', {'business': 2, 'user': 161}),
#  ('Beloeil', {'business': 2, 'user': 13}),
#  ('Saint-Jerome', {'business': 2, 'user': 24}),
#  ('Stowe', {'business': 2, 'user': 59}),
#  ('Heidelberg', {'business': 2, 'user': 29}),
#  ('La Salle', {'business': 2, 'user': 5}),
#  ('Châteauguay', {'business': 2, 'user': 13}),
#  ('Lasswade', {'business': 2, 'user': 31}),
#  ('Guadalupe', {'business': 2, 'user': 246}),
#  ('St-Leonard', {'business': 2, 'user': 2}),
#  ('Leith', {'business': 2, 'user': 66}),
#  ('Crafton', {'business': 2, 'user': 64}),
#  ('Orange Village', {'business': 2, 'user': 242}),
#  ('La Prairie', {'business': 2, 'user': 46}),
#  ('Mont-Saint-Hilaire', {'business': 2, 'user': 17}),
#  ('Cheswick', {'business': 2, 'user': 48}),
#  ('Leetsdale', {'business': 2, 'user': 110}),
#  ('columbia station', {'business': 2, 'user': 28}),
#  ('Oakland', {'business': 2, 'user': 56}),
#  ('Homer', {'business': 2, 'user': 6}),
#  ('Saint-Lazare', {'business': 2, 'user': 13}),
#  ('Harrison City', {'business': 2, 'user': 38}),
#  ('Rigaud', {'business': 2, 'user': 16}),
#  ('Wilkinsburg', {'business': 2, 'user': 25}),
#  ('Dalkeith', {'business': 2, 'user': 32}),
#  ('Grand River', {'business': 2, 'user': 124}),
#  ('Las  Vegas', {'business': 2, 'user': 200}),
#  ('Forest Hills', {'business': 2, 'user': 18}),
#  ('Stanley', {'business': 2, 'user': 48}),
#  ('Nellis Afb', {'business': 2, 'user': 47}),
#  ('Montreal-West', {'business': 2, 'user': 5}),
#  ('N. Las Vegas', {'business': 2, 'user': 172}),
#  ('Vaudreuil-Dorion', {'business': 2, 'user': 93}),
#  ('Joliette', {'business': 2, 'user': 7}),
#  ('Finleyville', {'business': 2, 'user': 56}),
#  ('Concord Mills', {'business': 2, 'user': 117}),
#  ('Blue Diamond', {'business': 2, 'user': 260}),
#  ('Delson', {'business': 2, 'user': 24}),
#  ('North Olmstead', {'business': 2, 'user': 10}),
#  ('Saint-Hyacinthe', {'business': 2, 'user': 15}),
#  ('Mont-Saint-Gregoire', {'business': 2, 'user': 15}),
#  ('Mt. Lebanon', {'business': 2, 'user': 189}),
#  ('Schönaich', {'business': 2, 'user': 51}),
#  ('Willowdale', {'business': 2, 'user': 22}),
#  ('Sainte-Anne-De-Bellevue', {'business': 2, 'user': 38}),
#  ('Avalon', {'business': 2, 'user': 52}),
#  ('Cuddy', {'business': 2, 'user': 3}),
#  ('Baldwin', {'business': 2, 'user': 18}),
#  ('Beaconsfield', {'business': 2, 'user': 30}),
#  ('Brooklin', {'business': 1, 'user': 39}),
#  ('Stockbridge', {'business': 1, 'user': 31}),
#  ('Montéal', {'business': 1, 'user': 8}),
#  ('Lake Park', {'business': 1, 'user': 6}),
#  ('Ridgeville', {'business': 1, 'user': 1}),
#  ('Litchfield', {'business': 1, 'user': 23}),
#  ('Sainte-Marie', {'business': 1, 'user': 0}),
#  ('Paoli', {'business': 1, 'user': 38}),
#  ('St-Benoît de Mirabel', {'business': 1, 'user': 33}),
#  ('Elizabeth Township', {'business': 1, 'user': 13}),
#  ('Rosemère', {'business': 1, 'user': 19}),
#  ('Saint-Jean-Sur-Richelieu', {'business': 1, 'user': 7}),
#  ('River Drive Park', {'business': 1, 'user': 4}),
#  ('Sainte-Catherine', {'business': 1, 'user': 5}),
#  ('toronto', {'business': 1, 'user': 35}),
#  ('Don Mills', {'business': 1, 'user': 60}),
#  ('Robinson Twp.', {'business': 1, 'user': 52}),
#  ('Buena Vista', {'business': 1, 'user': 0}),
#  ('Russellton', {'business': 1, 'user': 15}),
#  ('Montreal-Ouest', {'business': 1, 'user': 36}),
#  ('Nobleton', {'business': 1, 'user': 16}),
#  ('Green Valley', {'business': 1, 'user': 14}),
#  ('Las vegas', {'business': 1, 'user': 210}),
#  ('Sainte-Adele', {'business': 1, 'user': 10}),
#  ('tempe arizona', {'business': 1, 'user': 0}),
#  ('Tremont', {'business': 1, 'user': 204}),
#  ('Harmarville', {'business': 1, 'user': 19}),
#  ('North Scottsdale', {'business': 1, 'user': 127}),
#  ('Auburn Twp', {'business': 1, 'user': 3}),
#  ('McCandless', {'business': 1, 'user': 10}),
#  ('Queensferry', {'business': 1, 'user': 24}),
#  ('Paradise', {'business': 1, 'user': 346}),
#  ('Venetia', {'business': 1, 'user': 23}),
#  ('Olmsted Township', {'business': 1, 'user': 22}),
#  ('Troy Township', {'business': 1, 'user': 5}),
#  ('Mc Murray', {'business': 1, 'user': 53}),
#  ('Library', {'business': 1, 'user': 20}),
#  ('Quartermile', {'business': 1, 'user': 10}),
#  ('Lawrence', {'business': 1, 'user': 6}),
#  ('Upper St Clair', {'business': 1, 'user': 70}),
#  ('Currie', {'business': 1, 'user': 2}),
#  ('Lavaltrie', {'business': 1, 'user': 0}),
#  ('Champlain', {'business': 1, 'user': 27}),
#  ('Bainbridge Township', {'business': 1, 'user': 7}),
#  ('New Eagle', {'business': 1, 'user': 12}),
#  ('Mirabel', {'business': 1, 'user': 10}),
#  ('Indian Lands', {'business': 1, 'user': 0}),
#  ('Indian land', {'business': 1, 'user': 8}),
#  ('East McKeesport', {'business': 1, 'user': 8}),
#  ('South Park', {'business': 1, 'user': 45}),
#  ('Prévost', {'business': 1, 'user': 3}),
#  ('Orange', {'business': 1, 'user': 16}),
#  ('Hinckley', {'business': 1, 'user': 52}),
#  ('Bonnyrigg', {'business': 1, 'user': 9}),
#  ('Salaberry-De-Valleyfield', {'business': 1, 'user': 8}),
#  ('West Akron', {'business': 1, 'user': 61}),
#  ('Bloomfield', {'business': 1, 'user': 4}),
#  ('Gelndale', {'business': 1, 'user': 9}),
#  ('Woodmere Village', {'business': 1, 'user': 182}),
#  ('Dollard-Des Ormeaux', {'business': 1, 'user': 16}),
#  ('Kennedy Township', {'business': 1, 'user': 10}),
#  ('Whiitby', {'business': 1, 'user': 7}),
#  ('Saint-Henri', {'business': 1, 'user': 10}),
#  ('Aichwald', {'business': 1, 'user': 4}),
#  ('Stoney Creek', {'business': 1, 'user': 10}),
#  ('Inglewood', {'business': 1, 'user': 5}),
#  ('Linden', {'business': 1, 'user': 5}),
#  ('Ratho', {'business': 1, 'user': 17}),
#  ('Montreal-Nord', {'business': 1, 'user': 21}),
#  ('Warrensvile Heights', {'business': 1, 'user': 6}),
#  ('chandler', {'business': 1, 'user': 32}),
#  ('Catawba Springs', {'business': 1, 'user': 3}),
#  ('Haddington', {'business': 1, 'user': 11}),
#  ('Edgewood', {'business': 1, 'user': 16}),
#  ('Fort McDowell', {'business': 1, 'user': 211}),
#  ('Lagrange', {'business': 1, 'user': 19}),
#  ('Mansfield', {'business': 1, 'user': 3}),
#  ('Spring Valley', {'business': 1, 'user': 241}),
#  ('Schottsdale', {'business': 1, 'user': 0}),
#  ('Lower Burrell', {'business': 1, 'user': 38}),
#  ('Weddington', {'business': 1, 'user': 37}),
#  ('Estérel', {'business': 1, 'user': 6}),
#  ('Jefferson Hills', {'business': 1, 'user': 26}),
#  ('Russell', {'business': 1, 'user': 3}),
#  ('Shaler Township', {'business': 1, 'user': 13}),
#  ('Pepper Pike', {'business': 1, 'user': 230}),
#  ('Dudley', {'business': 1, 'user': 6}),
#  ('Pheonix AZ', {'business': 1, 'user': 2}),
#  ('Concord Twp', {'business': 1, 'user': 1}),
#  ('Paw Creek', {'business': 1, 'user': 1}),
#  ('Schwaikheim', {'business': 1, 'user': 9}),
#  ('Brimfield', {'business': 1, 'user': 9}),
#  ('Saint-Sauveur-des-Monts', {'business': 1, 'user': 6}),
#  ('Goodwood', {'business': 1, 'user': 8}),
#  ('Sainte-Genevieve', {'business': 1, 'user': 8}),
#  ('Sainte-Madeleine', {'business': 1, 'user': 1}),
#  ('Brookpark', {'business': 1, 'user': 79}),
#  ('Gifford', {'business': 1, 'user': 9}),
#  ('Saint-Bruno', {'business': 1, 'user': 5}),
#  ('McCandless Township', {'business': 1, 'user': 71}),
#  ('Aspinwall', {'business': 1, 'user': 128}),
#  ('St-Lazare-de-Vaudreuil', {'business': 1, 'user': 1}),
#  ('Mantua', {'business': 1, 'user': 40}),
#  ('Enterprise', {'business': 1, 'user': 158}),
#  ('Richmond Hil', {'business': 1, 'user': 34}),
#  ('Brunswick Hills', {'business': 1, 'user': 4}),
#  ('Scarobrough', {'business': 1, 'user': 8}),
#  ('Malton', {'business': 1, 'user': 3}),
#  ('Denkendorf', {'business': 1, 'user': 29}),
#  ('Whtiby', {'business': 1, 'user': 5}),
#  ('Moss', {'business': 1, 'user': 13}),
#  ('Kernen', {'business': 1, 'user': 35}),
#  ('Central City', {'business': 1, 'user': 3}),
#  ('Pheonix', {'business': 1, 'user': 99}),
#  ('Beauharnois', {'business': 1, 'user': 1}),
#  ('Scaroborough', {'business': 1, 'user': 32}),
#  ('TORONTO', {'business': 1, 'user': 3}),
#  ('Gates Mills', {'business': 1, 'user': 38}),
#  ('Glendale Az', {'business': 1, 'user': 43}),
#  ('Downtown', {'business': 1, 'user': 42}),
#  ('LasVegas', {'business': 1, 'user': 0}),
#  ('Saint-Marc-Sur-Richelieu', {'business': 1, 'user': 4}),
#  ('Rillton', {'business': 1, 'user': 3}),
#  ('Cecil', {'business': 1, 'user': 94}),
#  ('Noyan', {'business': 1, 'user': 5}),
#  ('Chomedey, Laval', {'business': 1, 'user': 0}),
#  ('Springfield', {'business': 1, 'user': 3}),
#  ('East Cleveland', {'business': 1, 'user': 12}),
#  ('Presto', {'business': 1, 'user': 42}),
#  ('Sagamore Hills', {'business': 1, 'user': 14}),
#  ('Dane', {'business': 1, 'user': 12}),
#  ('NORTH YORK', {'business': 1, 'user': 15}),
#  ('Sainte-Marthe', {'business': 1, 'user': 2}),
#  ('Lachute', {'business': 1, 'user': 7}),
#  ('Thornhil', {'business': 1, 'user': 7}),
#  ('Kirkcaldy', {'business': 1, 'user': 33}),
#  ('Warrensville Hts.', {'business': 1, 'user': 25}),
#  ('Nellis AFB', {'business': 1, 'user': 53}),
#  ('Phoenix Valley', {'business': 1, 'user': 2}),
#  ('Sainte-Marguerite-du-Lac-Masson', {'business': 1, 'user': 3}),
#  ('Ranlo', {'business': 1, 'user': 5}),
#  ('Thorncliffe Park', {'business': 1, 'user': 6}),
#  ('Sainte-thérèse', {'business': 1, 'user': 1}),
#  ('Rawdon', {'business': 1, 'user': 7}),
#  ('Centre Island', {'business': 1, 'user': 2}),
#  ('West View', {'business': 1, 'user': 67}),
#  ('Saint Laurent', {'business': 1, 'user': 21}),
#  ('Saint-Basile-Le-Grand', {'business': 1, 'user': 2}),
#  ('Saint Leonard', {'business': 1, 'user': 3}),
#  ('Bernhausen', {'business': 1, 'user': 31}),
#  ('Sun Lakes', {'business': 1, 'user': 125}),
#  ("L'ile-Perrot", {'business': 1, 'user': 20}),
#  ('East Mc Keesport', {'business': 1, 'user': 10}),
#  ('Bathurst Quay', {'business': 1, 'user': 10}),
#  ('South Park Township', {'business': 1, 'user': 58}),
#  ('North Toronto', {'business': 1, 'user': 17}),
#  ('Cleveland Hghts.', {'business': 1, 'user': 19}),
#  ('Farnham', {'business': 1, 'user': 1}),
#  ('Rural Ridge', {'business': 1, 'user': 4}),
#  ('Richmond Hts', {'business': 1, 'user': 14}),
#  ('East Pittsburgh', {'business': 1, 'user': 21}),
#  ('LaSalle', {'business': 1, 'user': 9}),
#  ('Sainte-Adèle', {'business': 1, 'user': 9}),
#  ('Schwieberdingen', {'business': 1, 'user': 34}),
#  ('Ft. Mill', {'business': 1, 'user': 43}),
#  ('Elrama', {'business': 1, 'user': 10}),
#  ('Saint-Marc-sur-Richelieu', {'business': 1, 'user': 1}),
#  ('Remseck am Neckar', {'business': 1, 'user': 17}),
#  ('Lower Lawrenceville', {'business': 1, 'user': 181}),
#  ('Cote-Saint-Luc', {'business': 1, 'user': 12}),
#  ('Northside', {'business': 1, 'user': 0}),
#  ('Napierville', {'business': 1, 'user': 2}),
#  ('Streetsville', {'business': 1, 'user': 15}),
#  ('Phx', {'business': 1, 'user': 0}),
#  ('Montrose', {'business': 1, 'user': 62}),
#  ('Clarkson', {'business': 1, 'user': 8}),
#  ('Saint-Constant', {'business': 1, 'user': 12}),
#  ('Wilkins Township', {'business': 1, 'user': 34}),
#  ('Ben Avon', {'business': 1, 'user': 28}),
#  ('Dravosburg', {'business': 1, 'user': 28}),
#  ('Peters Township', {'business': 1, 'user': 36}),
#  ('Harrisbug', {'business': 1, 'user': 0}),
#  ('Dalgety Bay', {'business': 1, 'user': 2}),
#  ('Mayfield', {'business': 1, 'user': 101}),
#  ('clinton', {'business': 1, 'user': 18}),
#  ('', {'business': 0, 'user': 10}),
#  ('Sindelfingen/Eichholz', {'business': 0, 'user': 5}),
#  ('South Amherst', {'business': 0, 'user': 2}),
#  ('N. Randall', {'business': 0, 'user': 3}),
#  ('Bonnyrigg and Lasswade', {'business': 0, 'user': 3}),
#  ('Sainte-Thérèse-de-Blainville', {'business': 0, 'user': 0}),
#  ('Freiberg', {'business': 0, 'user': 4}),
#  ('Pointe-Aux-Trembles', {'business': 0, 'user': 7}),
#  ('Hazelwood', {'business': 0, 'user': 0}),
#  ('Burntisland', {'business': 0, 'user': 6}),
#  ('Old Scottsdale', {'business': 0, 'user': 3}),
#  ('Promenade', {'business': 0, 'user': 14}),
#  ('Livingstone', {'business': 0, 'user': 2}),
#  ('Middleburg Hts', {'business': 0, 'user': 22}),
#  ('W Spring Valley', {'business': 0, 'user': 33}),
#  ('Fox Chapel', {'business': 0, 'user': 4}),
#  ('Hendserson', {'business': 0, 'user': 1}),
#  ('Elk Grove Villa', {'business': 0, 'user': 40}),
#  ('Bois-Des-Filion', {'business': 0, 'user': 1}),
#  ('Lachenaie', {'business': 0, 'user': 3}),
#  ("Baie-d'Urfé", {'business': 0, 'user': 0}),
#  ('las vegas', {'business': 0, 'user': 473}),
#  ('Upper St. Clair', {'business': 0, 'user': 14}),
#  ('Ingomar', {'business': 0, 'user': 4}),
#  ('St-Lazare', {'business': 0, 'user': 3}),
#  ('Pgh Int Arprt', {'business': 0, 'user': 2}),
#  ('Deux-Montagnes Regional County Municipality', {'business': 0, 'user': 3}),
#  ('Möglingen', {'business': 0, 'user': 22}),
#  ('St Leonard', {'business': 0, 'user': 6}),
#  ('nboulder city', {'business': 0, 'user': 25}),
#  ("L'assomption", {'business': 0, 'user': 2}),
#  ('Sun City Anthem', {'business': 0, 'user': 6}),
#  ('peoria', {'business': 0, 'user': 2}),
#  ('Broadlands', {'business': 0, 'user': 2}),
#  ('Ogden', {'business': 0, 'user': 16}),
#  ('Saint - Hyacinthe', {'business': 0, 'user': 4}),
#  ('Candiac', {'business': 0, 'user': 5}),
#  ('Brooklyn Hts.', {'business': 0, 'user': 6}),
#  ('Villa Grove', {'business': 0, 'user': 4}),
#  ('Henderson (Green Valley)', {'business': 0, 'user': 15}),
#  ('Le Sud-Ouest', {'business': 0, 'user': 12}),
#  ('Gormley', {'business': 0, 'user': 23}),
#  ('Buckeye - Shaker', {'business': 0, 'user': 7}),
#  ('Dewey', {'business': 0, 'user': 2}),
#  ('Henderston', {'business': 0, 'user': 23}),
#  ('McMasterville', {'business': 0, 'user': 3}),
#  ('West Toronto', {'business': 0, 'user': 4}),
#  ('Chateau', {'business': 0, 'user': 3}),
#  ('Edinburgh City of', {'business': 0, 'user': 4}),
#  ('Nellis', {'business': 0, 'user': 2}),
#  ('N Ridgeville', {'business': 0, 'user': 8}),
#  ('Indian Land,', {'business': 0, 'user': 1}),
#  ('Vaughn City', {'business': 0, 'user': 0}),
#  ('St. Anns', {'business': 0, 'user': 3}),
#  ('South Gyle', {'business': 0, 'user': 6}),
#  ('Phoniex', {'business': 0, 'user': 1}),
#  ('Las Vegas East', {'business': 0, 'user': 15}),
#  ("Peoria Ave Citizen's Group", {'business': 0, 'user': 4}),
#  ('North Braddock', {'business': 0, 'user': 0}),
#  ('Ingliston', {'business': 0, 'user': 0}),
#  ('Mississuaga', {'business': 0, 'user': 5}),
#  ('Saint-Antoine', {'business': 0, 'user': 5}),
#  ('Straiton', {'business': 0, 'user': 1}),
#  ('Meza', {'business': 0, 'user': 12}),
#  ('Pine', {'business': 0, 'user': 6}),
#  ('Woodbridge (Vaughan)', {'business': 0, 'user': 3}),
#  ('SLOAN', {'business': 0, 'user': 4}),
#  ('Monoroeville', {'business': 0, 'user': 6}),
#  ('Cowdenbeath', {'business': 0, 'user': 3}),
#  ('Summerlin South', {'business': 0, 'user': 11}),
#  ('Mint  Hill', {'business': 0, 'user': 39}),
#  ('Stuttgart Bad-Canstatt', {'business': 0, 'user': 3}),
#  ('Tranent', {'business': 0, 'user': 5}),
#  ('Hawthorne', {'business': 0, 'user': 2}),
#  ('Lothian', {'business': 0, 'user': 4}),
#  ('Mesa Arizona', {'business': 0, 'user': 0}),
#  ('Bruntsfield', {'business': 0, 'user': 5}),
#  ('etobicoke', {'business': 0, 'user': 4}),
#  ('Nellis Air Force Base', {'business': 0, 'user': 4}),
#  ('Lacolle', {'business': 0, 'user': 0}),
#  ('Scott Township', {'business': 0, 'user': 7}),
#  ('Scarborough,', {'business': 0, 'user': 2}),
#  ('Oak Ridges', {'business': 0, 'user': 0}),
#  ('Saint-Bernard-de-Lacolle', {'business': 0, 'user': 5}),
#  ('Godmanchester', {'business': 0, 'user': 2}),
#  ('McMurry', {'business': 0, 'user': 5}),
#  ('Hemmingford', {'business': 0, 'user': 0}),
#  ('Banksville', {'business': 0, 'user': 4}),
#  ('East Mesa', {'business': 0, 'user': 3}),
#  ('Auburn Township', {'business': 0, 'user': 8}),
#  ('Middleburg Hts.', {'business': 0, 'user': 6}),
#  ('St. Jean Sur Richelieu', {'business': 0, 'user': 3}),
#  ('Charlotte (University)', {'business': 0, 'user': 10}),
#  ('Norval', {'business': 0, 'user': 3}),
#  ('N. Ridgeville', {'business': 0, 'user': 2}),
#  ('Glasgow', {'business': 0, 'user': 8}),
#  ('Citibank', {'business': 0, 'user': 2}),
#  ('Fitchburgh', {'business': 0, 'user': 0}),
#  ('Phoneix', {'business': 0, 'user': 8}),
#  ('East Mississauga', {'business': 0, 'user': 7}),
#  ('Strongville', {'business': 0, 'user': 5}),
#  ('Stetten', {'business': 0, 'user': 2}),
#  ('N W Las Vegas', {'business': 0, 'user': 29}),
#  ('Ahwahtukee', {'business': 0, 'user': 11}),
#  ('Robinson Town', {'business': 0, 'user': 6}),
#  ('St Bernard de Lacolle', {'business': 0, 'user': 4}),
#  ('McKnight', {'business': 0, 'user': 17}),
#  ('Lingen', {'business': 0, 'user': 5}),
#  ('Vimont', {'business': 0, 'user': 15}),
#  ('Fountainbridge', {'business': 0, 'user': 7}),
#  ('Firth of Forth', {'business': 0, 'user': 18}),
#  ('Liberty', {'business': 0, 'user': 5}),
#  ('C Las Vegas', {'business': 0, 'user': 20}),
#  ('Spring Hill City View', {'business': 0, 'user': 1}),
#  ('Tolono', {'business': 0, 'user': 5}),
#  ('South Hills', {'business': 0, 'user': 5}),
#  ('Central City Village', {'business': 0, 'user': 25}),
#  ('East Gwilimbury', {'business': 0, 'user': 3}),
#  ('La Baie', {'business': 0, 'user': 9}),
#  ('Summerlin', {'business': 0, 'user': 53}),
#  ('Las Vegas Strip', {'business': 0, 'user': 1}),
#  ('Side Slopes', {'business': 0, 'user': 4}),
#  ('Camargo', {'business': 0, 'user': 2}),
#  ('Mooers', {'business': 0, 'user': 1}),
#  ('Leslieville', {'business': 0, 'user': 2}),
#  ('Mississauaga', {'business': 0, 'user': 0}),
#  ('Westworld Scottsdale', {'business': 0, 'user': 6}),
#  ("L'Île-Bizard", {'business': 0, 'user': 10}),
#  ('McDonald', {'business': 0, 'user': 20}),
#  ('Saint-Bernard-De-Lacolle', {'business': 0, 'user': 15}),
#  ('Fullerton', {'business': 0, 'user': 11}),
#  ('Pepperpike', {'business': 0, 'user': 4}),
#  ('Aberlady', {'business': 0, 'user': 4}),
#  ('Warrensville', {'business': 0, 'user': 4}),
#  ('Ste-Therese-de-Blainville', {'business': 0, 'user': 0}),
#  ('Central Henderson', {'business': 0, 'user': 23}),
#  ('Montréal (Québec)', {'business': 0, 'user': 2}),
#  ('Boston Heights', {'business': 0, 'user': 3}),
#  ('Reminderville', {'business': 0, 'user': 4}),
#  ('SCOTTSDALE AZ', {'business': 0, 'user': 9}),
#  ('AGINCOURT', {'business': 0, 'user': 4}),
#  ('Moon Twp', {'business': 0, 'user': 13}),
#  ('frazer', {'business': 0, 'user': 12}),
#  ('Fort  Mill', {'business': 0, 'user': 0}),
#  ('Neville Island', {'business': 0, 'user': 19}),
#  ('Ste-Rose', {'business': 0, 'user': 15}),
#  ('Bradfordwoods', {'business': 0, 'user': 6}),
#  ('Surprise Crossing', {'business': 0, 'user': 5}),
#  ('Sharpsburg', {'business': 0, 'user': 79}),
#  ('Huntsburg', {'business': 0, 'user': 4}),
#  ('Murrysville (Monroeville)', {'business': 0, 'user': 6}),
#  ('McAdenville', {'business': 0, 'user': 25}),
#  ('Vaudreuil', {'business': 0, 'user': 0}),
#  ('West Lothian', {'business': 0, 'user': 2}),
#  ('Las Vegas NV', {'business': 0, 'user': 1}),
#  ('Point Claire', {'business': 0, 'user': 2}),
#  ('Newburgh Heights', {'business': 0, 'user': 4}),
#  ('Stuttgart - Bad Cannstatt', {'business': 0, 'user': 5}),
#  ('Stuttgart-Vaihingen', {'business': 0, 'user': 7}),
#  ('Statesville', {'business': 0, 'user': 3}),
#  ('Harwick', {'business': 0, 'user': 5}),
#  ('Piedmont', {'business': 0, 'user': 9}),
#  ('Walton Hills', {'business': 0, 'user': 34}),
#  ('York Regional Municipality', {'business': 0, 'user': 22}),
#  ('Vanier', {'business': 0, 'user': 7}),
#  ('Old Town Scottsdale', {'business': 0, 'user': 1}),
#  ('Morin-Heights', {'business': 0, 'user': 11}),
#  ('Pencaitland', {'business': 0, 'user': 9}),
#  ('Warrensville Hts', {'business': 0, 'user': 5}),
#  ('Côte-Saint-Luc', {'business': 0, 'user': 4}),
#  ('Sloan', {'business': 0, 'user': 0}),
#  ('Loanhead', {'business': 0, 'user': 25}),
#  ('Glbert', {'business': 0, 'user': 1}),
#  ('N Las Vegas', {'business': 0, 'user': 137}),
#  ("Baie-D'urfe", {'business': 0, 'user': 4}),
#  ('Blackness', {'business': 0, 'user': 10}),
#  ('Roslin', {'business': 0, 'user': 8}),
#  ('Sainte-Dorothée', {'business': 0, 'user': 0}),
#  ('East Loth', {'business': 0, 'user': 2}),
#  ('North Huntington', {'business': 0, 'user': 15}),
#  ('St-Laurent', {'business': 0, 'user': 3}),
#  ('Sainte-Anne-des-Plaines', {'business': 0, 'user': 2}),
#  ('Montral', {'business': 0, 'user': 5}),
#  ('Oakwood Village', {'business': 0, 'user': 22}),
#  ('Juniper Green', {'business': 0, 'user': 9}),
#  ('Lambton', {'business': 0, 'user': 5}),
#  ('Shorewood Hills', {'business': 0, 'user': 29}),
#  ('Brooklyn Heights', {'business': 0, 'user': 2}),
#  ('Ingram', {'business': 0, 'user': 5}),
#  ('Mccandless Township', {'business': 0, 'user': 4}),
#  ('Mattews', {'business': 0, 'user': 6}),
#  ('St. Joseph', {'business': 0, 'user': 2}),
#  ('Estrella Village', {'business': 0, 'user': 0}),
#  ('Duquesne', {'business': 0, 'user': 3}),
#  ('Windsor', {'business': 0, 'user': 108}),
#  ('Leaside', {'business': 0, 'user': 3}),
#  ('Montréal-Ouest', {'business': 0, 'user': 2}),
#  ('Pincourt', {'business': 0, 'user': 3}),
#  ('Chatauguay', {'business': 0, 'user': 2}),
#  ('Montréal-Nord', {'business': 0, 'user': 17}),
#  ('Geauga', {'business': 0, 'user': 4}),
#  ('Greater Charlotte', {'business': 0, 'user': 0}),
#  ('Maple Grove', {'business': 0, 'user': 2}),
#  ('Ansnorveldt', {'business': 0, 'user': 5}),
#  ('University Ht', {'business': 0, 'user': 4}),
#  ('NorthYork', {'business': 0, 'user': 1}),
#  ('Ashburn', {'business': 0, 'user': 3}),
#  ('Mckeesport', {'business': 0, 'user': 4}),
#  ("Notre-Dame-De-L'ile-Perrot", {'business': 0, 'user': 9}),
#  ('Sunrise', {'business': 0, 'user': 12}),
#  ('Mayfield Hts.', {'business': 0, 'user': 2}),
#  ('Glassport', {'business': 0, 'user': 10}),
#  ('Morriston', {'business': 0, 'user': 3}),
#  ('Leinfelden', {'business': 0, 'user': 12}),
#  ('Lauder', {'business': 0, 'user': 5}),
#  ('Charlemagne', {'business': 0, 'user': 5}),
#  ('Saint-Philippe', {'business': 0, 'user': 7}),
#  ('Silver Lake', {'business': 0, 'user': 5}),
#  ('Mercier', {'business': 0, 'user': 11}),
#  ('Mt Albert', {'business': 0, 'user': 6}),
#  ('Mascouche', {'business': 0, 'user': 12}),
#  ('Rankin', {'business': 0, 'user': 4}),
#  ('Bellvue', {'business': 0, 'user': 18}),
#  ('Prestonpans', {'business': 0, 'user': 8}),
#  ('Queensville', {'business': 0, 'user': 1}),
#  ('Toronto, Ontario', {'business': 0, 'user': 11}),
#  ('Fithian', {'business': 0, 'user': 3}),
#  ('Arlington', {'business': 0, 'user': 3}),
#  ('San Tan', {'business': 0, 'user': 0}),
#  ('Strip District', {'business': 0, 'user': 1}),
#  ('Mt Lebanon', {'business': 0, 'user': 51}),
#  ('Mathews', {'business': 0, 'user': 1}),
#  ('Mayfield Heights (Cleveland)', {'business': 0, 'user': 12}),
#  ('Median', {'business': 0, 'user': 10}),
#  ('Herminie', {'business': 0, 'user': 1}),
#  ('Clark', {'business': 0, 'user': 172}),
#  ('Pointe Claire', {'business': 0, 'user': 5}),
#  ('Westview', {'business': 0, 'user': 1}),
#  ('Regional Municipality of York', {'business': 0, 'user': 8}),
#  ('Totronto', {'business': 0, 'user': 1}),
#  ('Sidney', {'business': 0, 'user': 9}),
#  ('Cuyahoga Heights', {'business': 0, 'user': 16}),
#  ('Le Haut-Saint-Laurent Regional County Municipality',
#   {'business': 0, 'user': 3}),
#  ('Münster', {'business': 0, 'user': 4}),
#  ('N. Olmsted', {'business': 0, 'user': 31}),
#  ('Leven', {'business': 0, 'user': 6}),
#  ('Indianola', {'business': 0, 'user': 3}),
#  ('Île des Soeurs', {'business': 0, 'user': 24}),
#  ('Phoenix metro area', {'business': 0, 'user': 5}),
#  ('Sainte-Thérèse', {'business': 0, 'user': 7}),
#  ('110 Las Vegas', {'business': 0, 'user': 7}),
#  ('Repentigny', {'business': 0, 'user': 9}),
#  ('Old Port of Montreal', {'business': 0, 'user': 1}),
#  ('Newington', {'business': 0, 'user': 10}),
#  ('Vilas', {'business': 0, 'user': 3}),
#  ('Blainville', {'business': 0, 'user': 12}),
#  ('Philo', {'business': 0, 'user': 15}),
#  ('Sunnyslope', {'business': 0, 'user': 8}),
#  ('Northfield Center', {'business': 0, 'user': 12}),
#  ('Inverkeithing', {'business': 0, 'user': 8}),
#  ('Lowesville', {'business': 0, 'user': 10}),
#  ('Bedford HTS', {'business': 0, 'user': 12}),
#  ('Pilton', {'business': 0, 'user': 3}),
#  ('Nottingham', {'business': 0, 'user': 80}),
#  ('Allegheny', {'business': 0, 'user': 5}),
#  ('Bedford Hts.', {'business': 0, 'user': 7}),
#  ('Port Credit', {'business': 0, 'user': 55}),
#  ('Las Vegas, NV', {'business': 0, 'user': 7}),
#  ("L'Ile-Perrot", {'business': 0, 'user': 2}),
#  ('Glen Williams', {'business': 0, 'user': 1}),
#  ('Plieningen', {'business': 0, 'user': 6}),
#  ('Topaz', {'business': 0, 'user': 19}),
#  ('Berry', {'business': 0, 'user': 4}),
#  ('Forest Grove', {'business': 0, 'user': 3}),
#  ('Swissvale', {'business': 0, 'user': 28}),
#  ('Pittsburg', {'business': 0, 'user': 22}),
#  ('Edimbourg', {'business': 0, 'user': 1}),
#  ('Old Brooklyn', {'business': 0, 'user': 0}),
#  ('Gorebridge', {'business': 0, 'user': 8}),
#  ('Kingussie', {'business': 0, 'user': 5}),
#  ('Shady Side', {'business': 0, 'user': 5}),
#  ('Scotesdale', {'business': 0, 'user': 3}),
#  ('N. OLMSTED', {'business': 0, 'user': 11}),
#  ('Pittsburch', {'business': 0, 'user': 2}),
#  ('Saint-Hippolyte', {'business': 0, 'user': 4}),
#  ('St Joseph', {'business': 0, 'user': 3}),
#  ('Castle Shannon', {'business': 0, 'user': 43}),
#  ('Rainbow Valley', {'business': 0, 'user': 2}),
#  ('Clinton', {'business': 0, 'user': 16}),
#  ('Crescent', {'business': 0, 'user': 4}),
#  ('Creighton', {'business': 0, 'user': 8}),
#  ('Sun City Grand', {'business': 0, 'user': 2}),
#  ('Pitcairn', {'business': 0, 'user': 6}),
#  ('Mt. Horeb', {'business': 0, 'user': 9}),
#  ('Edgeworth', {'business': 0, 'user': 2}),
#  ('Gullane', {'business': 0, 'user': 20}),
#  ('Scotland', {'business': 0, 'user': 3}),
#  ('Saint-Isidore-De-Laprairie', {'business': 0, 'user': 2}),
#  ('Vaughn', {'business': 0, 'user': 5}),
#  ('Henderson and Las vegas', {'business': 0, 'user': 8}),
#  ('Berg', {'business': 0, 'user': 7}),
#  ('Ormstown', {'business': 0, 'user': 2}),
#  ('Shaler', {'business': 0, 'user': 2}),
#  ('Water of Leith', {'business': 0, 'user': 7}),
#  ('St-Bruno-de-Montarville', {'business': 0, 'user': 0}),
#  ('Downtown Toronto', {'business': 0, 'user': 5}),
#  ('Highland Hills', {'business': 0, 'user': 5}),
#  ('Aberdour', {'business': 0, 'user': 3}),
#  ('Lake Norman', {'business': 0, 'user': 3}),
#  ('Huntingdon', {'business': 0, 'user': 2}),
#  ('Mc Donald', {'business': 0, 'user': 8}),
#  ('Saint-Pierre-de-Véronne-à-Pike-River', {'business': 0, 'user': 3}),
#  ('Plum Boro', {'business': 0, 'user': 2}),
#  ('Broxburn', {'business': 0, 'user': 3}),
#  ('Charlote', {'business': 0, 'user': 0}),
#  ('W Henderson', {'business': 0, 'user': 44}),
#  ('East Liberty', {'business': 0, 'user': 28}),
#  ('oakville', {'business': 0, 'user': 3}),
#  ("Saint-Roch-De-L'achigan", {'business': 0, 'user': 3}),
#  ('Bath', {'business': 0, 'user': 34}),
#  ('South Mountain', {'business': 0, 'user': 4}),
#  ('Gilbert AZ', {'business': 0, 'user': 2}),
#  ('Wolfschlugen', {'business': 0, 'user': 2}),
#  ('CHARLOTTE', {'business': 0, 'user': 0}),
#  ('Phoenix,', {'business': 0, 'user': 11}),
#  ('Stetson Valley', {'business': 0, 'user': 1}),
#  ('Brookline', {'business': 0, 'user': 49}),
#  ('Hendersonville', {'business': 0, 'user': 7}),
#  ('Russell Twp', {'business': 0, 'user': 5}),
#  ('Mt. Oliver Boro', {'business': 0, 'user': 3}),
#  ('Southside Flats', {'business': 0, 'user': 4}),
#  ('FORT MILL', {'business': 0, 'user': 2}),
#  ('Cooksville', {'business': 0, 'user': 4}),
#  ('Mesa AZ', {'business': 0, 'user': 3}),
#  ('Longniddry', {'business': 0, 'user': 3}),
#  ('Beeton', {'business': 0, 'user': 11}),
#  ('Remseck', {'business': 0, 'user': 38}),
#  ('Saint-Jérôme', {'business': 0, 'user': 12}),
#  ('Waddell', {'business': 0, 'user': 104}),
#  ('East Credit', {'business': 0, 'user': 2}),
#  ('Stowe Township', {'business': 0, 'user': 7}),
#  ('Black Earth', {'business': 0, 'user': 55}),
#  ('Chagrin Highlands', {'business': 0, 'user': 1}),
#  ('Saint Anns', {'business': 0, 'user': 1}),
#  ('MC Murray', {'business': 0, 'user': 8}),
#  ('San Rafael', {'business': 0, 'user': 175}),
#  ('Municipality of Murrysville', {'business': 0, 'user': 3}),
#  ('Newhaven', {'business': 0, 'user': 35}),
#  ('St-Jerome', {'business': 0, 'user': 2}),
#  ('Goodyear AZ', {'business': 0, 'user': 2}),
#  ('North of Brampton', {'business': 0, 'user': 9}),
#  ('Vieux Montreal', {'business': 0, 'user': 41}),
#  ('Mayfield Hts', {'business': 0, 'user': 1}),
#  ('Wildwood', {'business': 0, 'user': 12}),
#  ('Cramond', {'business': 0, 'user': 7}),
#  ('Whitney', {'business': 0, 'user': 4}),
#  ('London', {'business': 0, 'user': 4}),
#  ('Kernen-Stetten', {'business': 0, 'user': 4}),
#  ("L'Île-Perrôt", {'business': 0, 'user': 5}),
#  ('Mayfield Heights.', {'business': 0, 'user': 3}),
#  ('Alburg', {'business': 0, 'user': 3}),
#  ('St Davids', {'business': 0, 'user': 43}),
#  ('Harrisburg,', {'business': 0, 'user': 3}),
#  ('University Hts ', {'business': 0, 'user': 7}),
#  ('Arnold', {'business': 0, 'user': 45}),
#  ('Mount Washington', {'business': 0, 'user': 14}),
#  ('Arrowhead', {'business': 0, 'user': 2}),
#  ('Portobello', {'business': 0, 'user': 2}),
#  ('Phoenix AZ', {'business': 0, 'user': 1}),
#  ('Chander', {'business': 0, 'user': 4}),
#  ('Mount Royal', {'business': 0, 'user': 1}),
#  ('Saint-Bruno-de-Montarville', {'business': 0, 'user': 6}),
#  ('Canonsburd', {'business': 0, 'user': 1}),
#  ('Henderson Nevada', {'business': 0, 'user': 1}),
#  ('West Elizabeth', {'business': 0, 'user': 3}),
#  ('Roxboro', {'business': 0, 'user': 6}),
#  ('Saint-sauveur', {'business': 0, 'user': 3}),
#  ('East Lothian', {'business': 0, 'user': 7}),
#  ('St-Eugène', {'business': 0, 'user': 4}),
#  ('Shadyside', {'business': 0, 'user': 51}),
#  ('Ahwatukee Foothills Village', {'business': 0, 'user': 4}),
#  ('Rosemere', {'business': 0, 'user': 25}),
#  ('Novelty', {'business': 0, 'user': 9}),
#  ('Morgan', {'business': 0, 'user': 3}),
#  ('Tottenham', {'business': 0, 'user': 5}),
#  ('Île-des-Soeurs', {'business': 0, 'user': 2}),
#  ('Kirknewton', {'business': 0, 'user': 8}),
#  ('Mentor On the Lake', {'business': 0, 'user': 23}),
#  ('CITY CENTER', {'business': 0, 'user': 25}),
#  ('Squirrel Hill', {'business': 0, 'user': 20}),
#  ('Chertsey', {'business': 0, 'user': 4}),
#  ('Phoenix, AZ', {'business': 0, 'user': 12}),
#  ('Newbridge', {'business': 0, 'user': 31}),
#  ('North Olmsted,', {'business': 0, 'user': 0}),
#  ('Mentor On the', {'business': 0, 'user': 18}),
#  ('Las Vegass', {'business': 0, 'user': 5}),
#  ('Desert Ridge', {'business': 0, 'user': 7}),
#  ('Ballantyne', {'business': 0, 'user': 6}),
#  ('Fabreville', {'business': 0, 'user': 5}),
#  ('Shandwick', {'business': 0, 'user': 3}),
#  ('Lake Las Vegas', {'business': 0, 'user': 2}),
#  ('Concord Township', {'business': 0, 'user': 1}),
#  ('Oka', {'business': 0, 'user': 11}),
#  ('Mcmurray', {'business': 0, 'user': 6}),
#  ('Green Tree', {'business': 0, 'user': 64}),
#  ('Balerno', {'business': 0, 'user': 3}),
#  ('North Queensferry', {'business': 0, 'user': 27}),
#  ('Ste-Adele', {'business': 0, 'user': 1}),
#  ('Ross', {'business': 0, 'user': 5}),
#  ('Monroeville - Pit.', {'business': 0, 'user': 2}),
#  ('Palmerston', {'business': 0, 'user': 3}),
#  ('Caledon Village', {'business': 0, 'user': 4}),
#  ('Shaker Hts', {'business': 0, 'user': 4}),
#  ('Cote Saint-Luc', {'business': 0, 'user': 10}),
#  ('Communauté-Urbaine-de-Montréal', {'business': 0, 'user': 10}),
#  ('Downsview', {'business': 0, 'user': 19}),
#  ('Northfield Center Township', {'business': 0, 'user': 4}),
#  ('Centennial Hills', {'business': 0, 'user': 23}),
#  ('Churubusco', {'business': 0, 'user': 9}),
#  ('Hiram', {'business': 0, 'user': 14}),
#  ('Robinson', {'business': 0, 'user': 122}),
#  ('Cuyahoga Fls', {'business': 0, 'user': 5}),
#  ('The Promenade', {'business': 0, 'user': 1}),
#  ('Chandler-Gilbert', {'business': 0, 'user': 8}),
#  ('Bentleyville', {'business': 0, 'user': 2}),
#  ('Midlothian', {'business': 0, 'user': 46}),
#  ('mesa', {'business': 0, 'user': 18}),
#  ('N E Las Vegas', {'business': 0, 'user': 8}),
#  ...]

# %%
sorted_by_user = sorted(listCity.items(), key=lambda x: -x[1]['user'])
sorted_by_user
# Out:
# [('Las Vegas', {'business': 1427, 'user': 290813}),
#  ('Phoenix', {'business': 1033, 'user': 114505}),
#  ('Scottsdale', {'business': 542, 'user': 71454}),
#  ('Toronto', {'business': 1325, 'user': 53905}),
#  ('Tempe', {'business': 272, 'user': 44293}),
#  ('Charlotte', {'business': 784, 'user': 39523}),
#  ('Henderson', {'business': 227, 'user': 37913}),
#  ('Mesa', {'business': 285, 'user': 32842}),
#  ('Pittsburgh', {'business': 671, 'user': 31715}),
#  ('Chandler', {'business': 208, 'user': 30060}),
#  ('Gilbert', {'business': 180, 'user': 23918}),
#  ('Montréal', {'business': 614, 'user': 21535}),
#  ('Glendale', {'business': 166, 'user': 21017}),
#  ('Cleveland', {'business': 409, 'user': 20653}),
#  ('Madison', {'business': 368, 'user': 17121}),
#  ('Peoria', {'business': 98, 'user': 12282}),
#  ('North Las Vegas', {'business': 68, 'user': 10471}),
#  ('Mississauga', {'business': 210, 'user': 8450}),
#  ('Stuttgart', {'business': 326, 'user': 7877}),
#  ('Edinburgh', {'business': 676, 'user': 6869}),
#  ('Surprise', {'business': 66, 'user': 6230}),
#  ('Champaign', {'business': 96, 'user': 6173}),
#  ('Markham', {'business': 138, 'user': 6136}),
#  ('Goodyear', {'business': 42, 'user': 5891}),
#  ('Avondale', {'business': 37, 'user': 5230}),
#  ('North York', {'business': 74, 'user': 5138}),
#  ('Lakewood', {'business': 75, 'user': 4170}),
#  ('Scarborough', {'business': 57, 'user': 4148}),
#  ('Richmond Hill', {'business': 79, 'user': 4051}),
#  ('Concord', {'business': 83, 'user': 3941}),
#  ('Cave Creek', {'business': 25, 'user': 3742}),
#  ('Boulder City', {'business': 16, 'user': 3567}),
#  ('Etobicoke', {'business': 56, 'user': 3332}),
#  ('Matthews', {'business': 46, 'user': 3170}),
#  ('Huntersville', {'business': 38, 'user': 3076}),
#  ('Vaughan', {'business': 71, 'user': 2997}),
#  ('Urbana', {'business': 34, 'user': 2855}),
#  ('Cleveland Heights', {'business': 28, 'user': 2587}),
#  ('Middleton', {'business': 31, 'user': 2342}),
#  ('Montreal', {'business': 23, 'user': 2334}),
#  ('Fort Mill', {'business': 54, 'user': 2313}),
#  ('Paradise Valley', {'business': 13, 'user': 2303}),
#  ('Westlake', {'business': 47, 'user': 2282}),
#  ('Thornhill', {'business': 28, 'user': 2280}),
#  ('Litchfield Park', {'business': 15, 'user': 2201}),
#  ('Brampton', {'business': 95, 'user': 2128}),
#  ('Cornelius', {'business': 36, 'user': 2071}),
#  ('Pineville', {'business': 23, 'user': 1983}),
#  ('North Olmsted', {'business': 39, 'user': 1958}),
#  ('Oakville', {'business': 71, 'user': 1927}),
#  ('Rocky River', {'business': 32, 'user': 1909}),
#  ('Fountain Hills', {'business': 22, 'user': 1847}),
#  ('Beachwood', {'business': 19, 'user': 1843}),
#  ('Monroeville', {'business': 31, 'user': 1751}),
#  ('Strongsville', {'business': 47, 'user': 1738}),
#  ('Cuyahoga Falls', {'business': 48, 'user': 1607}),
#  ('Parma', {'business': 33, 'user': 1552}),
#  ('Mentor', {'business': 58, 'user': 1511}),
#  ('Independence', {'business': 17, 'user': 1443}),
#  ('Gastonia', {'business': 44, 'user': 1436}),
#  ('Fitchburg', {'business': 18, 'user': 1350}),
#  ('Kent', {'business': 30, 'user': 1277}),
#  ('MESA', {'business': 7, 'user': 1192}),
#  ('Woodmere', {'business': 8, 'user': 1170}),
#  ('Hudson', {'business': 25, 'user': 1156}),
#  ('Sun City', {'business': 10, 'user': 1152}),
#  ('Homestead', {'business': 16, 'user': 1140}),
#  ('Coraopolis', {'business': 26, 'user': 1139}),
#  ('Medina', {'business': 32, 'user': 1137}),
#  ('Wexford', {'business': 26, 'user': 1120}),
#  ('Ludwigsburg', {'business': 36, 'user': 1113}),
#  ('Solon', {'business': 32, 'user': 1093}),
#  ('Willoughby', {'business': 41, 'user': 1085}),
#  ('Sun Prairie', {'business': 27, 'user': 993}),
#  ('Avon', {'business': 28, 'user': 992}),
#  ('Lyndhurst', {'business': 11, 'user': 984}),
#  ('Stow', {'business': 28, 'user': 981}),
#  ('Indian Trail', {'business': 16, 'user': 972}),
#  ('Aurora', {'business': 38, 'user': 969}),
#  ('Chagrin Falls', {'business': 14, 'user': 955}),
#  ('Davidson', {'business': 14, 'user': 945}),
#  ('Tolleson', {'business': 7, 'user': 910}),
#  ('Laveen', {'business': 12, 'user': 873}),
#  ('Verona', {'business': 26, 'user': 872}),
#  ('Fairlawn', {'business': 18, 'user': 862}),
#  ('Mayfield Heights', {'business': 23, 'user': 861}),
#  ('Carefree', {'business': 14, 'user': 857}),
#  ('Bridgeville', {'business': 21, 'user': 844}),
#  ('Woodbridge', {'business': 23, 'user': 840}),
#  ('East York', {'business': 7, 'user': 807}),
#  ('Whitby', {'business': 39, 'user': 802}),
#  ('Newmarket', {'business': 35, 'user': 797}),
#  ('Pickering', {'business': 25, 'user': 782}),
#  ('Monona', {'business': 18, 'user': 769}),
#  ('Berea', {'business': 13, 'user': 753}),
#  ('Fairview Park', {'business': 12, 'user': 729}),
#  ('Belmont', {'business': 19, 'user': 701}),
#  ('Twinsburg', {'business': 18, 'user': 693}),
#  ('Ajax', {'business': 27, 'user': 672}),
#  ('Anthem', {'business': 6, 'user': 670}),
#  ('Canonsburg', {'business': 15, 'user': 667}),
#  ('Laval', {'business': 39, 'user': 659}),
#  ('Bethel Park', {'business': 16, 'user': 648}),
#  ('Carnegie', {'business': 20, 'user': 644}),
#  ('Böblingen', {'business': 20, 'user': 641}),
#  ('Middleburg Heights', {'business': 19, 'user': 625}),
#  ('Waxhaw', {'business': 12, 'user': 618}),
#  ('Avon Lake', {'business': 21, 'user': 609}),
#  ('Broadview Heights', {'business': 20, 'user': 591}),
#  ('Sindelfingen', {'business': 27, 'user': 573}),
#  ('Esslingen', {'business': 29, 'user': 563}),
#  ('Unionville', {'business': 10, 'user': 554}),
#  ('Streetsboro', {'business': 15, 'user': 548}),
#  ('El Mirage', {'business': 6, 'user': 541}),
#  ('York', {'business': 8, 'user': 540}),
#  ('Brunswick', {'business': 21, 'user': 539}),
#  ('Dorval', {'business': 9, 'user': 527}),
#  ('South Las Vegas', {'business': 3, 'user': 519}),
#  ('West Mifflin', {'business': 13, 'user': 517}),
#  ('Valley View', {'business': 8, 'user': 515}),
#  ('Sewickley', {'business': 13, 'user': 515}),
#  ('Ahwatukee', {'business': 5, 'user': 509}),
#  ('North Royalton', {'business': 22, 'user': 506}),
#  ('Elyria', {'business': 24, 'user': 502}),
#  ('Brecksville', {'business': 8, 'user': 495}),
#  ('Brooklyn', {'business': 11, 'user': 494}),
#  ('las vegas', {'business': 0, 'user': 473}),
#  ('McMurray', {'business': 13, 'user': 473}),
#  ('Harrisburg', {'business': 16, 'user': 469}),
#  ('Macedonia', {'business': 12, 'user': 462}),
#  ('Highland Heights', {'business': 6, 'user': 462}),
#  ('University Heights', {'business': 7, 'user': 458}),
#  ('Northfield', {'business': 10, 'user': 451}),
#  ('Kannapolis', {'business': 14, 'user': 451}),
#  ('Inverness', {'business': 30, 'user': 447}),
#  ('San Tan Valley', {'business': 4, 'user': 444}),
#  ('Frazer', {'business': 6, 'user': 442}),
#  ('Savoy', {'business': 6, 'user': 441}),
#  ('Painesville', {'business': 18, 'user': 439}),
#  ('Verdun', {'business': 9, 'user': 439}),
#  ('Fellbach', {'business': 27, 'user': 437}),
#  ('Saint-Laurent', {'business': 9, 'user': 435}),
#  ('South Euclid', {'business': 10, 'user': 413}),
#  ('Murrysville', {'business': 11, 'user': 412}),
#  ('Leinfelden-Echterdingen', {'business': 13, 'user': 405}),
#  ('Bedford', {'business': 9, 'user': 399}),
#  ('Gibsonia', {'business': 11, 'user': 390}),
#  ('Allison Park', {'business': 11, 'user': 389}),
#  ('Brossard', {'business': 13, 'user': 378}),
#  ('West Homestead', {'business': 5, 'user': 377}),
#  ('Amherst', {'business': 13, 'user': 373}),
#  ('Chesterland', {'business': 8, 'user': 364}),
#  ('Shaker Heights', {'business': 9, 'user': 362}),
#  ('Moon Township', {'business': 6, 'user': 360}),
#  ('Sun City West', {'business': 5, 'user': 353}),
#  ('North Ridgeville', {'business': 8, 'user': 353}),
#  ('Paradise', {'business': 1, 'user': 346}),
#  ('Westmount', {'business': 12, 'user': 343}),
#  ('Euclid', {'business': 13, 'user': 337}),
#  ('Irwin', {'business': 21, 'user': 328}),
#  ('Mount Horeb', {'business': 6, 'user': 325}),
#  ('Mint Hill', {'business': 9, 'user': 323}),
#  ('Pointe-Claire', {'business': 19, 'user': 321}),
#  ('Stoughton', {'business': 13, 'user': 320}),
#  ('Oakmont', {'business': 9, 'user': 314}),
#  ('Olmsted Falls', {'business': 9, 'user': 310}),
#  ('Peninsula', {'business': 4, 'user': 306}),
#  ('Filderstadt', {'business': 9, 'user': 305}),
#  ('Parma Heights', {'business': 8, 'user': 303}),
#  ('Lake Wylie', {'business': 6, 'user': 301}),
#  ('Warrensville Heights', {'business': 6, 'user': 300}),
#  ('Richfield', {'business': 7, 'user': 298}),
#  ('Outremont', {'business': 6, 'user': 288}),
#  ('Lorain', {'business': 11, 'user': 284}),
#  ('Youngtown', {'business': 5, 'user': 282}),
#  ('New Kensington', {'business': 11, 'user': 279}),
#  ('Eastlake', {'business': 11, 'user': 277}),
#  ('Tallmadge', {'business': 6, 'user': 276}),
#  ('Willoughby Hills', {'business': 10, 'user': 273}),
#  ('Seven Hills', {'business': 6, 'user': 264}),
#  ('Blue Diamond', {'business': 2, 'user': 260}),
#  ('Robinson Township', {'business': 7, 'user': 259}),
#  ('Dollard-Des-Ormeaux', {'business': 10, 'user': 258}),
#  ('Tega Cay', {'business': 6, 'user': 257}),
#  ('Brook Park', {'business': 10, 'user': 251}),
#  ('Stallings', {'business': 4, 'user': 247}),
#  ('Waunakee', {'business': 11, 'user': 246}),
#  ('Guadalupe', {'business': 2, 'user': 246}),
#  ('Orange Village', {'business': 2, 'user': 242}),
#  ('Spring Valley', {'business': 1, 'user': 241}),
#  ('Chardon', {'business': 9, 'user': 233}),
#  ('Scottdale', {'business': 2, 'user': 233}),
#  ('Indian Land', {'business': 5, 'user': 233}),
#  ('Mount Lebanon', {'business': 3, 'user': 232}),
#  ('Pepper Pike', {'business': 1, 'user': 230}),
#  ('Oregon', {'business': 10, 'user': 228}),
#  ('Willowick', {'business': 7, 'user': 228}),
#  ('North Huntingdon', {'business': 7, 'user': 223}),
#  ('Bay Village', {'business': 6, 'user': 221}),
#  ('Missisauga', {'business': 3, 'user': 218}),
#  ('Waiblingen', {'business': 10, 'user': 213}),
#  ('Bellevue', {'business': 4, 'user': 212}),
#  ('Fort McDowell', {'business': 1, 'user': 211}),
#  ('McKees Rocks', {'business': 13, 'user': 211}),
#  ('Las vegas', {'business': 1, 'user': 210}),
#  ('Pleasant Hills', {'business': 9, 'user': 205}),
#  ('Tremont', {'business': 1, 'user': 204}),
#  ('Whitchurch-Stouffville', {'business': 5, 'user': 202}),
#  ('Maple', {'business': 7, 'user': 201}),
#  ('Las  Vegas', {'business': 2, 'user': 200}),
#  ('Leonberg', {'business': 13, 'user': 197}),
#  ('Mt. Lebanon', {'business': 2, 'user': 189}),
#  ('Woodmere Village', {'business': 1, 'user': 182}),
#  ('Lower Lawrenceville', {'business': 1, 'user': 181}),
#  ('Wickliffe', {'business': 6, 'user': 177}),
#  ('Mc Kees Rocks', {'business': 5, 'user': 177}),
#  ('Ostfildern', {'business': 18, 'user': 176}),
#  ('Glenshaw', {'business': 7, 'user': 176}),
#  ('San Rafael', {'business': 0, 'user': 175}),
#  ('Copley', {'business': 5, 'user': 173}),
#  ('Clark', {'business': 0, 'user': 172}),
#  ('N. Las Vegas', {'business': 2, 'user': 172}),
#  ('Richmond Heights', {'business': 5, 'user': 169}),
#  ('Lasalle', {'business': 5, 'user': 168}),
#  ('Higley', {'business': 4, 'user': 166}),
#  ('Cramerton', {'business': 5, 'user': 162}),
#  ('Dollard-des-Ormeaux', {'business': 2, 'user': 161}),
#  ('Mahomet', {'business': 8, 'user': 159}),
#  ('Enterprise', {'business': 1, 'user': 158}),
#  ('McKeesport', {'business': 10, 'user': 157}),
#  ('Mc Farland', {'business': 5, 'user': 153}),
#  ('Wesley Chapel', {'business': 4, 'user': 149}),
#  ('Moreland Hills', {'business': 2, 'user': 148}),
#  ('Longueuil', {'business': 2, 'user': 147}),
#  ('Cottage Grove', {'business': 5, 'user': 146}),
#  ('Garfield Heights', {'business': 6, 'user': 146}),
#  ('North Versailles', {'business': 12, 'user': 142}),
#  ('Stouffville', {'business': 9, 'user': 142}),
#  ('Mount Holly', {'business': 7, 'user': 140}),
#  ('N Las Vegas', {'business': 0, 'user': 137}),
#  ('Ambridge', {'business': 8, 'user': 136}),
#  ('DeForest', {'business': 5, 'user': 134}),
#  ('Cross Plains', {'business': 6, 'user': 134}),
#  ('Oakdale', {'business': 7, 'user': 134}),
#  ('De Forest', {'business': 7, 'user': 133}),
#  ('Sheffield Village', {'business': 5, 'user': 133}),
#  ('Mayfield Village', {'business': 2, 'user': 132}),
#  ('Middlefield', {'business': 7, 'user': 130}),
#  ('Aspinwall', {'business': 1, 'user': 128}),
#  ('North Scottsdale', {'business': 1, 'user': 127}),
#  ('Kornwestheim', {'business': 9, 'user': 126}),
#  ('Sun Lakes', {'business': 1, 'user': 125}),
#  ('Fairview', {'business': 6, 'user': 124}),
#  ('Grand River', {'business': 2, 'user': 124}),
#  ('Pierrefonds', {'business': 4, 'user': 124}),
#  ('Robinson', {'business': 0, 'user': 122}),
#  ('Ross Township', {'business': 3, 'user': 121}),
#  ('Burton', {'business': 4, 'user': 119}),
#  ('WICKLIFFE', {'business': 5, 'user': 119}),
#  ('Munhall', {'business': 4, 'user': 118}),
#  ('Rantoul', {'business': 5, 'user': 117}),
#  ('Kirtland', {'business': 6, 'user': 117}),
#  ('Concord Mills', {'business': 2, 'user': 117}),
#  ('Esslingen am Neckar', {'business': 5, 'user': 116}),
#  ('Tuscola', {'business': 5, 'user': 115}),
#  ('McFarland', {'business': 5, 'user': 112}),
#  ('White Oak', {'business': 8, 'user': 111}),
#  ('Georgetown', {'business': 10, 'user': 110}),
#  ('Leetsdale', {'business': 2, 'user': 110}),
#  ('Springdale', {'business': 2, 'user': 108}),
#  ('Windsor', {'business': 0, 'user': 108}),
#  ('Gerlingen', {'business': 13, 'user': 107}),
#  ('Monticello', {'business': 7, 'user': 107}),
#  ('Waddell', {'business': 0, 'user': 104}),
#  ('Livingston', {'business': 6, 'user': 103}),
#  ('Saint-Leonard', {'business': 3, 'user': 102}),
#  ('Mayfield', {'business': 1, 'user': 101}),
#  ('Ditzingen', {'business': 5, 'user': 99}),
#  ('Pheonix', {'business': 1, 'user': 99}),
#  ('Saint-Sauveur', {'business': 11, 'user': 97}),
#  ('Rexdale', {'business': 3, 'user': 96}),
#  ('Lachine', {'business': 5, 'user': 94}),
#  ('Cecil', {'business': 1, 'user': 94}),
#  ('Belleville', {'business': 6, 'user': 93}),
#  ('Vaudreuil-Dorion', {'business': 2, 'user': 93}),
#  ('Plum', {'business': 3, 'user': 91}),
#  ('Lowell', {'business': 4, 'user': 90}),
#  ('Valley City', {'business': 5, 'user': 90}),
#  ('Dunfermline', {'business': 10, 'user': 88}),
#  ('Mont-Royal', {'business': 4, 'user': 87}),
#  ('Mentor-on-the-Lake', {'business': 5, 'user': 86}),
#  ('Bolton', {'business': 6, 'user': 84}),
#  ('Bedford Heights', {'business': 5, 'user': 84}),
#  ('Kirkland', {'business': 5, 'user': 80}),
#  ('Nottingham', {'business': 0, 'user': 80}),
#  ('Sharpsburg', {'business': 0, 'user': 79}),
#  ('Maple Heights', {'business': 5, 'user': 79}),
#  ('Brookpark', {'business': 1, 'user': 79}),
#  ('Newbury', {'business': 5, 'user': 78}),
#  ('Musselburgh', {'business': 2, 'user': 78}),
#  ("L'Île-Perrot", {'business': 2, 'user': 77}),
#  ('Braddock', {'business': 6, 'user': 76}),
#  ('Caledon', {'business': 4, 'user': 75}),
#  ('Penn Hills', {'business': 4, 'user': 75}),
#  ('Dallas', {'business': 5, 'user': 74}),
#  ('Clairton', {'business': 2, 'user': 72}),
#  ('East Gwillimbury', {'business': 6, 'user': 71}),
#  ('McCandless Township', {'business': 1, 'user': 71}),
#  ('Etna', {'business': 3, 'user': 70}),
#  ('Upper St Clair', {'business': 1, 'user': 70}),
#  ('Olivos', {'business': 8, 'user': 70}),
#  ('Turtle Creek', {'business': 4, 'user': 70}),
#  ('Imperial', {'business': 3, 'user': 69}),
#  ('Boucherville', {'business': 6, 'user': 69}),
#  ('King City', {'business': 5, 'user': 68}),
#  ('West View', {'business': 1, 'user': 67}),
#  ('Hemmingen', {'business': 4, 'user': 66}),
#  ('Leith', {'business': 2, 'user': 66}),
#  ('Bradford', {'business': 6, 'user': 66}),
#  ('Crafton', {'business': 2, 'user': 64}),
#  ('Elizabeth', {'business': 6, 'user': 64}),
#  ('Green Tree', {'business': 0, 'user': 64}),
#  ('Bainbridge', {'business': 3, 'user': 62}),
#  ('Montrose', {'business': 1, 'user': 62}),
#  ('Dormont', {'business': 0, 'user': 62}),
#  ('West Akron', {'business': 1, 'user': 61}),
#  ('Don Mills', {'business': 1, 'user': 60}),
#  ('Stowe', {'business': 2, 'user': 59}),
#  ('Munroe Falls', {'business': 3, 'user': 58}),
#  ('South Queensferry', {'business': 3, 'user': 58}),
#  ('South Park Township', {'business': 1, 'user': 58}),
#  ('Monongahela', {'business': 5, 'user': 57}),
#  ('Oakland', {'business': 2, 'user': 56}),
#  ('Finleyville', {'business': 2, 'user': 56}),
#  ('Columbia Station', {'business': 3, 'user': 55}),
#  ('Fairport Harbor', {'business': 4, 'user': 55}),
#  ('Port Credit', {'business': 0, 'user': 55}),
#  ('Hampton Township', {'business': 3, 'user': 55}),
#  ('Black Earth', {'business': 0, 'user': 55}),
#  ('North Randall', {'business': 2, 'user': 54}),
#  ('Summerlin', {'business': 0, 'user': 53}),
#  ('Mc Murray', {'business': 1, 'user': 53}),
#  ('Sheffield', {'business': 2, 'user': 53}),
#  ('Nellis AFB', {'business': 1, 'user': 53}),
#  ('Robinson Twp.', {'business': 1, 'user': 52}),
#  ('Hinckley', {'business': 1, 'user': 52}),
#  ('Neuhausen', {'business': 5, 'user': 52}),
#  ('Avalon', {'business': 2, 'user': 52}),
#  ('Mt Lebanon', {'business': 0, 'user': 51}),
#  ('Shadyside', {'business': 0, 'user': 51}),
#  ('Schönaich', {'business': 2, 'user': 51}),
#  ('Houston', {'business': 3, 'user': 50}),
#  ('Saint-Hubert', {'business': 4, 'user': 50}),
#  ('Brookline', {'business': 0, 'user': 49}),
#  ('Cheswick', {'business': 2, 'user': 48}),
#  ('Millvale', {'business': 4, 'user': 48}),
#  ('Stanley', {'business': 2, 'user': 48}),
#  ('Anjou', {'business': 4, 'user': 47}),
#  ('Nellis Afb', {'business': 2, 'user': 47}),
#  ('La Prairie', {'business': 2, 'user': 46}),
#  ('Midlothian', {'business': 0, 'user': 46}),
#  ('South Park', {'business': 1, 'user': 45}),
#  ('Greenfield Park', {'business': 4, 'user': 45}),
#  ('Arnold', {'business': 0, 'user': 45}),
#  ('Saint-Lambert', {'business': 3, 'user': 45}),
#  ('W Henderson', {'business': 0, 'user': 44}),
#  ('Saint-Jean-sur-Richelieu', {'business': 7, 'user': 43}),
#  ('Trafford', {'business': 4, 'user': 43}),
#  ('Glendale Az', {'business': 1, 'user': 43}),
#  ('Castle Shannon', {'business': 0, 'user': 43}),
#  ('Midland', {'business': 3, 'user': 43}),
#  ('New Town', {'business': 4, 'user': 43}),
#  ('St Davids', {'business': 0, 'user': 43}),
#  ('Ft. Mill', {'business': 1, 'user': 43}),
#  ('Emsworth', {'business': 3, 'user': 42}),
#  ('Downtown', {'business': 1, 'user': 42}),
#  ('Presto', {'business': 1, 'user': 42}),
#  ('Korntal-Münchingen', {'business': 2, 'user': 41}),
#  ('Brentwood', {'business': 3, 'user': 41}),
#  ('Vieux Montreal', {'business': 0, 'user': 41}),
#  ('Elk Grove Villa', {'business': 0, 'user': 40}),
#  ('Mantua', {'business': 1, 'user': 40}),
#  ('Brooklin', {'business': 1, 'user': 39}),
#  ('Mint  Hill', {'business': 0, 'user': 39}),
#  ('Bradford West Gwillimbury', {'business': 2, 'user': 39}),
#  ('Paoli', {'business': 1, 'user': 38}),
#  ('Lower Burrell', {'business': 1, 'user': 38}),
#  ('Gates Mills', {'business': 1, 'user': 38}),
#  ('Harrison City', {'business': 2, 'user': 38}),
#  ('Remseck', {'business': 0, 'user': 38}),
#  ('Sainte-Anne-De-Bellevue', {'business': 2, 'user': 38}),
#  ('Chambly', {'business': 3, 'user': 38}),
#  ('Sheffield Lake', {'business': 2, 'user': 37}),
#  ('Kleinburg', {'business': 2, 'user': 37}),
#  ('Wilmerding', {'business': 3, 'user': 37}),
#  ('Weddington', {'business': 1, 'user': 37}),
#  ('Montreal-Ouest', {'business': 1, 'user': 36}),
#  ('Freyburg', {'business': 3, 'user': 36}),
#  ('Peters Township', {'business': 1, 'user': 36}),
#  ('toronto', {'business': 1, 'user': 35}),
#  ('Moon', {'business': 4, 'user': 35}),
#  ('Kernen', {'business': 1, 'user': 35}),
#  ('Newhaven', {'business': 0, 'user': 35}),
#  ('Walton Hills', {'business': 0, 'user': 34}),
#  ('Richmond Hil', {'business': 1, 'user': 34}),
#  ('Bath', {'business': 0, 'user': 34}),
#  ('Penicuik', {'business': 3, 'user': 34}),
#  ('Schwieberdingen', {'business': 1, 'user': 34}),
#  ('Wilkins Township', {'business': 1, 'user': 34}),
#  ('W Spring Valley', {'business': 0, 'user': 33}),
#  ('St-Benoît de Mirabel', {'business': 1, 'user': 33}),
#  ('Roosevelt', {'business': 4, 'user': 33}),
#  ('Kirkcaldy', {'business': 1, 'user': 33}),
#  ('Bratenahl', {'business': 2, 'user': 32}),
#  ('chandler', {'business': 1, 'user': 32}),
#  ('Scaroborough', {'business': 1, 'user': 32}),
#  ('Dalkeith', {'business': 2, 'user': 32}),
#  ('Stockbridge', {'business': 1, 'user': 31}),
#  ('Lasswade', {'business': 2, 'user': 31}),
#  ('N. Olmsted', {'business': 0, 'user': 31}),
#  ('Bernhausen', {'business': 1, 'user': 31}),
#  ('Newbridge', {'business': 0, 'user': 31}),
#  ('Rouses Point', {'business': 3, 'user': 30}),
#  ('Saint Joseph', {'business': 5, 'user': 30}),
#  ('Beaconsfield', {'business': 2, 'user': 30}),
#  ('N W Las Vegas', {'business': 0, 'user': 29}),
#  ('Shorewood Hills', {'business': 0, 'user': 29}),
#  ('Grafton', {'business': 3, 'user': 29}),
#  ('Heidelberg', {'business': 2, 'user': 29}),
#  ('Denkendorf', {'business': 1, 'user': 29}),
#  ('Swissvale', {'business': 0, 'user': 28}),
#  ('columbia station', {'business': 2, 'user': 28}),
#  ('East Liberty', {'business': 0, 'user': 28}),
#  ('Ben Avon', {'business': 1, 'user': 28}),
#  ('Dravosburg', {'business': 1, 'user': 28}),
#  ('Sainte-Anne-de-Bellevue', {'business': 4, 'user': 27}),
#  ('Champlain', {'business': 1, 'user': 27}),
#  ('North Queensferry', {'business': 0, 'user': 27}),
#  ('Glenrothes', {'business': 3, 'user': 26}),
#  ('Medina Township', {'business': 2, 'user': 26}),
#  ('Jefferson Hills', {'business': 1, 'user': 26}),
#  ('Chateauguay', {'business': 3, 'user': 26}),
#  ('Boisbriand', {'business': 7, 'user': 25}),
#  ('nboulder city', {'business': 0, 'user': 25}),
#  ('Central City Village', {'business': 0, 'user': 25}),
#  ('McAdenville', {'business': 0, 'user': 25}),
#  ('Loanhead', {'business': 0, 'user': 25}),
#  ('Saint-Eustache', {'business': 3, 'user': 25}),
#  ('Warrensville Hts.', {'business': 1, 'user': 25}),
#  ('Wilkinsburg', {'business': 2, 'user': 25}),
#  ('Rosemere', {'business': 0, 'user': 25}),
#  ('CITY CENTER', {'business': 0, 'user': 25}),
#  ('Queensferry', {'business': 1, 'user': 24}),
#  ('Saint-Jerome', {'business': 2, 'user': 24}),
#  ('Île des Soeurs', {'business': 0, 'user': 24}),
#  ('Delson', {'business': 2, 'user': 24}),
#  ('Gormley', {'business': 0, 'user': 23}),
#  ('Litchfield', {'business': 1, 'user': 23}),
#  ('Henderston', {'business': 0, 'user': 23}),
#  ('Venetia', {'business': 1, 'user': 23}),
#  ('Steinenbronn', {'business': 4, 'user': 23}),
#  ('Central Henderson', {'business': 0, 'user': 23}),
#  ('Mentor On the Lake', {'business': 0, 'user': 23}),
#  ('Centennial Hills', {'business': 0, 'user': 23}),
#  ('Middleburg Hts', {'business': 0, 'user': 22}),
#  ('Möglingen', {'business': 0, 'user': 22}),
#  ('Olmsted Township', {'business': 1, 'user': 22}),
#  ('Caledon East', {'business': 2, 'user': 22}),
#  ('York Regional Municipality', {'business': 0, 'user': 22}),
#  ('Oakwood Village', {'business': 0, 'user': 22}),
#  ('Pittsburg', {'business': 0, 'user': 22}),
#  ('Willowdale', {'business': 2, 'user': 22}),
#  ('Mount Albert', {'business': 2, 'user': 21}),
#  ('Montreal-Nord', {'business': 1, 'user': 21}),
#  ('Saint Laurent', {'business': 1, 'user': 21}),
#  ('East Pittsburgh', {'business': 1, 'user': 21}),
#  ('C Las Vegas', {'business': 0, 'user': 20}),
#  ('McDonald', {'business': 0, 'user': 20}),
#  ('Library', {'business': 1, 'user': 20}),
#  ('Gullane', {'business': 0, 'user': 20}),
#  ("L'ile-Perrot", {'business': 1, 'user': 20}),
#  ('Squirrel Hill', {'business': 0, 'user': 20}),
#  ('Rosemère', {'business': 1, 'user': 19}),
#  ('Harmarville', {'business': 1, 'user': 19}),
#  ('Neville Island', {'business': 0, 'user': 19}),
#  ('Lagrange', {'business': 1, 'user': 19}),
#  ('Topaz', {'business': 0, 'user': 19}),
#  ('Cleveland Hghts.', {'business': 1, 'user': 19}),
#  ('Downsview', {'business': 0, 'user': 19}),
#  ('Kernen im Remstal', {'business': 2, 'user': 18}),
#  ('Firth of Forth', {'business': 0, 'user': 18}),
#  ('Terrebonne', {'business': 2, 'user': 18}),
#  ('Bellvue', {'business': 0, 'user': 18}),
#  ('Forest Hills', {'business': 2, 'user': 18}),
#  ('King', {'business': 3, 'user': 18}),
#  ('Mentor On the', {'business': 0, 'user': 18}),
#  ('Baldwin', {'business': 2, 'user': 18}),
#  ('mesa', {'business': 0, 'user': 18}),
#  ('clinton', {'business': 1, 'user': 18}),
#  ('McKnight', {'business': 0, 'user': 17}),
#  ('Ratho', {'business': 1, 'user': 17}),
#  ('Montréal-Nord', {'business': 0, 'user': 17}),
#  ('Old Town', {'business': 3, 'user': 17}),
#  ('Mont-Saint-Hilaire', {'business': 2, 'user': 17}),
#  ('North Toronto', {'business': 1, 'user': 17}),
#  ('Remseck am Neckar', {'business': 1, 'user': 17}),
#  ('Ogden', {'business': 0, 'user': 16}),
#  ('Nobleton', {'business': 1, 'user': 16}),
#  ('Orange', {'business': 1, 'user': 16}),
#  ('Dollard-Des Ormeaux', {'business': 1, 'user': 16}),
#  ('Edgewood', {'business': 1, 'user': 16}),
#  ('Cuyahoga Heights', {'business': 0, 'user': 16}),
#  ('Clinton', {'business': 0, 'user': 16}),
#  ('Rigaud', {'business': 2, 'user': 16}),
#  ('Henderson (Green Valley)', {'business': 0, 'user': 15}),
#  ('Las Vegas East', {'business': 0, 'user': 15}),
#  ('Russellton', {'business': 1, 'user': 15}),
#  ('Vimont', {'business': 0, 'user': 15}),
#  ('Saint-Bernard-De-Lacolle', {'business': 0, 'user': 15}),
#  ('Schomberg', {'business': 4, 'user': 15}),
#  ('Ste-Rose', {'business': 0, 'user': 15}),
#  ('Laveen Village', {'business': 3, 'user': 15}),
#  ('North Huntington', {'business': 0, 'user': 15}),
#  ('Philo', {'business': 0, 'user': 15}),
#  ('NORTH YORK', {'business': 1, 'user': 15}),
#  ('Saint-Hyacinthe', {'business': 2, 'user': 15}),
#  ('Mont-Saint-Gregoire', {'business': 2, 'user': 15}),
#  ('Streetsville', {'business': 1, 'user': 15}),
#  ('Promenade', {'business': 0, 'user': 14}),
#  ('Upper St. Clair', {'business': 0, 'user': 14}),
#  ('Green Valley', {'business': 1, 'user': 14}),
#  ('Sagamore Hills', {'business': 1, 'user': 14}),
#  ('Mount Washington', {'business': 0, 'user': 14}),
#  ('Richmond Hts', {'business': 1, 'user': 14}),
#  ('Sainte-Julie', {'business': 3, 'user': 14}),
#  ('Hiram', {'business': 0, 'user': 14}),
#  ('Blawnox', {'business': 2, 'user': 13}),
#  ('Elizabeth Township', {'business': 1, 'user': 13}),
#  ('Moon Twp', {'business': 0, 'user': 13}),
#  ('Beloeil', {'business': 2, 'user': 13}),
#  ('Châteauguay', {'business': 2, 'user': 13}),
#  ('Shaler Township', {'business': 1, 'user': 13}),
#  ('Moss', {'business': 1, 'user': 13}),
#  ('Saint-Lazare', {'business': 2, 'user': 13}),
#  ('Le Sud-Ouest', {'business': 0, 'user': 12}),
#  ('Meza', {'business': 0, 'user': 12}),
#  ('New Eagle', {'business': 1, 'user': 12}),
#  ('frazer', {'business': 0, 'user': 12}),
#  ('Sunrise', {'business': 0, 'user': 12}),
#  ('Leinfelden', {'business': 0, 'user': 12}),
#  ('Mascouche', {'business': 0, 'user': 12}),
#  ('Mayfield Heights (Cleveland)', {'business': 0, 'user': 12}),
#  ('Blainville', {'business': 0, 'user': 12}),
#  ('Northfield Center', {'business': 0, 'user': 12}),
#  ('Bedford HTS', {'business': 0, 'user': 12}),
#  ('East Cleveland', {'business': 1, 'user': 12}),
#  ('Dane', {'business': 1, 'user': 12}),
#  ('Saint-Jérôme', {'business': 0, 'user': 12}),
#  ('Wildwood', {'business': 0, 'user': 12}),
#  ('Phoenix, AZ', {'business': 0, 'user': 12}),
#  ('Cote-Saint-Luc', {'business': 1, 'user': 12}),
#  ('Saint-Constant', {'business': 1, 'user': 12}),
#  ('Hochdorf', {'business': 2, 'user': 11}),
#  ('Summerlin South', {'business': 0, 'user': 11}),
#  ('Ahwahtukee', {'business': 0, 'user': 11}),
#  ('Fullerton', {'business': 0, 'user': 11}),
#  ('Morin-Heights', {'business': 0, 'user': 11}),
#  ('Haddington', {'business': 1, 'user': 11}),
#  ('Mercier', {'business': 0, 'user': 11}),
#  ('Toronto, Ontario', {'business': 0, 'user': 11}),
#  ('N. OLMSTED', {'business': 0, 'user': 11}),
#  ('Phoenix,', {'business': 0, 'user': 11}),
#  ('Beeton', {'business': 0, 'user': 11}),
#  ('Oka', {'business': 0, 'user': 11}),
#  ('Nord', {'business': 0, 'user': 11}),
#  ('', {'business': 0, 'user': 10}),
#  ('Sainte-Therese', {'business': 4, 'user': 10}),
#  ('Charlotte (University)', {'business': 0, 'user': 10}),
#  ('Sainte-Adele', {'business': 1, 'user': 10}),
#  ('McCandless', {'business': 1, 'user': 10}),
#  ("L'Île-Bizard", {'business': 0, 'user': 10}),
#  ('Quartermile', {'business': 1, 'user': 10}),
#  ('Mirabel', {'business': 1, 'user': 10}),
#  ('Blackness', {'business': 0, 'user': 10}),
#  ('Kennedy Township', {'business': 1, 'user': 10}),
#  ('Saint-Henri', {'business': 1, 'user': 10}),
#  ('Stoney Creek', {'business': 1, 'user': 10}),
#  ('Glassport', {'business': 0, 'user': 10}),
#  ('Median', {'business': 0, 'user': 10}),
#  ('Newington', {'business': 0, 'user': 10}),
#  ('Lowesville', {'business': 0, 'user': 10}),
#  ('East Mc Keesport', {'business': 1, 'user': 10}),
#  ('Bathurst Quay', {'business': 1, 'user': 10}),
#  ('North Olmstead', {'business': 2, 'user': 10}),
#  ('Elrama', {'business': 1, 'user': 10}),
#  ('Cote Saint-Luc', {'business': 0, 'user': 10}),
#  ('Communauté-Urbaine-de-Montréal', {'business': 0, 'user': 10}),
#  ('La Baie', {'business': 0, 'user': 9}),
#  ('Kahnawake', {'business': 2, 'user': 9}),
#  ('SCOTTSDALE AZ', {'business': 0, 'user': 9}),
#  ('Piedmont', {'business': 0, 'user': 9}),
#  ('Pencaitland', {'business': 0, 'user': 9}),
#  ('Bonnyrigg', {'business': 1, 'user': 9}),
#  ('Gelndale', {'business': 1, 'user': 9}),
#  ('Juniper Green', {'business': 0, 'user': 9}),
#  ("Notre-Dame-De-L'ile-Perrot", {'business': 0, 'user': 9}),
#  ('Schwaikheim', {'business': 1, 'user': 9}),
#  ('Brimfield', {'business': 1, 'user': 9}),
#  ('Gifford', {'business': 1, 'user': 9}),
#  ('Sidney', {'business': 0, 'user': 9}),
#  ('Repentigny', {'business': 0, 'user': 9}),
#  ('Mt. Horeb', {'business': 0, 'user': 9}),
#  ('North of Brampton', {'business': 0, 'user': 9}),
#  ('LaSalle', {'business': 1, 'user': 9}),
#  ('Novelty', {'business': 0, 'user': 9}),
#  ('Sainte-Adèle', {'business': 1, 'user': 9}),
#  ('Churubusco', {'business': 0, 'user': 9}),
#  ('Montéal', {'business': 1, 'user': 8}),
#  ('N Ridgeville', {'business': 0, 'user': 8}),
#  ('Auburn Township', {'business': 0, 'user': 8}),
#  ('Glasgow', {'business': 0, 'user': 8}),
#  ('Phoneix', {'business': 0, 'user': 8}),
#  ('City of Edinburgh', {'business': 2, 'user': 8}),
#  ('Indian land', {'business': 1, 'user': 8}),
#  ('East McKeesport', {'business': 1, 'user': 8}),
#  ('Roslin', {'business': 0, 'user': 8}),
#  ('Salaberry-De-Valleyfield', {'business': 1, 'user': 8}),
#  ('Prestonpans', {'business': 0, 'user': 8}),
#  ('Goodwood', {'business': 1, 'user': 8}),
#  ('Sainte-Genevieve', {'business': 1, 'user': 8}),
#  ('Regional Municipality of York', {'business': 0, 'user': 8}),
#  ('Sunnyslope', {'business': 0, 'user': 8}),
#  ('Inverkeithing', {'business': 0, 'user': 8}),
#  ('Scarobrough', {'business': 1, 'user': 8}),
#  ('Gorebridge', {'business': 0, 'user': 8}),
#  ('Creighton', {'business': 0, 'user': 8}),
#  ('Henderson and Las vegas', {'business': 0, 'user': 8}),
#  ('Mc Donald', {'business': 0, 'user': 8}),
#  ('MC Murray', {'business': 0, 'user': 8}),
#  ('Kirknewton', {'business': 0, 'user': 8}),
#  ('Clarkson', {'business': 1, 'user': 8}),
#  ('Chandler-Gilbert', {'business': 0, 'user': 8}),
#  ('N E Las Vegas', {'business': 0, 'user': 8}),
#  ('Franklin Park', {'business': 0, 'user': 8}),
#  ('Pointe-Aux-Trembles', {'business': 0, 'user': 7}),
#  ('Buckeye - Shaker', {'business': 0, 'user': 7}),
#  ('Saint-Jean-Sur-Richelieu', {'business': 1, 'user': 7}),
#  ('Scott Township', {'business': 0, 'user': 7}),
#  ('East Mississauga', {'business': 0, 'user': 7}),
#  ('Fountainbridge', {'business': 0, 'user': 7}),
#  ('Bainbridge Township', {'business': 1, 'user': 7}),
#  ('Stuttgart-Vaihingen', {'business': 0, 'user': 7}),
#  ('Vanier', {'business': 0, 'user': 7}),
#  ('Whiitby', {'business': 1, 'user': 7}),
#  ('Saint-Philippe', {'business': 0, 'user': 7}),
#  ('Sainte-Thérèse', {'business': 0, 'user': 7}),
#  ('110 Las Vegas', {'business': 0, 'user': 7}),
#  ('Bedford Hts.', {'business': 0, 'user': 7}),
#  ('Las Vegas, NV', {'business': 0, 'user': 7}),
#  ('Berg', {'business': 0, 'user': 7}),
#  ('Water of Leith', {'business': 0, 'user': 7}),
#  ('Hendersonville', {'business': 0, 'user': 7}),
#  ('Lachute', {'business': 1, 'user': 7}),
#  ('Thornhil', {'business': 1, 'user': 7}),
#  ('Stowe Township', {'business': 0, 'user': 7}),
#  ('Cramond', {'business': 0, 'user': 7}),
#  ('Rawdon', {'business': 1, 'user': 7}),
#  ('University Hts ', {'business': 0, 'user': 7}),
#  ('Joliette', {'business': 2, 'user': 7}),
#  ('East Lothian', {'business': 0, 'user': 7}),
#  ('Desert Ridge', {'business': 0, 'user': 7}),
#  ('Regent Square', {'business': 0, 'user': 7}),
#  ('Burntisland', {'business': 0, 'user': 6}),
#  ('Lake Park', {'business': 1, 'user': 6}),
#  ('St Leonard', {'business': 0, 'user': 6}),
#  ('Sun City Anthem', {'business': 0, 'user': 6}),
#  ('Brooklyn Hts.', {'business': 0, 'user': 6}),
#  ('South Gyle', {'business': 0, 'user': 6}),
#  ('Pine', {'business': 0, 'user': 6}),
#  ('Monoroeville', {'business': 0, 'user': 6}),
#  ('Middleburg Hts.', {'business': 0, 'user': 6}),
#  ('Robinson Town', {'business': 0, 'user': 6}),
#  ('Westworld Scottsdale', {'business': 0, 'user': 6}),
#  ('Lawrence', {'business': 1, 'user': 6}),
#  ('Bradfordwoods', {'business': 0, 'user': 6}),
#  ('Murrysville (Monroeville)', {'business': 0, 'user': 6}),
#  ('Mattews', {'business': 0, 'user': 6}),
#  ('Warrensvile Heights', {'business': 1, 'user': 6}),
#  ('Estérel', {'business': 1, 'user': 6}),
#  ('Mt Albert', {'business': 0, 'user': 6}),
#  ('Dudley', {'business': 1, 'user': 6}),
#  ('Saint-Sauveur-des-Monts', {'business': 1, 'user': 6}),
#  ('Leven', {'business': 0, 'user': 6}),
#  ('Plieningen', {'business': 0, 'user': 6}),
#  ('Pitcairn', {'business': 0, 'user': 6}),
#  ('Upper Saint Clair', {'business': 3, 'user': 6}),
#  ('Homer', {'business': 2, 'user': 6}),
#  ('Thorncliffe Park', {'business': 1, 'user': 6}),
#  ('Saint-Bruno-de-Montarville', {'business': 0, 'user': 6}),
#  ('Roxboro', {'business': 0, 'user': 6}),
#  ('Ballantyne', {'business': 0, 'user': 6}),
#  ('Mcmurray', {'business': 0, 'user': 6}),
#  ('S Concord', {'business': 0, 'user': 6}),
#  ('Sindelfingen/Eichholz', {'business': 0, 'user': 5}),
#  ('Candiac', {'business': 0, 'user': 5}),
#  ('Mississuaga', {'business': 0, 'user': 5}),
#  ('Saint-Antoine', {'business': 0, 'user': 5}),
#  ('Tranent', {'business': 0, 'user': 5}),
#  ('Sainte-Catherine', {'business': 1, 'user': 5}),
#  ('Bruntsfield', {'business': 0, 'user': 5}),
#  ('Saint-Bernard-de-Lacolle', {'business': 0, 'user': 5}),
#  ('McMurry', {'business': 0, 'user': 5}),
#  ('Strongville', {'business': 0, 'user': 5}),
#  ('Lingen', {'business': 0, 'user': 5}),
#  ('Liberty', {'business': 0, 'user': 5}),
#  ('Tolono', {'business': 0, 'user': 5}),
#  ('South Hills', {'business': 0, 'user': 5}),
#  ('Troy Township', {'business': 1, 'user': 5}),
#  ('Surprise Crossing', {'business': 0, 'user': 5}),
#  ('Stuttgart - Bad Cannstatt', {'business': 0, 'user': 5}),
#  ('Harwick', {'business': 0, 'user': 5}),
#  ('Warrensville Hts', {'business': 0, 'user': 5}),
#  ('Montral', {'business': 0, 'user': 5}),
#  ('Lambton', {'business': 0, 'user': 5}),
#  ('Ingram', {'business': 0, 'user': 5}),
#  ('Inglewood', {'business': 1, 'user': 5}),
#  ('Linden', {'business': 1, 'user': 5}),
#  ('Ansnorveldt', {'business': 0, 'user': 5}),
#  ('La Salle', {'business': 2, 'user': 5}),
#  ('Lauder', {'business': 0, 'user': 5}),
#  ('Charlemagne', {'business': 0, 'user': 5}),
#  ('Silver Lake', {'business': 0, 'user': 5}),
#  ('Pointe Claire', {'business': 0, 'user': 5}),
#  ('Saint-Bruno', {'business': 1, 'user': 5}),
#  ('Phoenix metro area', {'business': 0, 'user': 5}),
#  ('Allegheny', {'business': 0, 'user': 5}),
#  ('Whtiby', {'business': 1, 'user': 5}),
#  ('Kingussie', {'business': 0, 'user': 5}),
#  ('Shady Side', {'business': 0, 'user': 5}),
#  ('Vaughn', {'business': 0, 'user': 5}),
#  ('Downtown Toronto', {'business': 0, 'user': 5}),
#  ('Highland Hills', {'business': 0, 'user': 5}),
#  ('Noyan', {'business': 1, 'user': 5}),
#  ('Russell Twp', {'business': 0, 'user': 5}),
#  ('Ranlo', {'business': 1, 'user': 5}),
#  ("L'Île-Perrôt", {'business': 0, 'user': 5}),
#  ('Montreal-West', {'business': 2, 'user': 5}),
#  ('Tottenham', {'business': 0, 'user': 5}),
#  ('Las Vegass', {'business': 0, 'user': 5}),
#  ('Fabreville', {'business': 0, 'user': 5}),
#  ('Ross', {'business': 0, 'user': 5}),
#  ('Cuyahoga Fls', {'business': 0, 'user': 5}),
#  ("L'ile-Bizard", {'business': 0, 'user': 5}),
#  ('Scarbrough', {'business': 0, 'user': 5}),
#  ('Freiberg', {'business': 0, 'user': 4}),
#  ('Fox Chapel', {'business': 0, 'user': 4}),
#  ('Ingomar', {'business': 0, 'user': 4}),
#  ('Saint - Hyacinthe', {'business': 0, 'user': 4}),
#  ('Villa Grove', {'business': 0, 'user': 4}),
#  ('West Toronto', {'business': 0, 'user': 4}),
#  ('Edinburgh City of', {'business': 0, 'user': 4}),
#  ("Peoria Ave Citizen's Group", {'business': 0, 'user': 4}),
#  ('SLOAN', {'business': 0, 'user': 4}),
#  ('River Drive Park', {'business': 1, 'user': 4}),
#  ('Lothian', {'business': 0, 'user': 4}),
#  ('etobicoke', {'business': 0, 'user': 4}),
#  ('Nellis Air Force Base', {'business': 0, 'user': 4}),
#  ('Banksville', {'business': 0, 'user': 4}),
#  ('St Bernard de Lacolle', {'business': 0, 'user': 4}),
#  ('Side Slopes', {'business': 0, 'user': 4}),
#  ('Pepperpike', {'business': 0, 'user': 4}),
#  ('Aberlady', {'business': 0, 'user': 4}),
#  ('Warrensville', {'business': 0, 'user': 4}),
#  ('Reminderville', {'business': 0, 'user': 4}),
#  ('AGINCOURT', {'business': 0, 'user': 4}),
#  ('Huntsburg', {'business': 0, 'user': 4}),
#  ('Newburgh Heights', {'business': 0, 'user': 4}),
#  ('Côte-Saint-Luc', {'business': 0, 'user': 4}),
#  ("Baie-D'urfe", {'business': 0, 'user': 4}),
#  ('Bloomfield', {'business': 1, 'user': 4}),
#  ('Mccandless Township', {'business': 0, 'user': 4}),
#  ('Aichwald', {'business': 1, 'user': 4}),
#  ('Geauga', {'business': 0, 'user': 4}),
#  ('University Ht', {'business': 0, 'user': 4}),
#  ('Mckeesport', {'business': 0, 'user': 4}),
#  ('Rankin', {'business': 0, 'user': 4}),
#  ('Münster', {'business': 0, 'user': 4}),
#  ('Brunswick Hills', {'business': 1, 'user': 4}),
#  ('Berry', {'business': 0, 'user': 4}),
#  ('Saint-Hippolyte', {'business': 0, 'user': 4}),
#  ('Crescent', {'business': 0, 'user': 4}),
#  ('Saint-Marc-Sur-Richelieu', {'business': 1, 'user': 4}),
#  ('South Mountain', {'business': 0, 'user': 4}),
#  ('Southside Flats', {'business': 0, 'user': 4}),
#  ('Cooksville', {'business': 0, 'user': 4}),
#  ('Whitney', {'business': 0, 'user': 4}),
#  ('London', {'business': 0, 'user': 4}),
#  ('Kernen-Stetten', {'business': 0, 'user': 4}),
#  ('Chander', {'business': 0, 'user': 4}),
#  ('Rural Ridge', {'business': 1, 'user': 4}),
#  ('St-Eugène', {'business': 0, 'user': 4}),
#  ('Ahwatukee Foothills Village', {'business': 0, 'user': 4}),
#  ('Chertsey', {'business': 0, 'user': 4}),
#  ('Caledon Village', {'business': 0, 'user': 4}),
#  ('Shaker Hts', {'business': 0, 'user': 4}),
#  ('Northfield Center Township', {'business': 0, 'user': 4}),
#  ('N. Randall', {'business': 0, 'user': 3}),
#  ('Bonnyrigg and Lasswade', {'business': 0, 'user': 3}),
#  ('Old Scottsdale', {'business': 0, 'user': 3}),
#  ('Lachenaie', {'business': 0, 'user': 3}),
#  ('St-Lazare', {'business': 0, 'user': 3}),
#  ('Deux-Montagnes Regional County Municipality', {'business': 0, 'user': 3}),
#  ('McMasterville', {'business': 0, 'user': 3}),
#  ('Chateau', {'business': 0, 'user': 3}),
#  ('St. Anns', {'business': 0, 'user': 3}),
#  ('Woodbridge (Vaughan)', {'business': 0, 'user': 3}),
#  ('Cowdenbeath', {'business': 0, 'user': 3}),
#  ('Stuttgart Bad-Canstatt', {'business': 0, 'user': 3}),
#  ('East Mesa', {'business': 0, 'user': 3}),
#  ('St. Jean Sur Richelieu', {'business': 0, 'user': 3}),
#  ('Norval', {'business': 0, 'user': 3}),
#  ('Auburn Twp', {'business': 1, 'user': 3}),
#  ('East Gwilimbury', {'business': 0, 'user': 3}),
#  ('Boston Heights', {'business': 0, 'user': 3}),
#  ('Statesville', {'business': 0, 'user': 3}),
#  ('Prévost', {'business': 1, 'user': 3}),
#  ('St-Laurent', {'business': 0, 'user': 3}),
#  ('Duquesne', {'business': 0, 'user': 3}),
#  ('Leaside', {'business': 0, 'user': 3}),
#  ('Pincourt', {'business': 0, 'user': 3}),
#  ('Catawba Springs', {'business': 1, 'user': 3}),
#  ('Mansfield', {'business': 1, 'user': 3}),
#  ('Ashburn', {'business': 0, 'user': 3}),
#  ('Morriston', {'business': 0, 'user': 3}),
#  ('Russell', {'business': 1, 'user': 3}),
#  ('Fithian', {'business': 0, 'user': 3}),
#  ('Arlington', {'business': 0, 'user': 3}),
#  ('Le Haut-Saint-Laurent Regional County Municipality',
#   {'business': 0, 'user': 3}),
#  ('Indianola', {'business': 0, 'user': 3}),
#  ('Vilas', {'business': 0, 'user': 3}),
#  ('Pilton', {'business': 0, 'user': 3}),
#  ('Malton', {'business': 1, 'user': 3}),
#  ('Forest Grove', {'business': 0, 'user': 3}),
#  ('Central City', {'business': 1, 'user': 3}),
#  ('TORONTO', {'business': 1, 'user': 3}),
#  ('Scotesdale', {'business': 0, 'user': 3}),
#  ('St Joseph', {'business': 0, 'user': 3}),
#  ('Scotland', {'business': 0, 'user': 3}),
#  ('Rillton', {'business': 1, 'user': 3}),
#  ('Aberdour', {'business': 0, 'user': 3}),
#  ('Lake Norman', {'business': 0, 'user': 3}),
#  ('Saint-Pierre-de-Véronne-à-Pike-River', {'business': 0, 'user': 3}),
#  ('Broxburn', {'business': 0, 'user': 3}),
#  ('oakville', {'business': 0, 'user': 3}),
#  ("Saint-Roch-De-L'achigan", {'business': 0, 'user': 3}),
#  ('Springfield', {'business': 1, 'user': 3}),
#  ('Mt. Oliver Boro', {'business': 0, 'user': 3}),
#  ('Mesa AZ', {'business': 0, 'user': 3}),
#  ('Longniddry', {'business': 0, 'user': 3}),
#  ('Municipality of Murrysville', {'business': 0, 'user': 3}),
#  ('Sainte-Marguerite-du-Lac-Masson', {'business': 1, 'user': 3}),
#  ('Mayfield Heights.', {'business': 0, 'user': 3}),
#  ('Alburg', {'business': 0, 'user': 3}),
#  ('Harrisburg,', {'business': 0, 'user': 3}),
#  ('Saint Leonard', {'business': 1, 'user': 3}),
#  ('West Elizabeth', {'business': 0, 'user': 3}),
#  ('Saint-sauveur', {'business': 0, 'user': 3}),
#  ('Morgan', {'business': 0, 'user': 3}),
#  ('Shandwick', {'business': 0, 'user': 3}),
#  ('Balerno', {'business': 0, 'user': 3}),
#  ('Cuddy', {'business': 2, 'user': 3}),
#  ('Palmerston', {'business': 0, 'user': 3}),
#  ('Claremont', {'business': 0, 'user': 3}),
#  ('South Amherst', {'business': 0, 'user': 2}),
#  ('Livingstone', {'business': 0, 'user': 2}),
#  ('Pgh Int Arprt', {'business': 0, 'user': 2}),
#  ("L'assomption", {'business': 0, 'user': 2}),
#  ('peoria', {'business': 0, 'user': 2}),
#  ('Broadlands', {'business': 0, 'user': 2}),
#  ('Dewey', {'business': 0, 'user': 2}),
#  ('Nellis', {'business': 0, 'user': 2}),
#  ('Hawthorne', {'business': 0, 'user': 2}),
#  ('Scarborough,', {'business': 0, 'user': 2}),
#  ('Godmanchester', {'business': 0, 'user': 2}),
#  ('N. Ridgeville', {'business': 0, 'user': 2}),
#  ('Citibank', {'business': 0, 'user': 2}),
#  ('Stetten', {'business': 0, 'user': 2}),
#  ('Camargo', {'business': 0, 'user': 2}),
#  ('Leslieville', {'business': 0, 'user': 2}),
#  ('Currie', {'business': 1, 'user': 2}),
#  ('Montréal (Québec)', {'business': 0, 'user': 2}),
#  ('West Lothian', {'business': 0, 'user': 2}),
#  ('Point Claire', {'business': 0, 'user': 2}),
#  ('East Loth', {'business': 0, 'user': 2}),
#  ('Sainte-Anne-des-Plaines', {'business': 0, 'user': 2}),
#  ('Brooklyn Heights', {'business': 0, 'user': 2}),
#  ('St. Joseph', {'business': 0, 'user': 2}),
#  ('Montréal-Ouest', {'business': 0, 'user': 2}),
#  ('Chatauguay', {'business': 0, 'user': 2}),
#  ('Maple Grove', {'business': 0, 'user': 2}),
#  ('Mayfield Hts.', {'business': 0, 'user': 2}),
#  ('Pheonix AZ', {'business': 1, 'user': 2}),
#  ('St-Leonard', {'business': 2, 'user': 2}),
#  ("L'Ile-Perrot", {'business': 0, 'user': 2}),
#  ('Pittsburch', {'business': 0, 'user': 2}),
#  ('Rainbow Valley', {'business': 0, 'user': 2}),
#  ('Sun City Grand', {'business': 0, 'user': 2}),
#  ('Edgeworth', {'business': 0, 'user': 2}),
#  ('Saint-Isidore-De-Laprairie', {'business': 0, 'user': 2}),
#  ('Ormstown', {'business': 0, 'user': 2}),
#  ('Shaler', {'business': 0, 'user': 2}),
#  ('Huntingdon', {'business': 0, 'user': 2}),
#  ('Plum Boro', {'business': 0, 'user': 2}),
#  ('Gilbert AZ', {'business': 0, 'user': 2}),
#  ('Wolfschlugen', {'business': 0, 'user': 2}),
#  ('FORT MILL', {'business': 0, 'user': 2}),
#  ('Sainte-Marthe', {'business': 1, 'user': 2}),
#  ('East Credit', {'business': 0, 'user': 2}),
#  ('St-Jerome', {'business': 0, 'user': 2}),
#  ('Phoenix Valley', {'business': 1, 'user': 2}),
#  ('Goodyear AZ', {'business': 0, 'user': 2}),
#  ('Centre Island', {'business': 1, 'user': 2}),
#  ('Saint-Basile-Le-Grand', {'business': 1, 'user': 2}),
#  ('Arrowhead', {'business': 0, 'user': 2}),
#  ('Portobello', {'business': 0, 'user': 2}),
#  ('Île-des-Soeurs', {'business': 0, 'user': 2}),
#  ('Lake Las Vegas', {'business': 0, 'user': 2}),
#  ('Monroeville - Pit.', {'business': 0, 'user': 2}),
#  ('Napierville', {'business': 1, 'user': 2}),
#  ('Bentleyville', {'business': 0, 'user': 2}),
#  ('Dalgety Bay', {'business': 1, 'user': 2}),
#  ('Weston', {'business': 0, 'user': 2}),
#  ('Hendserson', {'business': 0, 'user': 1}),
#  ('Bois-Des-Filion', {'business': 0, 'user': 1}),
#  ('Ridgeville', {'business': 1, 'user': 1}),
#  ('Indian Land,', {'business': 0, 'user': 1}),
#  ('Phoniex', {'business': 0, 'user': 1}),
#  ('Straiton', {'business': 0, 'user': 1}),
#  ('Spring Hill City View', {'business': 0, 'user': 1}),
#  ('Las Vegas Strip', {'business': 0, 'user': 1}),
#  ('Mooers', {'business': 0, 'user': 1}),
#  ('Las Vegas NV', {'business': 0, 'user': 1}),
#  ('Old Town Scottsdale', {'business': 0, 'user': 1}),
#  ('Glbert', {'business': 0, 'user': 1}),
#  ('NorthYork', {'business': 0, 'user': 1}),
#  ('Queensville', {'business': 0, 'user': 1}),
#  ('Concord Twp', {'business': 1, 'user': 1}),
#  ('Paw Creek', {'business': 1, 'user': 1}),
#  ('Strip District', {'business': 0, 'user': 1}),
#  ('Mathews', {'business': 0, 'user': 1}),
#  ('Herminie', {'business': 0, 'user': 1}),
#  ('Sainte-Madeleine', {'business': 1, 'user': 1}),
#  ('Westview', {'business': 0, 'user': 1}),
#  ('Totronto', {'business': 0, 'user': 1}),
#  ('St-Lazare-de-Vaudreuil', {'business': 1, 'user': 1}),
#  ('Old Port of Montreal', {'business': 0, 'user': 1}),
#  ('Glen Williams', {'business': 0, 'user': 1}),
#  ('Edimbourg', {'business': 0, 'user': 1}),
#  ('Beauharnois', {'business': 1, 'user': 1}),
#  ('Stetson Valley', {'business': 0, 'user': 1}),
#  ('Chagrin Highlands', {'business': 0, 'user': 1}),
#  ('Saint Anns', {'business': 0, 'user': 1}),
#  ('Mayfield Hts', {'business': 0, 'user': 1}),
#  ('Sainte-thérèse', {'business': 1, 'user': 1}),
#  ('Phoenix AZ', {'business': 0, 'user': 1}),
#  ('Farnham', {'business': 1, 'user': 1}),
#  ('Mount Royal', {'business': 0, 'user': 1}),
#  ('Canonsburd', {'business': 0, 'user': 1}),
#  ('Henderson Nevada', {'business': 0, 'user': 1}),
#  ('Concord Township', {'business': 0, 'user': 1}),
#  ('Saint-Marc-sur-Richelieu', {'business': 1, 'user': 1}),
#  ('Ste-Adele', {'business': 0, 'user': 1}),
#  ('The Promenade', {'business': 0, 'user': 1}),
#  ('Sainte-Thérèse-de-Blainville', {'business': 0, 'user': 0}),
#  ('Hazelwood', {'business': 0, 'user': 0}),
#  ("Baie-d'Urfé", {'business': 0, 'user': 0}),
#  ('Sainte-Marie', {'business': 1, 'user': 0}),
#  ('Vaughn City', {'business': 0, 'user': 0}),
#  ('North Braddock', {'business': 0, 'user': 0}),
#  ('Ingliston', {'business': 0, 'user': 0}),
#  ('Mesa Arizona', {'business': 0, 'user': 0}),
#  ('Lacolle', {'business': 0, 'user': 0}),
#  ('Buena Vista', {'business': 1, 'user': 0}),
#  ('Oak Ridges', {'business': 0, 'user': 0}),
#  ('Hemmingford', {'business': 0, 'user': 0}),
#  ('tempe arizona', {'business': 1, 'user': 0}),
#  ('Fitchburgh', {'business': 0, 'user': 0}),
#  ('Mississauaga', {'business': 0, 'user': 0}),
#  ('Ste-Therese-de-Blainville', {'business': 0, 'user': 0}),
#  ('Lavaltrie', {'business': 1, 'user': 0}),
#  ('Fort  Mill', {'business': 0, 'user': 0}),
#  ('Vaudreuil', {'business': 0, 'user': 0}),
#  ('Indian Lands', {'business': 1, 'user': 0}),
#  ('Sloan', {'business': 0, 'user': 0}),
#  ('Sainte-Dorothée', {'business': 0, 'user': 0}),
#  ('Estrella Village', {'business': 0, 'user': 0}),
#  ('Greater Charlotte', {'business': 0, 'user': 0}),
#  ('Schottsdale', {'business': 1, 'user': 0}),
#  ('San Tan', {'business': 0, 'user': 0}),
#  ('Old Brooklyn', {'business': 0, 'user': 0}),
#  ...]

# %%
list_city = [ x[0] for x in sorted_by_business]

# %%
list_city
# Out:
# ['Las Vegas',
#  'Toronto',
#  'Phoenix',
#  'Charlotte',
#  'Edinburgh',
#  'Pittsburgh',
#  'Montréal',
#  'Scottsdale',
#  'Cleveland',
#  'Madison',
#  'Stuttgart',
#  'Mesa',
#  'Tempe',
#  'Henderson',
#  'Mississauga',
#  'Chandler',
#  'Gilbert',
#  'Glendale',
#  'Markham',
#  'Peoria',
#  'Champaign',
#  'Brampton',
#  'Concord',
#  'Richmond Hill',
#  'Lakewood',
#  'North York',
#  'Oakville',
#  'Vaughan',
#  'North Las Vegas',
#  'Surprise',
#  'Mentor',
#  'Scarborough',
#  'Etobicoke',
#  'Fort Mill',
#  'Cuyahoga Falls',
#  'Strongsville',
#  'Westlake',
#  'Matthews',
#  'Gastonia',
#  'Goodyear',
#  'Willoughby',
#  'North Olmsted',
#  'Whitby',
#  'Laval',
#  'Huntersville',
#  'Aurora',
#  'Avondale',
#  'Ludwigsburg',
#  'Cornelius',
#  'Newmarket',
#  'Urbana',
#  'Parma',
#  'Rocky River',
#  'Solon',
#  'Medina',
#  'Middleton',
#  'Monroeville',
#  'Inverness',
#  'Kent',
#  'Esslingen',
#  'Thornhill',
#  'Cleveland Heights',
#  'Stow',
#  'Avon',
#  'Fellbach',
#  'Sindelfingen',
#  'Sun Prairie',
#  'Ajax',
#  'Wexford',
#  'Coraopolis',
#  'Verona',
#  'Hudson',
#  'Pickering',
#  'Cave Creek',
#  'Elyria',
#  'Mayfield Heights',
#  'Montreal',
#  'Woodbridge',
#  'Pineville',
#  'Fountain Hills',
#  'North Royalton',
#  'Irwin',
#  'Avon Lake',
#  'Brunswick',
#  'Bridgeville',
#  'Broadview Heights',
#  'Böblingen',
#  'Carnegie',
#  'Belmont',
#  'Middleburg Heights',
#  'Beachwood',
#  'Pointe-Claire',
#  'Fitchburg',
#  'Painesville',
#  'Ostfildern',
#  'Twinsburg',
#  'Monona',
#  'Fairlawn',
#  'Independence',
#  'Boulder City',
#  'Harrisburg',
#  'Bethel Park',
#  'Homestead',
#  'Indian Trail',
#  'Streetsboro',
#  'Canonsburg',
#  'Litchfield Park',
#  'Chagrin Falls',
#  'Kannapolis',
#  'Carefree',
#  'Davidson',
#  'Brossard',
#  'Leonberg',
#  'West Mifflin',
#  'Leinfelden-Echterdingen',
#  'Gerlingen',
#  'Euclid',
#  'Paradise Valley',
#  'Berea',
#  'Amherst',
#  'Sewickley',
#  'McMurray',
#  'Stoughton',
#  'McKees Rocks',
#  'Fairview Park',
#  'North Versailles',
#  'Westmount',
#  'Laveen',
#  'Macedonia',
#  'Waxhaw',
#  'Lyndhurst',
#  'Gibsonia',
#  'Murrysville',
#  'Lorain',
#  'Waunakee',
#  'Brooklyn',
#  'New Kensington',
#  'Eastlake',
#  'Allison Park',
#  'Saint-Sauveur',
#  'Oregon',
#  'Dunfermline',
#  'Northfield',
#  'McKeesport',
#  'Waiblingen',
#  'Unionville',
#  'Brook Park',
#  'Sun City',
#  'Georgetown',
#  'South Euclid',
#  'Dollard-Des-Ormeaux',
#  'Willoughby Hills',
#  'Olmsted Falls',
#  'Dorval',
#  'Chardon',
#  'Oakmont',
#  'Bedford',
#  'Saint-Laurent',
#  'Stouffville',
#  'Filderstadt',
#  'Mint Hill',
#  'Kornwestheim',
#  'Shaker Heights',
#  'Verdun',
#  'Pleasant Hills',
#  'York',
#  'Parma Heights',
#  'Mahomet',
#  'Valley View',
#  'Brecksville',
#  'White Oak',
#  'Ambridge',
#  'Woodmere',
#  'Olivos',
#  'North Ridgeville',
#  'Chesterland',
#  'Boisbriand',
#  'De Forest',
#  'Saint-Jean-sur-Richelieu',
#  'East York',
#  'University Heights',
#  'Tolleson',
#  'Richfield',
#  'MESA',
#  'North Huntingdon',
#  'Middlefield',
#  'Mount Holly',
#  'Maple',
#  'Willowick',
#  'Oakdale',
#  'Monticello',
#  'Robinson Township',
#  'Glenshaw',
#  'Bay Village',
#  'Lake Wylie',
#  'Seven Hills',
#  'Fairview',
#  'Warrensville Heights',
#  'Tallmadge',
#  'East Gwillimbury',
#  'Frazer',
#  'Mount Horeb',
#  'Bolton',
#  'Moon Township',
#  'Savoy',
#  'Belleville',
#  'Wickliffe',
#  'Cross Plains',
#  'Kirtland',
#  'Braddock',
#  'Garfield Heights',
#  'Highland Heights',
#  'El Mirage',
#  'Boucherville',
#  'Elizabeth',
#  'Bradford',
#  'Anthem',
#  'Livingston',
#  'Outremont',
#  'Tega Cay',
#  'Kirkland',
#  'Newbury',
#  'Dallas',
#  'Cottage Grove',
#  'West Homestead',
#  'Rantoul',
#  'Lachine',
#  'Saint Joseph',
#  'DeForest',
#  'Youngtown',
#  'Maple Heights',
#  'Lasalle',
#  'Sun City West',
#  'Copley',
#  'Tuscola',
#  'Monongahela',
#  'Ditzingen',
#  'Indian Land',
#  'Mc Farland',
#  'Neuhausen',
#  'Cramerton',
#  'Mc Kees Rocks',
#  'Esslingen am Neckar',
#  'Ahwatukee',
#  'Sheffield Village',
#  'Valley City',
#  'Whitchurch-Stouffville',
#  'King City',
#  'Richmond Heights',
#  'McFarland',
#  'Bedford Heights',
#  'WICKLIFFE',
#  'Mentor-on-the-Lake',
#  'Sainte-Therese',
#  'Lowell',
#  'Trafford',
#  'Anjou',
#  'Hemmingen',
#  'San Tan Valley',
#  'Mont-Royal',
#  'Sainte-Anne-de-Bellevue',
#  'Moon',
#  'Steinenbronn',
#  'Schomberg',
#  'Stallings',
#  'Fairport Harbor',
#  'Saint-Hubert',
#  'Higley',
#  'Roosevelt',
#  'Greenfield Park',
#  'Millvale',
#  'Peninsula',
#  'Caledon',
#  'New Town',
#  'Munhall',
#  'Wesley Chapel',
#  'Burton',
#  'Bellevue',
#  'Pierrefonds',
#  'Turtle Creek',
#  'Penn Hills',
#  'Columbia Station',
#  'Plum',
#  'Rouses Point',
#  'Houston',
#  'Etna',
#  'South Las Vegas',
#  'Rexdale',
#  'Glenrothes',
#  'Freyburg',
#  'Saint-Leonard',
#  'Ross Township',
#  'Laveen Village',
#  'Mount Lebanon',
#  'Missisauga',
#  'Wilmerding',
#  'Grafton',
#  'Brentwood',
#  'Imperial',
#  'Saint-Eustache',
#  'Emsworth',
#  'Bainbridge',
#  'Chateauguay',
#  'Old Town',
#  'Upper Saint Clair',
#  'Midland',
#  'Hampton Township',
#  'Penicuik',
#  'King',
#  'Saint-Lambert',
#  'Munroe Falls',
#  'South Queensferry',
#  'Sainte-Julie',
#  'Chambly',
#  'Clairton',
#  'Springdale',
#  'Hochdorf',
#  'Sheffield Lake',
#  'Blawnox',
#  'Musselburgh',
#  'Kernen im Remstal',
#  'Bratenahl',
#  'Korntal-Münchingen',
#  "L'Île-Perrot",
#  'Medina Township',
#  'Moreland Hills',
#  'City of Edinburgh',
#  'Caledon East',
#  'Kahnawake',
#  'Bradford West Gwillimbury',
#  'Kleinburg',
#  'Sheffield',
#  'Mayfield Village',
#  'Longueuil',
#  'Terrebonne',
#  'North Randall',
#  'Scottdale',
#  'Mount Albert',
#  'Dollard-des-Ormeaux',
#  'Beloeil',
#  'Saint-Jerome',
#  'Stowe',
#  'Heidelberg',
#  'La Salle',
#  'Châteauguay',
#  'Lasswade',
#  'Guadalupe',
#  'St-Leonard',
#  'Leith',
#  'Crafton',
#  'Orange Village',
#  'La Prairie',
#  'Mont-Saint-Hilaire',
#  'Cheswick',
#  'Leetsdale',
#  'columbia station',
#  'Oakland',
#  'Homer',
#  'Saint-Lazare',
#  'Harrison City',
#  'Rigaud',
#  'Wilkinsburg',
#  'Dalkeith',
#  'Grand River',
#  'Las  Vegas',
#  'Forest Hills',
#  'Stanley',
#  'Nellis Afb',
#  'Montreal-West',
#  'N. Las Vegas',
#  'Vaudreuil-Dorion',
#  'Joliette',
#  'Finleyville',
#  'Concord Mills',
#  'Blue Diamond',
#  'Delson',
#  'North Olmstead',
#  'Saint-Hyacinthe',
#  'Mont-Saint-Gregoire',
#  'Mt. Lebanon',
#  'Schönaich',
#  'Willowdale',
#  'Sainte-Anne-De-Bellevue',
#  'Avalon',
#  'Cuddy',
#  'Baldwin',
#  'Beaconsfield',
#  'Brooklin',
#  'Stockbridge',
#  'Montéal',
#  'Lake Park',
#  'Ridgeville',
#  'Litchfield',
#  'Sainte-Marie',
#  'Paoli',
#  'St-Benoît de Mirabel',
#  'Elizabeth Township',
#  'Rosemère',
#  'Saint-Jean-Sur-Richelieu',
#  'River Drive Park',
#  'Sainte-Catherine',
#  'toronto',
#  'Don Mills',
#  'Robinson Twp.',
#  'Buena Vista',
#  'Russellton',
#  'Montreal-Ouest',
#  'Nobleton',
#  'Green Valley',
#  'Las vegas',
#  'Sainte-Adele',
#  'tempe arizona',
#  'Tremont',
#  'Harmarville',
#  'North Scottsdale',
#  'Auburn Twp',
#  'McCandless',
#  'Queensferry',
#  'Paradise',
#  'Venetia',
#  'Olmsted Township',
#  'Troy Township',
#  'Mc Murray',
#  'Library',
#  'Quartermile',
#  'Lawrence',
#  'Upper St Clair',
#  'Currie',
#  'Lavaltrie',
#  'Champlain',
#  'Bainbridge Township',
#  'New Eagle',
#  'Mirabel',
#  'Indian Lands',
#  'Indian land',
#  'East McKeesport',
#  'South Park',
#  'Prévost',
#  'Orange',
#  'Hinckley',
#  'Bonnyrigg',
#  'Salaberry-De-Valleyfield',
#  'West Akron',
#  'Bloomfield',
#  'Gelndale',
#  'Woodmere Village',
#  'Dollard-Des Ormeaux',
#  'Kennedy Township',
#  'Whiitby',
#  'Saint-Henri',
#  'Aichwald',
#  'Stoney Creek',
#  'Inglewood',
#  'Linden',
#  'Ratho',
#  'Montreal-Nord',
#  'Warrensvile Heights',
#  'chandler',
#  'Catawba Springs',
#  'Haddington',
#  'Edgewood',
#  'Fort McDowell',
#  'Lagrange',
#  'Mansfield',
#  'Spring Valley',
#  'Schottsdale',
#  'Lower Burrell',
#  'Weddington',
#  'Estérel',
#  'Jefferson Hills',
#  'Russell',
#  'Shaler Township',
#  'Pepper Pike',
#  'Dudley',
#  'Pheonix AZ',
#  'Concord Twp',
#  'Paw Creek',
#  'Schwaikheim',
#  'Brimfield',
#  'Saint-Sauveur-des-Monts',
#  'Goodwood',
#  'Sainte-Genevieve',
#  'Sainte-Madeleine',
#  'Brookpark',
#  'Gifford',
#  'Saint-Bruno',
#  'McCandless Township',
#  'Aspinwall',
#  'St-Lazare-de-Vaudreuil',
#  'Mantua',
#  'Enterprise',
#  'Richmond Hil',
#  'Brunswick Hills',
#  'Scarobrough',
#  'Malton',
#  'Denkendorf',
#  'Whtiby',
#  'Moss',
#  'Kernen',
#  'Central City',
#  'Pheonix',
#  'Beauharnois',
#  'Scaroborough',
#  'TORONTO',
#  'Gates Mills',
#  'Glendale Az',
#  'Downtown',
#  'LasVegas',
#  'Saint-Marc-Sur-Richelieu',
#  'Rillton',
#  'Cecil',
#  'Noyan',
#  'Chomedey, Laval',
#  'Springfield',
#  'East Cleveland',
#  'Presto',
#  'Sagamore Hills',
#  'Dane',
#  'NORTH YORK',
#  'Sainte-Marthe',
#  'Lachute',
#  'Thornhil',
#  'Kirkcaldy',
#  'Warrensville Hts.',
#  'Nellis AFB',
#  'Phoenix Valley',
#  'Sainte-Marguerite-du-Lac-Masson',
#  'Ranlo',
#  'Thorncliffe Park',
#  'Sainte-thérèse',
#  'Rawdon',
#  'Centre Island',
#  'West View',
#  'Saint Laurent',
#  'Saint-Basile-Le-Grand',
#  'Saint Leonard',
#  'Bernhausen',
#  'Sun Lakes',
#  "L'ile-Perrot",
#  'East Mc Keesport',
#  'Bathurst Quay',
#  'South Park Township',
#  'North Toronto',
#  'Cleveland Hghts.',
#  'Farnham',
#  'Rural Ridge',
#  'Richmond Hts',
#  'East Pittsburgh',
#  'LaSalle',
#  'Sainte-Adèle',
#  'Schwieberdingen',
#  'Ft. Mill',
#  'Elrama',
#  'Saint-Marc-sur-Richelieu',
#  'Remseck am Neckar',
#  'Lower Lawrenceville',
#  'Cote-Saint-Luc',
#  'Northside',
#  'Napierville',
#  'Streetsville',
#  'Phx',
#  'Montrose',
#  'Clarkson',
#  'Saint-Constant',
#  'Wilkins Township',
#  'Ben Avon',
#  'Dravosburg',
#  'Peters Township',
#  'Harrisbug',
#  'Dalgety Bay',
#  'Mayfield',
#  'clinton',
#  '',
#  'Sindelfingen/Eichholz',
#  'South Amherst',
#  'N. Randall',
#  'Bonnyrigg and Lasswade',
#  'Sainte-Thérèse-de-Blainville',
#  'Freiberg',
#  'Pointe-Aux-Trembles',
#  'Hazelwood',
#  'Burntisland',
#  'Old Scottsdale',
#  'Promenade',
#  'Livingstone',
#  'Middleburg Hts',
#  'W Spring Valley',
#  'Fox Chapel',
#  'Hendserson',
#  'Elk Grove Villa',
#  'Bois-Des-Filion',
#  'Lachenaie',
#  "Baie-d'Urfé",
#  'las vegas',
#  'Upper St. Clair',
#  'Ingomar',
#  'St-Lazare',
#  'Pgh Int Arprt',
#  'Deux-Montagnes Regional County Municipality',
#  'Möglingen',
#  'St Leonard',
#  'nboulder city',
#  "L'assomption",
#  'Sun City Anthem',
#  'peoria',
#  'Broadlands',
#  'Ogden',
#  'Saint - Hyacinthe',
#  'Candiac',
#  'Brooklyn Hts.',
#  'Villa Grove',
#  'Henderson (Green Valley)',
#  'Le Sud-Ouest',
#  'Gormley',
#  'Buckeye - Shaker',
#  'Dewey',
#  'Henderston',
#  'McMasterville',
#  'West Toronto',
#  'Chateau',
#  'Edinburgh City of',
#  'Nellis',
#  'N Ridgeville',
#  'Indian Land,',
#  'Vaughn City',
#  'St. Anns',
#  'South Gyle',
#  'Phoniex',
#  'Las Vegas East',
#  "Peoria Ave Citizen's Group",
#  'North Braddock',
#  'Ingliston',
#  'Mississuaga',
#  'Saint-Antoine',
#  'Straiton',
#  'Meza',
#  'Pine',
#  'Woodbridge (Vaughan)',
#  'SLOAN',
#  'Monoroeville',
#  'Cowdenbeath',
#  'Summerlin South',
#  'Mint  Hill',
#  'Stuttgart Bad-Canstatt',
#  'Tranent',
#  'Hawthorne',
#  'Lothian',
#  'Mesa Arizona',
#  'Bruntsfield',
#  'etobicoke',
#  'Nellis Air Force Base',
#  'Lacolle',
#  'Scott Township',
#  'Scarborough,',
#  'Oak Ridges',
#  'Saint-Bernard-de-Lacolle',
#  'Godmanchester',
#  'McMurry',
#  'Hemmingford',
#  'Banksville',
#  'East Mesa',
#  'Auburn Township',
#  'Middleburg Hts.',
#  'St. Jean Sur Richelieu',
#  'Charlotte (University)',
#  'Norval',
#  'N. Ridgeville',
#  'Glasgow',
#  'Citibank',
#  'Fitchburgh',
#  'Phoneix',
#  'East Mississauga',
#  'Strongville',
#  'Stetten',
#  'N W Las Vegas',
#  'Ahwahtukee',
#  'Robinson Town',
#  'St Bernard de Lacolle',
#  'McKnight',
#  'Lingen',
#  'Vimont',
#  'Fountainbridge',
#  'Firth of Forth',
#  'Liberty',
#  'C Las Vegas',
#  'Spring Hill City View',
#  'Tolono',
#  'South Hills',
#  'Central City Village',
#  'East Gwilimbury',
#  'La Baie',
#  'Summerlin',
#  'Las Vegas Strip',
#  'Side Slopes',
#  'Camargo',
#  'Mooers',
#  'Leslieville',
#  'Mississauaga',
#  'Westworld Scottsdale',
#  "L'Île-Bizard",
#  'McDonald',
#  'Saint-Bernard-De-Lacolle',
#  'Fullerton',
#  'Pepperpike',
#  'Aberlady',
#  'Warrensville',
#  'Ste-Therese-de-Blainville',
#  'Central Henderson',
#  'Montréal (Québec)',
#  'Boston Heights',
#  'Reminderville',
#  'SCOTTSDALE AZ',
#  'AGINCOURT',
#  'Moon Twp',
#  'frazer',
#  'Fort  Mill',
#  'Neville Island',
#  'Ste-Rose',
#  'Bradfordwoods',
#  'Surprise Crossing',
#  'Sharpsburg',
#  'Huntsburg',
#  'Murrysville (Monroeville)',
#  'McAdenville',
#  'Vaudreuil',
#  'West Lothian',
#  'Las Vegas NV',
#  'Point Claire',
#  'Newburgh Heights',
#  'Stuttgart - Bad Cannstatt',
#  'Stuttgart-Vaihingen',
#  'Statesville',
#  'Harwick',
#  'Piedmont',
#  'Walton Hills',
#  'York Regional Municipality',
#  'Vanier',
#  'Old Town Scottsdale',
#  'Morin-Heights',
#  'Pencaitland',
#  'Warrensville Hts',
#  'Côte-Saint-Luc',
#  'Sloan',
#  'Loanhead',
#  'Glbert',
#  'N Las Vegas',
#  "Baie-D'urfe",
#  'Blackness',
#  'Roslin',
#  'Sainte-Dorothée',
#  'East Loth',
#  'North Huntington',
#  'St-Laurent',
#  'Sainte-Anne-des-Plaines',
#  'Montral',
#  'Oakwood Village',
#  'Juniper Green',
#  'Lambton',
#  'Shorewood Hills',
#  'Brooklyn Heights',
#  'Ingram',
#  'Mccandless Township',
#  'Mattews',
#  'St. Joseph',
#  'Estrella Village',
#  'Duquesne',
#  'Windsor',
#  'Leaside',
#  'Montréal-Ouest',
#  'Pincourt',
#  'Chatauguay',
#  'Montréal-Nord',
#  'Geauga',
#  'Greater Charlotte',
#  'Maple Grove',
#  'Ansnorveldt',
#  'University Ht',
#  'NorthYork',
#  'Ashburn',
#  'Mckeesport',
#  "Notre-Dame-De-L'ile-Perrot",
#  'Sunrise',
#  'Mayfield Hts.',
#  'Glassport',
#  'Morriston',
#  'Leinfelden',
#  'Lauder',
#  'Charlemagne',
#  'Saint-Philippe',
#  'Silver Lake',
#  'Mercier',
#  'Mt Albert',
#  'Mascouche',
#  'Rankin',
#  'Bellvue',
#  'Prestonpans',
#  'Queensville',
#  'Toronto, Ontario',
#  'Fithian',
#  'Arlington',
#  'San Tan',
#  'Strip District',
#  'Mt Lebanon',
#  'Mathews',
#  'Mayfield Heights (Cleveland)',
#  'Median',
#  'Herminie',
#  'Clark',
#  'Pointe Claire',
#  'Westview',
#  'Regional Municipality of York',
#  'Totronto',
#  'Sidney',
#  'Cuyahoga Heights',
#  'Le Haut-Saint-Laurent Regional County Municipality',
#  'Münster',
#  'N. Olmsted',
#  'Leven',
#  'Indianola',
#  'Île des Soeurs',
#  'Phoenix metro area',
#  'Sainte-Thérèse',
#  '110 Las Vegas',
#  'Repentigny',
#  'Old Port of Montreal',
#  'Newington',
#  'Vilas',
#  'Blainville',
#  'Philo',
#  'Sunnyslope',
#  'Northfield Center',
#  'Inverkeithing',
#  'Lowesville',
#  'Bedford HTS',
#  'Pilton',
#  'Nottingham',
#  'Allegheny',
#  'Bedford Hts.',
#  'Port Credit',
#  'Las Vegas, NV',
#  "L'Ile-Perrot",
#  'Glen Williams',
#  'Plieningen',
#  'Topaz',
#  'Berry',
#  'Forest Grove',
#  'Swissvale',
#  'Pittsburg',
#  'Edimbourg',
#  'Old Brooklyn',
#  'Gorebridge',
#  'Kingussie',
#  'Shady Side',
#  'Scotesdale',
#  'N. OLMSTED',
#  'Pittsburch',
#  'Saint-Hippolyte',
#  'St Joseph',
#  'Castle Shannon',
#  'Rainbow Valley',
#  'Clinton',
#  'Crescent',
#  'Creighton',
#  'Sun City Grand',
#  'Pitcairn',
#  'Mt. Horeb',
#  'Edgeworth',
#  'Gullane',
#  'Scotland',
#  'Saint-Isidore-De-Laprairie',
#  'Vaughn',
#  'Henderson and Las vegas',
#  'Berg',
#  'Ormstown',
#  'Shaler',
#  'Water of Leith',
#  'St-Bruno-de-Montarville',
#  'Downtown Toronto',
#  'Highland Hills',
#  'Aberdour',
#  'Lake Norman',
#  'Huntingdon',
#  'Mc Donald',
#  'Saint-Pierre-de-Véronne-à-Pike-River',
#  'Plum Boro',
#  'Broxburn',
#  'Charlote',
#  'W Henderson',
#  'East Liberty',
#  'oakville',
#  "Saint-Roch-De-L'achigan",
#  'Bath',
#  'South Mountain',
#  'Gilbert AZ',
#  'Wolfschlugen',
#  'CHARLOTTE',
#  'Phoenix,',
#  'Stetson Valley',
#  'Brookline',
#  'Hendersonville',
#  'Russell Twp',
#  'Mt. Oliver Boro',
#  'Southside Flats',
#  'FORT MILL',
#  'Cooksville',
#  'Mesa AZ',
#  'Longniddry',
#  'Beeton',
#  'Remseck',
#  'Saint-Jérôme',
#  'Waddell',
#  'East Credit',
#  'Stowe Township',
#  'Black Earth',
#  'Chagrin Highlands',
#  'Saint Anns',
#  'MC Murray',
#  'San Rafael',
#  'Municipality of Murrysville',
#  'Newhaven',
#  'St-Jerome',
#  'Goodyear AZ',
#  'North of Brampton',
#  'Vieux Montreal',
#  'Mayfield Hts',
#  'Wildwood',
#  'Cramond',
#  'Whitney',
#  'London',
#  'Kernen-Stetten',
#  "L'Île-Perrôt",
#  'Mayfield Heights.',
#  'Alburg',
#  'St Davids',
#  'Harrisburg,',
#  'University Hts ',
#  'Arnold',
#  'Mount Washington',
#  'Arrowhead',
#  'Portobello',
#  'Phoenix AZ',
#  'Chander',
#  'Mount Royal',
#  'Saint-Bruno-de-Montarville',
#  'Canonsburd',
#  'Henderson Nevada',
#  'West Elizabeth',
#  'Roxboro',
#  'Saint-sauveur',
#  'East Lothian',
#  'St-Eugène',
#  'Shadyside',
#  'Ahwatukee Foothills Village',
#  'Rosemere',
#  'Novelty',
#  'Morgan',
#  'Tottenham',
#  'Île-des-Soeurs',
#  'Kirknewton',
#  'Mentor On the Lake',
#  'CITY CENTER',
#  'Squirrel Hill',
#  'Chertsey',
#  'Phoenix, AZ',
#  'Newbridge',
#  'North Olmsted,',
#  'Mentor On the',
#  'Las Vegass',
#  'Desert Ridge',
#  'Ballantyne',
#  'Fabreville',
#  'Shandwick',
#  'Lake Las Vegas',
#  'Concord Township',
#  'Oka',
#  'Mcmurray',
#  'Green Tree',
#  'Balerno',
#  'North Queensferry',
#  'Ste-Adele',
#  'Ross',
#  'Monroeville - Pit.',
#  'Palmerston',
#  'Caledon Village',
#  'Shaker Hts',
#  'Cote Saint-Luc',
#  'Communauté-Urbaine-de-Montréal',
#  'Downsview',
#  'Northfield Center Township',
#  'Centennial Hills',
#  'Churubusco',
#  'Hiram',
#  'Robinson',
#  'Cuyahoga Fls',
#  'The Promenade',
#  'Chandler-Gilbert',
#  'Bentleyville',
#  'Midlothian',
#  'mesa',
#  'N E Las Vegas',
#  ...]

# %%
def recommend_based_on_state(state):
    print('============================================')
    print('Recommendation info summary for : ', state)

    City_of_Data = state
   
    # pre-process data: build up user and business data set based on state
    filter_user = {}
    valid_user = {}
    valid_test_user = {}
    for i in user_rating[City_of_Data]:
        if len(user_rating[City_of_Data][i]) >= 20:
            filter_user[i] = len(user_rating[City_of_Data][i])
    raw = sorted(filter_user.items(), key=lambda x:-x[1])
    valid_list = []
    for k, v in raw:
        if k in ucrmap[City_of_Data] and k in test_urcmap[City_of_Data]:
            valid_list.append(k)
            valid_user[k] = ucrmap[City_of_Data][k]
            valid_test_user[k] = test_urcmap[City_of_Data][k]
            
    print('number of valid user: ', len(valid_user))
    print('number of valid test user: ', len(valid_user))
    
    #generate business category dict with pure vector
    def generate_nbcrmap(data):
        for business in data:
            for k, v in data[business].items():
                data[business][k] = statistics.mean(v)

        for business in data:
            for i in tc[state]:
                if i not in data[business]:
                    data[business][i] = 3.12

        nbcrmap = {}
        for k, v in data.items():
            nbcrmap[k] = []
            value = []
            for i in tc[state]:
                value.append(v[i])
            nbcrmap[k] = value
        return nbcrmap

    nbcrmp = generate_nbcrmap(bcrmap[City_of_Data])
    
    # Compose user category vector
    def generate_nucrmap(data):
        for user in data:
            for cate, value in data[user].items():
                data[user][cate] = statistics.mean(value)
        for user in data:
            for i in tc[state]:
                if i not in data[user]:
                    data[user][i] = 3.12

        nucrmap = {}
        for k, v in data.items():
            nucrmap[k] = []
            value = []
            for i in tc[state]:
                value.append(v[i])
            nucrmap[k] = value
        return nucrmap

    nucrmap = generate_nucrmap(valid_user)
    
    data = nucrmap
    listV = list(data.values())
    listK = list(data.keys())
    
    # Agglomerative clustering using scipy
    Z = scipy.cluster.hierarchy.linkage(listV[:300], method='average')
    plt.clf()
    fig = plt.figure(figsize=(20, 16), dpi=40, facecolor='w', edgecolor='k')
    dd = scipy.cluster.hierarchy.dendrogram(Z)
    plt.savefig('{}.pdf'.format('average'))
    plt.show()
    
#     c, coph_dists = scipy.cluster.hierarchy.cophenet(Z, pdist(listV))
#     print("c, coph_dists = cophenet(Z, pdist(X)); c is ideally close to one, c="+repr(c))
    
    #agglomerative clustering using sklearn 
    data1 = []
    for k,v in nucrmap.items():
        data1.append(v)
    np.save('123', np.array(data1))
    data1 = np.load('123.npy')

    # get number of clusters from above plot and generate clusters dictionary
    model = cluster.AgglomerativeClustering(linkage='average', n_clusters=20)
    result = model.fit_predict(listV)
    clusters = {}
    for i in range(len(result)):
        k = result[i]
        v = data1[i]
        clusters.setdefault(k, []).append(v)

    # Average Vector for each cluster generated above

    average_vector = {}
    for i in list(clusters.keys()):
        average_vector[i] = np.mean(clusters[i], axis=0)

    def generate_recommendatioin(uid):
        index = listK.index(uid)
        uvector = average_vector[result[index]]
        r = {}
        for i in nbcrmp:
            r[i] = np.inner(uvector, nbcrmp[i])
        top_business = sorted(r.items(), key=lambda x:(-x[1]))[1:100]
        return [k for k,v in top_business]
    def cacluate_hr(uid, bids):
        score = 0
        count = 0
        for bid in bids:
            if bid in valid_test_user[uid]:
                count += 1
                if valid_test_user[uid][bid] > 3.7:
                    score += 1
                if valid_test_user[uid][bid] < 2.6:
                    score -= 1
        return np.array([score, count])
    
    def calculate_ndcg(uid, bids):
        gain = 0
        ind_list = []
        for i in range(len(bids)):
            bid = bids[i]
            if bid in valid_test_user[uid]:
                ind_list.append(i+1)
                gain += valid_test_user[uid][bid]/(i+1)
        idcg = 0
        for i in ind_list:
            idcg += 5/i
        if idcg == 0:
            return 0
        return np.array([gain,idcg])

    def evaluate(list_test):
        hr = np.array([0.,0.])
        ndcg = np.array([0.,0.])
        for uid in list_test:
            recs = generate_recommendatioin(uid)
            tmp = cacluate_hr(uid, recs)
            ndcg += calculate_ndcg(uid, recs)
            hr += tmp
        print('Hit Ratio: ', hr[0]/hr[1])
        print('NDCG: ', ndcg[0]/ndcg[1])
        print('============================================')
        print('\n\n\n\n')
        return (hr[0]/hr[1], ndcg[0]/ndcg[1])
    
    # user index corresponding to user vector dictionary
    index = random.randint(0,len(listK)-1)
    # Get the users cluster vector 
    user_vector = average_vector[result[index]]
    # Perfor inner dot product between user_vector and each business vector

    result_bcrmap = {}
    for i in nbcrmp:
        result_bcrmap[i] = np.inner(user_vector, nbcrmp[i])
    # Sort the business based on the minimum value of above operation. Keep top 20 businesses
    top_business = sorted(result_bcrmap.items(), key=lambda x:(-x[1]))[1:20]
    # print out the recommended businesses

    for k,v in top_business:
        print(business_name[k])
        
        
    return evaluate(valid_list)

# %%
hr_list = []
ndcg_list = []
for state in list_city[:20]:
    result = recommend_based_on_state(state)
    hr_list.append(result[0])
    ndcg_list.append(result[1])
# Out:
# ============================================
# Recommendation info summary for :  Las Vegas
# number of valid user:  5896
# number of valid test user:  5896
# Jjanga Steak & Sushi,6125 S Fort Apache Rd, Ste 200,Las Vegas,NV
# Gilligan's HideAway,2601 Atlantic St,Las Vegas,NV
# Zest - Bistro & Bar,10670 Southern Highlands Pkwy, Ste 102,Las Vegas,NV
# Pier 215,7060 S Durango Dr, Ste 101,Las Vegas,NV
# Soho Sushi Burrito,6040 W Badura Ave, Ste 150,Las Vegas,NV
# Mojito Hut,3570 S Las Vegas Blvd,Las Vegas,NV
# Modern Proteins,6475 W Charleston Blvd, Ste 110,Las Vegas,NV
# VIP Sushi and Karaoke,953 E Sahara Ave, Ste E-1A,Las Vegas,NV
# J Karaoke Bar,3899 Spring Mountain Rd,Las Vegas,NV
# Rachel's Kitchen,888 W Bonneville Ave,Las Vegas,NV
# Toddy Shop,238 S Rainbow Blvd,Las Vegas,NV
# Playa Papagayos,4760 W Sahara Ave, Ste 21,Las Vegas,NV
# Snack Bar,1220 E Harmon Ave, Ste A,Las Vegas,NV
# Aroma Cuisine of the World/Oscar Catering,6370 W Flamingo Rd, Ste 30,Las Vegas,NV
# Yard House,11011 W Charleston Blvd,Las Vegas,NV
# Greens and Proteins,8975 S Eastern Ave,Las Vegas,NV
# The Steakhouse at Treasures,2801 Westwood Dr,Las Vegas,NV
# Kaffe Live,5135 S Fort Apache Rd, Ste 145,Las Vegas,NV
# Izakaya Go,3775 Spring Mountain Rd, Ste 301,Las Vegas,NV
# Hit Ratio:  0.652941176471
# NDCG:  0.77462519661
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Toronto
# number of valid user:  2104
# number of valid test user:  2104
# MoTo Coffee and Snack Bar,1321 Dundas Street W,Toronto,ON
# Paint Cabin,723 Gerrard Street E,Toronto,ON
# Tesla Cafe,690 Euclid Avenue,Toronto,ON
# Haute Coffee,153 Dupont Street,Toronto,ON
# The Porch Light,982 Kingston Road,Toronto,ON
# Scout & Cash Caffe,146 Christie Street,Toronto,ON
# Voodoo Child,388 College Street,Toronto,ON
# Page One,106 Mutual Street,Toronto,ON
# Ciao Europa Cafe,80 Western Battery Road,Toronto,ON
# Green Republic Food,439 University Avenue, Unit 105,Toronto,ON
# Raca Cafe and Bar,1704 Queen Street W,Toronto,ON
# Bailey's Cafe,324 Bathurst Street,Toronto,ON
# Noble Coffee,1421 Bloor Street W,Toronto,ON
# The Merseyside,2413 Dundas Street W,Toronto,ON
# Wraps On The Go,Cumberland Terrace, 2 Bloor Street W,Toronto,ON
# Placebo Space,2877 Lakeshore Boulevard W,Toronto,ON
# Livelihood Cafe,254 Augusta Avenue,Toronto,ON
# East of York Gourmet Food,1904 Danforth Avenue,Toronto,ON
# Zocalo,1426 Bloor Street W,Toronto,ON
# Hit Ratio:  0.65
# NDCG:  0.88883804579
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Phoenix
# number of valid user:  1963
# number of valid test user:  1963
# Presidio Cocina Mexicana,519 W Thomas Rd,Phoenix,AZ
# Phoenix City Grille,5816 N 16th St,Phoenix,AZ
# Lakeside Hideout Cafe,11225 N 28th Dr,Phoenix,AZ
# Cafe 1010,1010 W Washington St,Phoenix,AZ
# City Square Deli & Grill,22601 N 19th Ave, Ste 121,Phoenix,AZ
# Helio Basin Brewing,3935 E Thomas Rd,Phoenix,AZ
# Lux Central,4400 N Central Ave,Phoenix,AZ
# The Coronado,2201 N 7th St,Phoenix,AZ
# Ollie Vaughn's,1526 E McDowell Rd,Phoenix,AZ
# Beneficial Beans,1221 N Central Ave,Phoenix,AZ
# The Dressing Room,220 E Roosevelt St,Phoenix,AZ
# Shorty's Sandwich Shop,3767 E Broadway Rd, Ste 8,Phoenix,AZ
# Nana Tee's Hometown Dogs,4212 W Cactus Rd, Ste 1107,Phoenix,AZ
# Ncounter,888 N 1st Ave, Ste 114,Phoenix,AZ
# My Gal Sal Bakery & Catering,15820 N 35th Ave, Ste 18,Phoenix,AZ
# Hidden Track Café,111 W Monroe St, Ste 121,Phoenix,AZ
# Jacked Ice,,Phoenix,AZ
# La Casita Cafe,6036 S 7th Ave, Ste 110,Phoenix,AZ
# Tuck Shop,2245 N 12th St,Phoenix,AZ
# Hit Ratio:  0.703296703297
# NDCG:  0.824389753574
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Charlotte
# number of valid user:  838
# number of valid test user:  838
# HoneyBaked Ham,5700 University Pointe Blvd, Suite 115,Charlotte,NC
# The Cookin Coop,,Charlotte,NC
# The Tasty Bowl Subs N Such,2900 Westinghouse Blvd, Ste 116,Charlotte,NC
# Chicken King,3222 Rozzelles Ferry Rd,Charlotte,NC
# Circles Grill and Market,8129 Ardrey Kell Rd,Charlotte,NC
# Rhino Market & Deli,1500 W Morehead St, Ste E,Charlotte,NC
# The Turnhouse Grille,1600 E Woodlawn Rd, Ste 100,Charlotte,NC
# Murphy's Kitchen & Tap,445 W Trade St,Charlotte,NC
# Bedder Bedder & Moore Montford-Abbey,1730 Abbey Pl, Ste 4,Charlotte,NC
# 300 East,300 East Blvd,Charlotte,NC
# Chicken Salad Chick,7617-C Pineville-Matthews Rd,Charlotte,NC
# Whooli's Grill,7146 E Independence Blvd,Charlotte,NC
# The Great Wagon Road Distilling Co,227 Southside Dr,Charlotte,NC
# The Peace Pipe,204 W Woodlawn Rd, Ste H,Charlotte,NC
# My Camille's,9211 N Tryon St, Ste 9,Charlotte,NC
# Rush Espresso Cafe and Wine Bar,14825 Ballantyne Village Way, Ste 135,Charlotte,NC
# Great Harvest Bread,1824 E Arbors Dr, Ste 390,Charlotte,NC
# Studio Cellar,1800 Camden Rd,Charlotte,NC
# Palmer St,412 W Palmer St,Charlotte,NC
# Hit Ratio:  0.62962962963
# NDCG:  0.859915756986
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Edinburgh
# number of valid user:  94
# number of valid test user:  94
# Colonnades,The Signet Library, Parliament Square, The Royal Mile,Edinburgh,EDH
# The Safari Lounge,21 Cadzow Place, London Road,Edinburgh,EDH
# Nobles Cafe Bar & Venue,44a Constitution Street, Leith,Edinburgh,EDH
# Badger & Co.,32 Castle Street,Edinburgh,EDH
# Colonial House,305 Leith Walk,Edinburgh,EDH
# Sala Cafe Bar,58a Broughton Street,Edinburgh,EDH
# Filament Coffee,5 India Buildings, Victoria Street,Edinburgh,EDH
# The Grain Store,30 Victoria Street,Edinburgh,EDH
# Black Dutch Cafe Bar,91 Montgomery Street,Edinburgh,EDH
# Cafe Cassis,43-45 Salisbury Road,Edinburgh,EDH
# Uncle T's,8 Forrest Road,Edinburgh,EDH
# Joseph Pearce,23 Elm Row,Edinburgh,EDH
# Gannet and Guga,Unit 2-3 The Arches, East Market Street,Edinburgh,EDH
# The Spiegeltent,George Square Gardens,Edinburgh,EDH
# The Persevere Bar,398 Easter Road,Edinburgh,EDH
# The Cocktail Emporium,44 Broughton Street,Edinburgh,EDH
# Ye Olde Inn,25 Main Street Davidsons Mains,Edinburgh,MLN
# Stramash,207 Cowgate,Edinburgh,EDH
# The Royal Dick Bar,Summerhall, 1 Summerhall,Edinburgh,EDH
# Hit Ratio:  1.0
# NDCG:  0.876926682343
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Pittsburgh
# number of valid user:  637
# number of valid test user:  637
# Smallman Galley,54 21st St,Pittsburgh,PA
# Mixtape,4907 Penn Ave,Pittsburgh,PA
# Perspolis Hookah Lounge,304 N Craig St,Pittsburgh,PA
# S&D Cafe,1425 Forbes Ave,Pittsburgh,PA
# Arancini House,615 Washington Rd,Pittsburgh,PA
# Joey D's in the Park, RIDC,180 Gamma Dr,Pittsburgh,PA
# Leaf and Plate,5884 Ellsworth Ave, 1st Fl,Pittsburgh,PA
# Altius,1230 Grandview Ave,Pittsburgh,PA
# Colony Café,1125 Penn Ave,Pittsburgh,PA
# Proper Brick Oven & Tap Room,139 7th St,Pittsburgh,PA
# Lexus Club at PNC Park,115 Federal St,Pittsburgh,PA
# Bakersfield Penn Ave,940 Penn Ave,Pittsburgh,PA
# Verde Good Beans,412 First Ave,Pittsburgh,PA
# Dive Bar and Grille,2132 East Carson St,Pittsburgh,PA
# Carson Street Deli & Craft Beer Bar,1507 E Carson St,Pittsburgh,PA
# The Alcove,875 Greentree Rd, Ste 6, Bldg 4,Pittsburgh,PA
# Marketplace Cafe,Nordstrom, 1000 Ross Park Mall Dr,Pittsburgh,PA
# Skinny Pete's Kitchen,538 California Ave,Pittsburgh,PA
# Redwood Cafe,698 Washington Rd,Pittsburgh,PA
# Hit Ratio:  0.739130434783
# NDCG:  0.844719527332
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Montréal
# number of valid user:  378
# number of valid test user:  378
# Bouffe Dave Plant Food,1206 Boulevard de Maisonneuve E,Montréal,QC
# Café de' Mercanti,350 Rue Notre-Dame Est,Montréal,QC
# Novanta Café,90 Avenue Laurier O,Montréal,QC
# Café Tuyo,370 Rue Marie-Anne,Montréal,QC
# Farine,102 Saint-Viateur Ouest,Montréal,QC
# Yummy2Go,Métro Atwater, 3015 Boulevard de Maisonneuve Ouest,Montréal,QC
# Green,443 Avenue Viger O,Montréal,QC
# Café Aléatoire,1964 rue Notre-Dame ouest,Montréal,QC
# Kiffin,3439 Rue Saint-Denis,Montréal,QC
# Belém Café & Yoga - L'Espace Café,4409 Boulevard Saint-Laurent,Montréal,QC
# Salerno,2411 Avenue Charland,Montréal,QC
# Chez Lavigne,4280 Rue Notre-Dame O,Montréal,QC
# Un Autre Restaurant,200 Rue Saint-Viateur Ouest,Montréal,QC
# Dans la Gueule du Loup,2055 Avenue Laurier E,Montréal,QC
# La Rouladerie,1205 Avenue Bernard,Montréal,QC
# Le Pier 66,361 Rue Bernard O,Montréal,QC
# Le Majestique,4105 Boulevard Saint-Laurent,Montréal,QC
# Auberge du Dragon Rouge,8870 Rue Lajeunesse,Montréal,QC
# Kaiji Sushi,2115 Jean-Talon Est,Montréal,QC
# Hit Ratio:  0.625
# NDCG:  0.873550819745
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Scottsdale
# number of valid user:  882
# number of valid test user:  882
# B&R Wine - Food,7366 E Shea Blvd, Ste 112,Scottsdale,AZ
# The Original Marketplace,7272 E Indian School Rd, Ste 105,Scottsdale,AZ
# Sorso Wine Room,15323 N Scottsdale Rd, Ste 150,Scottsdale,AZ
# CM2 Pizzeria & Bakeshop,11485 N 136th St,Scottsdale,AZ
# Sugar Jam Bake Shop & Bistro,7950 E Redfield Rd,Scottsdale,AZ
# Tommy V's Urban Kitchen & Bar,7303 E Indian School Rd,Scottsdale,AZ
# Starfire Grille,11500 N Hayden Rd,Scottsdale,AZ
# Cafe Monarch,6934 E 1st Ave, Ste 102,Scottsdale,AZ
# Snooze An AM Eatery,15054 N Scottsdale Rd, Ste 110 D18,Scottsdale,AZ
# D'Lite Healthy On The Go,7337 E Shea Blvd, Ste 100,Scottsdale,AZ
# Pasto di Forno,7116 E Mercer Ln, Ste 101,Scottsdale,AZ
# East & West Cafe,8880 E Via Linda,Scottsdale,AZ
# La Locanda,6830 E 5th Ave, Ste 108,Scottsdale,AZ
# Street Cafe and Coffee Lounge,10435 N Scottsdale Rd,Scottsdale,AZ
# Forno Fabbri 1949,8977 N Scottsdale Rd, Ste 504,Scottsdale,AZ
# Craft 64,6922 E Main St,Scottsdale,AZ
# Turquoise Bar @ The Andaz,6114 North Scottsdale Rd,Scottsdale,AZ
# Postino Highland,4821 N Scottsdale Rd,Scottsdale,AZ
# Sip Coffee & Beer House,3617 N Goldwater Rd,Scottsdale,AZ
# Hit Ratio:  0.707317073171
# NDCG:  0.880104215042
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Cleveland
# number of valid user:  268
# number of valid test user:  268
# Rowley Inn,1104 Rowley Ave,Cleveland,OH
# Speedys Grub Shack,14001 Lakewood Heights Blvd,Cleveland,OH
# Marjees Bar & Grill,3604 Superior Ave,Cleveland,OH
# Ontario Street Cafe,2053 Ontario St,Cleveland,OH
# Tabletop Board Game Cafe,1810 W 25th St,Cleveland,OH
# Knuckleheads,2115 Brookpark Rd,Cleveland,OH
# Distefano's Authentic Italian Foods,5600 Highland Rd,Cleveland,OH
# Barristers Deli,1424 Hamilton Ave,Cleveland,OH
# Applebee's,20705 Center Ridge Rd,Cleveland,OH
# Coffee Bean Cafe & Bakery,2901 Euclid Ave,Cleveland,OH
# Iron City Cafe,4002 Jennings Rd,Cleveland,OH
# Thirst & Ten,15299 Sheldon Rd,Cleveland,OH
# Cleveland Beer Cellars,11500 Euclid Ave,Cleveland,OH
# The Plum Cafe & Kitchen,4133 Lorain Ave,Cleveland,OH
# Murray Hill Market,2072 Murray Hill Rd,Cleveland,OH
# Leader Bar And Grill,526 Superior Ave,Cleveland,OH
# Good To Go,1360 E 9th St,Cleveland,OH
# Cafe Miami,4517 State Rd,Cleveland,OH
# Felice,12502 Larchmere Blvd,Cleveland,OH
# Hit Ratio:  0.80487804878
# NDCG:  0.878474686068
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Madison
# number of valid user:  325
# number of valid test user:  325
# Players Sports Bar,2013 Winnebago St,Madison,WI
# Manna Cafe & Bakery,611 N Sherman Ave,Madison,WI
# Madison Food Explorers,2406 Upham St,Madison,WI
# Sí Café,117 S Pinckney St,Madison,WI
# Highland Espresso Bar,45 S Bassett St,Madison,WI
# Great Harvest Bread,3258 University Ave,Madison,WI
# Village Bar,3801 Mineral Point Rd,Madison,WI
# Hail Mary Sports Grill,401 E Washington Ave,Madison,WI
# Jordan's Big Ten Pub,1330 Regent St,Madison,WI
# Growlers To Go-Go,2927 E Washington Ave,Madison,WI
# Cambridge Winery - Madison Tasting Room,1001 S Whitney Way,Madison,WI
# Salted Root Coffee House,11 N Allen St,Madison,WI
# Leia's Lunchbox,44 E Mifflin St,Madison,WI
# 4&20 Bakery & Cafe,305 N 4th St,Madison,WI
# Pan y Pan,3737 Milwaukee St,Madison,WI
# Mermaid Cafe,1929 Winnebago St,Madison,WI
# PaintBar Madison,1224 Williamson St,Madison,WI
# Indie Coffee,1225 Regent St,Madison,WI
# Black Locust Cafe,829 E Washington Ave,Madison,WI
# Hit Ratio:  0.74358974359
# NDCG:  0.83869340848
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Stuttgart
# number of valid user:  21
# number of valid test user:  21
# Mögle,Dieterlestr. 32,Stuttgart,BW
# Wein-Musketier,Julius-Hölder-Str. 29 B,Stuttgart,BW
# Weinstube Am Stadtgraben,Am Stadtgraben 6,Stuttgart,BW
# El Camino,Marbacher Str. 18,Stuttgart,BW
# Délice,Hauptstätter Str. 61,Stuttgart,BW
# Ulmers Besenwirtschaft,Langobardenstr. 30,Stuttgart,BW
# Weinstube zum Tröpfle,Zabergäustr. 73,Stuttgart,BW
# Weinstube Vetter,Bopserstr. 18,Stuttgart,BW
# Bar Vicino,Traubenstr. 45,Stuttgart,BW
# Heslacher Weinstube,Böcklerstr.18,Stuttgart,BW
# Knausbira Stüble,Heumadener Str. 15,Stuttgart,BW
# Weinstube Viertelesschlotzer,Forststr. 57,Stuttgart,BW
# BO'TECA di vino,Beethovenstr. 30,Stuttgart,BW
# Buschpilot,Karl-Schurz-Str. 28 C,Stuttgart,BW
# Weinstube Cafe Löwen,Trollingerstr. 4,Stuttgart,BW
# Reiterstüble Gasthaus,Furtwänglerstr. 190,Stuttgart,BW
# Nouvel,Köstlinstr. 2,Stuttgart,BW
# Pincho,Epplestr. 30,Stuttgart,BW
# Karl Wöhrwag,Klingenbachstr. 13,Stuttgart,BW
# Hit Ratio:  0.5
# NDCG:  0.665306122449
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Mesa
# number of valid user:  264
# number of valid test user:  264
# Double Overtime Sports Grille,2235 S Power Rd,Mesa,AZ
# Planet Sub Mesa-Grand,1641 S Stapley Dr, Ste 101,Mesa,AZ
# Donut Worry Coffee & Smoothies,9115 E Baseline Rd,Mesa,AZ
# Lava Cafe Hookah Lounge,1038 W Southern Ave, Ste 2,Mesa,AZ
# Big Daddy Vape Mesa,4446 E University Dr, Ste 112,Mesa,AZ
# Miele's Italian and Banquet Hall,2050 W Guadalupe Rd, Ste 9,Mesa,AZ
# Bricks Family Sports Grill,2235 S Power Rd, Ste 127,Mesa,AZ
# Urban Heat,1749 W Main St,Mesa,AZ
# The Hub Grill and Bar,1925 S Sossaman Rd,Mesa,AZ
# Pineapple Grill,4545 E McKellips Rd, Ste C108,Mesa,AZ
# Roosters Country,3731 E Main St,Mesa,AZ
# Drunken Tiger,1954 S Dobson Rd, Ste 5,Mesa,AZ
# Salad and Go,5259 E Brown Rd,Mesa,AZ
# Fat Willy's,2250 S Buttercup Rd,Mesa,AZ
# Sam's Famous Subs,6807 E Broadway Rd,Mesa,AZ
# Boca Taqueria,1249 N Greenfield Rd, Ste 104,Mesa,AZ
# Cafe Agit,1954 S Dobson Rd, Ste 5,Mesa,AZ
# Paradise,1749 W Main St,Mesa,AZ
# Mesa Drummer,1211 N Country Club, Ste 9,Mesa,AZ
# Hit Ratio:  0.5
# NDCG:  0.757212317951
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Tempe
# number of valid user:  334
# number of valid test user:  334
# 1865 Coffee,40 E University Dr,Tempe,AZ
# LaGattara Cat Cafe,1301 E University Dr, Ste 136,Tempe,AZ
# Sweet Dessert Café,715 W Baseline Rd, Ste 2,Tempe,AZ
# Perfect Pear Bistro,9845 S Priest Dr,Tempe,AZ
# Salut Kitchen Bar,1435 E University Dr, Ste 12,Tempe,AZ
# Metro Espresso & Sandwiches,2070 E Apache Blvd, Ste 103,Tempe,AZ
# Around the Board A Board Game Cafe,5004 S. Price Rd,Tempe,AZ
# Lucy's Fountainhead Cafe,1501 W Fountainhead Pkwy, Ste 140,Tempe,AZ
# Snooze An AM Eatery,615 S College Ave, Ste 103,Tempe,AZ
# Panera Bread,1707 W Warner Rd,Tempe,AZ
# Vertigo Hookah Lounge & Cafe,1320 E Broadway Rd, Ste 102,Tempe,AZ
# Postino Annex,615 S College Ave,Tempe,AZ
# Infusion Coffee & Tea,1300 E 8th St, Ste 100,Tempe,AZ
# Crêpe Bar,7520 S Rural Rd, Ste A12,Tempe,AZ
# Subway,1849 E Guadalupe Rd,Tempe,AZ
# Detroit Coney Grill,930 W Broadway Rd,Tempe,AZ
# Steve's Espresso,1801 E Baseline Rd, Ste 102,Tempe,AZ
# Moroccan Paradise,1212 E Apache Blvd,Tempe,AZ
# Pitchforks & Corks,660 S College Ave, Fl 2,Tempe,AZ
# Hit Ratio:  0.484848484848
# NDCG:  0.791871149594
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Henderson
# number of valid user:  423
# number of valid test user:  423
# Costa Del Sol At Sunset Station,1301 W Sunset Road,Henderson,NV
# Served,1770 W Horizon Ridge, Ste 100,Henderson,NV
# Woods Family Sandwiches,931 American Pacific Dr, Ste 106,Henderson,NV
# HoneyBaked Ham,1533 W Sunset Rd,Henderson,NV
# Egg Works,10839 S Eastern Ave,Henderson,NV
# Dylans Grill and Pub,4401 E Sunset Rd,Henderson,NV
# KIT's Kitchen,2021 W Sunset Rd,Henderson,NV
# Chefery,,Henderson,NV
# Sin City Brew Tours,,Henderson,NV
# Akropolis Gyro & Pizza,1690 W Sunset Rd, Ste 104,Henderson,NV
# The Coffee Press,280 S Green Valley Pkwy,Henderson,NV
# Buddha Belly Deli,50 N Valle Verde Dr, Ste 110,Henderson,NV
# Purple Potato by Yonaka,10090 S Eastern Ave, Ste 110,Henderson,NV
# The Players Club LV,75 S, Ste phanie,Henderson,NV
# Straight From Philly Steakout,1659 W Warm Springs Rd, Ste 100,Henderson,NV
# Straight From Philly,65 W Lake Mead Pkwy,Henderson,NV
# Burger Joint,10890 S Eastern Ave, Ste 108,Henderson,NV
# Me Gusta Tacos,2235 Village Walk Dr, Ste 153,Henderson,NV
# Fix8 Fitness Cafe,72 W Horizon Ridge Pkwy, Ste 105,Henderson,NV
# Hit Ratio:  0.690909090909
# NDCG:  0.929623554558
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Mississauga
# number of valid user:  165
# number of valid test user:  165
# Cities Sports Bar & Grill,5835 Dixie Road,Mississauga,ON
# Ya Hala,1969 Lakeshore Road W,Mississauga,ON
# Roosters Edge,812 Britannia Road W, Unit 104,Mississauga,ON
# Tim Horton,910 Lakeshore Road E,Mississauga,ON
# St. Louis Bar & Grill,29 Aventura Court,Mississauga,ON
# Desi Bar & Grill,925 Rathburn Road E,Mississauga,ON
# Kelseys Original Roadhouse,3970 Grand Park Drive,Mississauga,ON
# Oliver's Ale House,6155 Tomken Road,Mississauga,ON
# Ricks Good Eats,6660 Kennedy Road, Unit 1,Mississauga,ON
# Pak Sweets,400 Dundas Street E,Mississauga,ON
# Piatto Bistro,1646 Dundas Street W,Mississauga,ON
# Stavro's Greek Restaurant & Lounge,11 Pearl Street,Mississauga,ON
# Rehevot Shawarma,4870 Tomken Road, Unit 2,Mississauga,ON
# Pizza Nostra,362 Lakeshore Road W,Mississauga,ON
# Al-Omda Lounge,33-3100 Ridgeway Drive,Mississauga,ON
# Thyme Ristorante,347 Lakeshore Road E,Mississauga,ON
# The Mission Eatery,5915 Airport Road, Suite100,Mississauga,ON
# Solstice Restaurant & Wine Bar,1801 Lakeshore Road W,Mississauga,ON
# The Clarkson Pump & Patio,1744 Lakeshore Road W,Mississauga,ON
# Hit Ratio:  0.347826086957
# NDCG:  0.679450304312
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Chandler
# number of valid user:  321
# number of valid test user:  321
# GRAZ Kitchen Fresh,1005 S Arizona Ave, Ste 6,Chandler,AZ
# SanTan Brewing Company,8 S San Marcos Pl,Chandler,AZ
# American Way Market,1509 N Arizona Ave,Chandler,AZ
# Cuisine & Wine Bistro - Chandler,4991 S Alma School Rd St 101,Chandler,AZ
# Kiwi Juice Bar,3985 S Arizona Ave,Chandler,AZ
# Smokin Fins,900 N 54th St, Ste 1,Chandler,AZ
# VB Lounge,81 W Boston St,Chandler,AZ
# Bella Gusto Urban Pizzeria,1964 N Alma School Rd, Ste 1,Chandler,AZ
# Rick's Pub and Grub,4910 W Ray Rd,Chandler,AZ
# Press Coffee,2577 W Queen Creek Rd, Ste 100,Chandler,AZ
# Mozza Hookah Lounge,1964 N Alma School Rd, Unit 10, Zorba's Greek Cafe,Chandler,AZ
# Arizona Mead Company,6503 W Frye Rd, Ste 12,Chandler,AZ
# Sawtooth Bar & Grill,4929 W Ray Rd, Ste 3,Chandler,AZ
# Slice of Chicago,478 N Arizona Ave,Chandler,AZ
# Twisted Cactus Brewing Company,4080 W Ray Rd, Ste 26,Chandler,AZ
# AZ Food Crafters,961 W Ray Rd, Ste 1,Chandler,AZ
# Rocket Burger & Subs,2100 W Chandler Blvd, Ste 38,Chandler,AZ
# Pokitrition - Poke Shop,3235 W Ray Rd, Ste 3,Chandler,AZ
# Buon Padre Pizza,1080 E Pecos Rd,Chandler,AZ
# Hit Ratio:  0.652777777778
# NDCG:  0.852048164448
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Gilbert
# number of valid user:  202
# number of valid test user:  202
# Triple 2's Tavern,1686 N  Higley Rd, Ste 101,Gilbert,AZ
# Frost Gelato,2150 E Williams Field Rd, Ste 120,Gilbert,AZ
# Casanova Brothers Pizza,929 N Val Vista Dr, Ste 101,Gilbert,AZ
# Fire and Brimstone,3000 E Ray Rd,Gilbert,AZ
# Four Silos Cafe,143 S Higley Rd,Gilbert,AZ
# Everybody Loves Fondue,3244 E Guadalupe Rd,Gilbert,AZ
# Postino East,302 N Gilbert Rd,Gilbert,AZ
# Local Eats,6348 S Higley Rd,Gilbert,AZ
# Salad and Go,743 N Gilbert Rd,Gilbert,AZ
# Wild Ginger,861 N Higley Rd, Ste 111,Gilbert,AZ
# Zappone's Italian Bistro,1652 N Higley Rd, Ste 103,Gilbert,AZ
# 1455 American Grill,1455 W Elliot Rd, Ste 101,Gilbert,AZ
# Lesley's Creative Cakes,2401 E Baseline Rd,Gilbert,AZ
# Tropical Sno,2268 E Williams Field Rd, Bldg 7, Ste108,Gilbert,AZ
# Bruster's Real Ice Cream,709 W Ray Rd,Gilbert,AZ
# Menchie's Frozen Yogurt,3757 S Gilbert Rd, Ste 108,Gilbert,AZ
# Water and Ice Discount Superstore,785 W Warner Rd, Ste A113,Gilbert,AZ
# The Soda Shop,4311 E Baseline Rd, Ste 101A,Gilbert,AZ
# Baskin-Robbins,1939 E Baseline Rd, Ste 112,Gilbert,AZ
# Hit Ratio:  0.513513513514
# NDCG:  0.793746022969
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Glendale
# number of valid user:  132
# number of valid test user:  132
# Braistas Coffee Bar,6409 W Glendale Ave,Glendale,AZ
# Panini Bread & Grill,3510 W Bell Rd,Glendale,AZ
# Tavern+Bowl,9380 W Westgate Blvd,Glendale,AZ
# Flora House Cafe,6922 N 95th Ave, Ste 200,Glendale,AZ
# My Hidden Bistro,19805 N 51st Ave,Glendale,AZ
# Olde Towne Glendale Wine and Beer Bar,5745 W Glendale Ave,Glendale,AZ
# Lucky's Pizza,6630 W Cactus Rd, Ste B108,Glendale,AZ
# Venice Pizza,4645 W Maryland Ave,Glendale,AZ
# Doglicious Hot Dogs,5060 W Bell Rd, Ste A,Glendale,AZ
# A Taste of Buffalo,17045 N 59th Ave, Ste 103,Glendale,AZ
# Gaslight Cafe,5747 W Glendale Ave,Glendale,AZ
# Wildflower Bread Company,17530 N 75th Ave,Glendale,AZ
# La Santisima,5932 W Glendale Ave,Glendale,AZ
# Rainbow Donuts,4729 W Olive Ave,Glendale,AZ
# Small Town Coffeehouse,19420 N 59th Ave, Ste D-415,Glendale,AZ
# Kimmyz on Greenway Rock & Roll Bar & Grill,5930 W Greenway Rd,Glendale,AZ
# Playgrounds Fun Zone & Cafe,8190 W Union Hills Dr, Ste 110,Glendale,AZ
# Rayner's Chocolate & Coffee Shop,14021 N 51st Ave,Glendale,AZ
# Cafe Lito,7155 W Campo Bello Dr, Bldg A, Ste 2,Glendale,AZ
# Hit Ratio:  0.708333333333
# NDCG:  0.865326858693
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Markham
# number of valid user:  197
# number of valid test user:  197
# Golf Wing Virtual Golf & Restaurant,7500 Woodbine Avenue, Unit G,Markham,ON
# Eini & Co,3229 Hwy 7 E,Markham,ON
# Matcha Tea & Dessert,505 Highway 7 E, Unit 15, Commerce Gate,Markham,ON
# Paintlounge,118 Main Street N,Markham,ON
# Raw-More Cafe,8110 Birchmount Road, Suite 10,Markham,ON
# Duo Patisserie & Cafe,230 Commerce Valley Drive E, Unit 4,Markham,ON
# The Old Curiosity Tea Shop,91 Main Street N,Markham,ON
# The Bake House,250 Cochrane Drive, Unit 9,Markham,ON
# Food Jungle,4300 Steeles Avenue E,Markham,ON
# Funky Munky Cafe,9275 Markham Road, Unit 7,Markham,ON
# Cultural Cafe,105 Gibson Drive,Markham,ON
# Bodira Cafe and Fine Foods,6899 14th Avenue, Unit 3,Markham,ON
# Ocean Palate,7181 Yonge Street, Unit  243,Markham,ON
# Alden Coffee Shop,431 Alden Road,Markham,ON
# Sweet Esc,30 Gibson Drive, Unit 120,Markham,ON
# Tasty House,3255 Highway 7 E,Markham,ON
# Toast Delight,8339 Kennedy Road, Unit 2659,Markham,ON
# Graceful Vegetarian Restaurant,Market Village, 7131 Kennedy Road, Suite 8,Markham,ON
# Alchemy Coffee,4361 Highway 7 E, Unit 1,Markham,ON
# Hit Ratio:  0.47619047619
# NDCG:  0.816508139168
# ============================================
#
#
#
#
#
# ============================================
# Recommendation info summary for :  Peoria
# number of valid user:  44
# number of valid test user:  44
# What's Fresh?,8650 W Peoria Ave, Ste 1038,Peoria,AZ
# K Star BBQ,,Peoria,AZ
# Winery 101,9299 W Olive Ave, Ste 101,Peoria,AZ
# Chick-fil-A,16657 N 83rd Ave,Peoria,AZ
# Jamburritos Cajun Grille - Express,8200 W Peoria Ave,Peoria,AZ
# Sardella's Pizza & Wings,8278 W Lake Pleasant Pkwy,Peoria,AZ
# Dash Grill,7557 W Greenway Rd, Ste 104,Peoria,AZ
# Pizza Near Me,8525 W Grand Ave,Peoria,AZ
# Firebirds Wood Fired Grill,16067 N Arrowhead Fountains Ctr Dr,Peoria,AZ
# Headquarters Grill Bar Sushi,16041 N Arrowhead Fountains Center Dr,Peoria,AZ
# Brunos Pizza,6750 W Olive Ave,Peoria,AZ
# JJ's Louisiana BBQ,5601 W Glendale Ave,Peoria,AZ
# BoSa Donuts,7446 W Cactus Rd,Peoria,AZ
# Crispy Crust Pizza,7558 W Thunderbird Rd,Peoria,AZ
# Deli Sports Bar,9635 W Peoria Ave,Peoria,AZ
# Revolu Modern Taqueria + Bar,15703 N 83rd Ave, Ste 110,Peoria,AZ
# Coop's Bar & Grill,8455 W Peoria Ave,Peoria,AZ
# Modern Round,8320 W Mariners Way,Peoria,AZ
# TRU Burger Company,9828 W Northern Ave,Peoria,AZ
# Hit Ratio:  0.777777777778
# NDCG:  0.884834626178
# ============================================

# %%
plt.hist(hr_list, bins=[x for x in np.arange(0., 1.01, 0.1)])
plt.show()

# %%
plt.hist(ndcg_list, bins=[x for x in np.arange(0., 1.01, 0.1)])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pylab
import json

from datetime import datetime

from pyspark.sql import SQLContext
from pyspark.sql.types import *
from pyspark import SparkContext

from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating

# %%
sc =SparkContext()
sqlContext = SQLContext(sc)

# %%
threshold = 20
users = sc.textFile('dataset/user.json')
filter_user = users.map(lambda l: json.loads(l)).filter(lambda l: l['review_count'] >= threshold).map(lambda l: (l['user_id'])).zipWithIndex().persist()

# %%
filter_user.first()
# Out:
# ('lsSiIjAKVl-QRxKjRErBeg', 0)

# %%
def getkc(l):
    a = json.loads(l)
    return (a['user_id'], a)

# %%
reviews = sc.textFile('dataset/review.json').map(getkc).persist()

# %%
reviews.first()
# Out:
# ('cjpdDjZyprfyDG3RlkVG3w',
#  {'business_id': 'uYHaNptLzDLoV_JZ_MuzUA',
#   'cool': 0,
#   'date': '2016-07-12',
#   'funny': 0,
#   'review_id': 'VfBHSwC5Vz_pbFluy07i9Q',
#   'stars': 5,
# ...

# %%
join_reviews = reviews.join(filter_user)
join_reviews.take(5)
#data.saveAsTextFile("filter_dataset/review/")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-45-804fbae18d1d> in <module>()
#       1 join_reviews = reviews.join(filter_user)
# ----> 2 join_reviews.take(5)
#       3 #data.saveAsTextFile("filter_dataset/review/")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\rdd.py in take(self, num)
#    1341
#    1342             p = range(partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1343             res = self.context.runJob(self, takeUpToNumLeft, p)
#    1344
#    1345             items += res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\context.py in runJob(self, rdd, partitionFunc, partitions, allowLocal)
#     990         # SparkContext#runJob.
#     991         mappedRDD = rdd.mapPartitions(partitionFunc)
# --> 992         port = self._jvm.PythonRDD.runJob(self._jsc.sc(), mappedRDD._jrdd, partitions)
# ...

# %%
filter_reviews = join_reviews.map(lambda l: l[1][0])
filter_reviews.take(5)

# %%
def get_rating(l):
    j = json.loads(l)    
    user = hash(j['user_id']) % (10 ** 8)
    business = hash(j['business_id']) % (10 ** 8)
    rate = j['stars']
    return Rating(user,business,float(rate))

# %%
filter_reviews.take(5)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-44-0362fbadf4f7> in <module>()
# ----> 1 filter_reviews.take(5)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\rdd.py in take(self, num)
#    1341
#    1342             p = range(partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1343             res = self.context.runJob(self, takeUpToNumLeft, p)
#    1344
#    1345             items += res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\context.py in runJob(self, rdd, partitionFunc, partitions, allowLocal)
#     990         # SparkContext#runJob.
#     991         mappedRDD = rdd.mapPartitions(partitionFunc)
# --> 992         port = self._jvm.PythonRDD.runJob(self._jsc.sc(), mappedRDD._jrdd, partitions)
#     993         return list(_load_from_socket(port, mappedRDD._jrdd_deserializer))
#     994
#
# ...

# %%
ratings = reviews.map(get_rating)

# %%
rank = 10
numIterations = 10
model = ALS.train(ratings, rank, numIterations)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-18-b170cb862e0b> in <module>()
#       1 rank = 10
#       2 numIterations = 10
# ----> 3 model = ALS.train(ratings, rank, numIterations)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\mllib\recommendation.py in train(cls, ratings, rank, iterations, lambda_, blocks, nonnegative, seed)
#     270           (default: None)
#     271         """
# --> 272         model = callMLlibFunc("trainALSModel", cls._prepare(ratings), rank, iterations,
#     273                               lambda_, blocks, nonnegative, seed)
#     274         return MatrixFactorizationModel(model)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\mllib\recommendation.py in _prepare(cls, ratings)
#     227             raise TypeError("Ratings should be represented by either an RDD or a DataFrame, "
# ...

# %%
testdata = ratings.map(lambda p: (p[0], p[1]))

# %%
ratesAndPreds = ratings.map(lambda r: ((r[0], r[1]), r[2])).join(predictions)
MSE = ratesAndPreds.map(lambda r: (r[1][0] - r[1][1])**2).mean()
print("Mean Squared Error = " + str(MSE))

# %%
model.save(sc, "target/myCollaborativeFilter")

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pylab
import json

from datetime import datetime

# %%
df_users = pd.read_json('D:/desk_2104/CS Sem4/CS6220/Project/dataset/user.json', lines=True)

# %%
df_users.head()
# Out:
#    average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0           3.80             5174              284              5174
# 1           3.94             1556              211              1556
# 2           4.72               15                1                15
# 3           3.76                9                0                 9
# 4           4.23              276                0               276
#
#    compliment_hot  compliment_list  compliment_more  compliment_note  \
# 0            5175               78              299             1435
# 1            1285              101              134             1295
# 2               5                0                1               11
# 3               1                0                1                4
# 4              59                0                8               51
#
#    compliment_photos  compliment_plain      ...         cool  \
# 0               7829              7397      ...        16856
# ...

# %%
#Reading big file line by line, taking first 1000 reviews
c=0
s = open('D:/desk_2104/CS Sem4/CS6220/Project/dataset/review_sub.json','w')
with open('D:/desk_2104/CS Sem4/CS6220/Project/dataset/review.json') as f:
    for line in f:
        c=c+1
        s.write(line)
        if(c == 1000):
            break

# %%
df_reviews = pd.read_json('D:/desk_2104/CS Sem4/CS6220/Project/dataset/review_sub.json', lines=True)

# %%
df_reviews.head()
# Out:
#               business_id  cool       date  funny               review_id  \
# 0  uYHaNptLzDLoV_JZ_MuzUA     0 2016-07-12      0  VfBHSwC5Vz_pbFluy07i9Q
# 1  uYHaNptLzDLoV_JZ_MuzUA     0 2016-10-02      0  3zRpneRKDsOPq92tq7ybAA
# 2  uYHaNptLzDLoV_JZ_MuzUA     0 2015-09-17      0  ne5WhI1jUFOcRn-b-gAzHA
# 3  uYHaNptLzDLoV_JZ_MuzUA     0 2016-08-21      0  llmdwOgDReucVoWEry61Lw
# 4  uYHaNptLzDLoV_JZ_MuzUA     0 2013-11-20      0  DuffS87NaSMDmIfluvT83g
#
#    stars                                               text  useful  \
# 0      5  My girlfriend and I stayed here for 3 nights a...       0
# 1      3  If you need an inexpensive place to stay for a...       0
# 2      3  Mittlerweile gibt es in Edinburgh zwei Ableger...       0
# 3      4  Location is everything and this hotel has it! ...       0
# 4      5  gute lage im stadtzentrum. shoppingmeile und s...       0
#
#                   user_id
# 0  cjpdDjZyprfyDG3RlkVG3w
# 1  bjTcT8Ty4cJZhEOEo01FGA
# 2  AXgRULmWcME7J6Ix3I--ww
# ...

# %%
df_bus = pd.read_json('D:/desk_2104/CS Sem4/CS6220/Project/dataset/business.json', lines=True)

# %%
res_mer = pd.merge(df_bus,df_reviews, on='business_id')

# %%
res_mer
# Out:
#                      address  \
# 0    4520 N Tryon St, Ste 25
# 1    4520 N Tryon St, Ste 25
# 2    4520 N Tryon St, Ste 25
# 3    4520 N Tryon St, Ste 25
# 4    4520 N Tryon St, Ste 25
# 5    4520 N Tryon St, Ste 25
# 6    4520 N Tryon St, Ste 25
# 7         1614 Washington Rd
# 8         1614 Washington Rd
# 9         1614 Washington Rd
# 10        1614 Washington Rd
# 11        1614 Washington Rd
# 12        1614 Washington Rd
# 13        1614 Washington Rd
# 14        1614 Washington Rd
# 15        1614 Washington Rd
# 16        1614 Washington Rd
# 17        1614 Washington Rd
# 18        1614 Washington Rd
# 19        1614 Washington Rd
# 20        1614 Washington Rd
# 21        1614 Washington Rd
# 22        1614 Washington Rd
# 23        1614 Washington Rd
# 24        1614 Washington Rd
# 25        1614 Washington Rd
# 26        1614 Washington Rd
# 27        1614 Washington Rd
# 28        1614 Washington Rd
# 29        1614 Washington Rd
# ..                       ...
# ...
